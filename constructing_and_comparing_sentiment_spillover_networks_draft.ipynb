# %% [markdown]
# # **`README.md`**
#
# # Constructing and Comparing Sentiment Spillover Networks
#
# <!-- PROJECT SHIELDS -->
# [![License: MIT](https://img.shields.io/badge/License-MIT-blue.svg)](https://opensource.org/licenses/MIT)
# [![Python Version](https://img.shields.io/badge/python-3.10%2B-blue.svg)](https://www.python.org/)
# [![arXiv](https://img.shields.io/badge/arXiv-2604.26811-b31b1b.svg)](https://arxiv.org/abs/2604.26811)
# [![Journal](https://img.shields.io/badge/Journal-ArXiv%20Preprint-003366)](https://arxiv.org/abs/2604.26811)
# [![Year](https://img.shields.io/badge/Year-2026-purple)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Discipline: Econometrics](https://img.shields.io/badge/Discipline-Information%20Econometrics-00529B)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Discipline: Network Science](https://img.shields.io/badge/Discipline-Computational%20Network%20Science-00529B)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Discipline: Topology](https://img.shields.io/badge/Discipline-Combinatorial%20Topology-00529B)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Data Sources](https://img.shields.io/badge/Data-Bloomberg%20Terminal%20%7C%20News%20%26%20Social%20Media-lightgrey)](https://www.bloomberg.com/professional/solution/bloomberg-terminal/)
# [![Core Method: Transfer Entropy](https://img.shields.io/badge/Method-Transfer%20Entropy-orange)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Core Method: Markov Bootstrap](https://img.shields.io/badge/Method-Markov%20Bootstrap-orange)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Core Method: PageRank](https://img.shields.io/badge/Method-Weighted%20PageRank-orange)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Core Method: MSA](https://img.shields.io/badge/Method-Maximum%20Spanning%20Arborescence-orange)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Optimization](https://img.shields.io/badge/Optimization-Chu--Liu%2FEdmonds-red)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
# [![Code style: black](https://img.shields.io/badge/code%20style-black-000000.svg)](https://github.com/psf/black)
# [![Type Checking: mypy](https://img.shields.io/badge/type%20checking-mypy-blue)](http://mypy-lang.org/)
# [![NumPy](https://img.shields.io/badge/numpy-%23013243.svg?style=flat&logo=numpy&logoColor=white)](https://numpy.org/)
# [![Pandas](https://img.shields.io/badge/pandas-%23150458.svg?style=flat&logo=pandas&logoColor=white)](https://pandas.pydata.org/)
# [![NetworkX](https://img.shields.io/badge/NetworkX-%2300529B.svg?style=flat)](https://networkx.org/)
# [![Statsmodels](https://img.shields.io/badge/Statsmodels-%233F51B5.svg?style=flat)](https://www.statsmodels.org/)
# [![YAML](https://img.shields.io/badge/YAML-%23CB171E.svg?style=flat&logo=yaml&logoColor=white)](https://yaml.org/)
# [![Jupyter](https://img.shields.io/badge/Jupyter-%23F37626.svg?style=flat&logo=Jupyter&logoColor=white)](https://jupyter.org/)
# [![Open Source](https://img.shields.io/badge/Open%20Source-%E2%9D%A4-brightgreen)](https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks)
#
# **Repository:** `https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks`
#
# **Owner:** 2026 Craig Chirinda (Open Source Projects)
#
# This repository contains an **independent**, professional-grade Python implementation of the research methodology from the 2026 paper entitled **"Do News and Social Media Tell the Same Story? Constructing and Comparing Sentiment Spillover Networks"** by:
#
# *   **Fan Wu**
# *   **Anqi Liu**
# *   **Jing Chen**
# *   **Yuhua Li**
#
# The project provides a complete, end-to-end computational framework for replicating the paper's findings. It delivers a modular, highly optimized pipeline that executes the entire research workflow: from the rigorous ingestion and stochastic imputation of high-frequency Bloomberg sentiment data, to the non-parametric estimation of Transfer Entropy, and the extraction of complex topological backbones via Maximum Spanning Arborescences. The pipeline culminates in a rigorous comparative analysis, demonstrating that authoritative news and speculative social media generate fundamentally distinct topologies of information contagion within the U.S. technology sector.
#
# ## Table of Contents
#
# - [Introduction](#introduction)
# - [Theoretical Background](#theoretical-background)
# - [Features](#features)
# - [Methodology Implemented](#methodology-implemented)
# - [Core Components (Notebook Structure)](#core-components-notebook-structure)
# - [Key Callable: `deploy_sentinel_system`](#key-callable-deploy_sentinel_system)
# - [Prerequisites](#prerequisites)
# - [Installation](#installation)
# - [Input Data Structure](#input-data-structure)
# - [Usage](#usage)
# - [Output Structure](#output-structure)
# - [Project Structure](#project-structure)
# - [Customization](#customization)
# - [Contributing](#contributing)
# - [Recommended Extensions](#recommended-extensions)
# - [License](#license)
# - [Citation](#citation)
# - [Acknowledgments](#acknowledgments)
#
# ## Introduction
#
# This project provides a Python implementation of the analytical framework presented in Wu et al. (2026). The core of this repository is the iPython Notebook `constructing_and_comparing_sentiment_spillover_networks_draft.ipynb`, which contains a comprehensive suite of orchestrated tasks to replicate the paper's findings.
#
# The pipeline addresses a foundational vulnerability in behavioral finance: the reliance on linear, mean-based models (like VAR or Granger Causality) to map information flow, which fail to capture the non-Gaussian, heavy-tailed nature of investor sentiment.
#
# The codebase operationalizes the proposed solution—a **High-Frequency "Sentinel" System for Information Topology**:
# -   **Anchors** sentiment measurement in confidence-weighted aggregation and stochastic decay imputation, preserving the non-linear fade of investor memory.
# -   **Enforces** model-free causality detection using Shannon Entropy and Normalized Transfer Entropy, capturing directional information flow without distributional assumptions.
# -   **Propagates** the analysis to the systemic level by constructing dynamic, rolling-window adjacency matrices, filtered for statistical significance via rigorous Markov bootstrapping.
# -   **Evaluates** the topological structure through recursive centrality (PageRank) to identify "Information Hubs" and combinatorial optimization (Chu-Liu/Edmonds) to extract the dominant paths of sentiment contagion.
#
# ## Theoretical Background
#
# The implemented methods combine techniques from Information Econometrics, Computational Network Science, and Combinatorial Topology.
#
# **1. Stochastic Imputation and Signal Synthesis:**
# To handle asynchronous media volumes, missing data is modeled as an exponential decay function with additive Gaussian noise calibrated via an AR(1) process:
# $$ x_t = B e^{-\lambda t} + \epsilon_t, \quad \epsilon_t \sim \mathcal{N}(0, \sigma^2) $$
#
# **2. Information-Theoretic Causality (Transfer Entropy):**
# The framework abandons linear correlation in favor of Transfer Entropy, which quantifies the reduction in uncertainty of a target company's future sentiment ($Z$) provided by a source company's history ($Y$):
# $$ T_{Y \to Z}^{k,l} = H(z_{t+1}|z_t^{(k)}) - H(z_{t+1}|z_t^{(k)}, y_t^{(l)}) $$
# This is normalized to bound the intensity of information flow:
# $$ \hat{T}_{Y \to Z} = \frac{T_{Y \to Z}}{H(z_{t+1}|z_t)} $$
#
# **3. Systemic Influence and Centrality:**
# The framework shifts the analytical unit from pairwise links to global influence using the Weighted PageRank algorithm, identifying nodes whose sentiment shifts have the most profound "ripple effect":
# $$ PR(v_i) = \frac{1-f}{n} + f \sum_{v_j \in V_m} \frac{\hat{T}_{ji}}{d_{v_j}^{out}} PR(v_j) $$
#
# **4. Dominant Path Extraction (Maximum Spanning Arborescence):**
# To isolate the strongest chains of information diffusion, the framework solves a combinatorial optimization problem rooted at the node with peak out-degree:
# $$ \max \sum_{(v_i, v_j) \in \mathbb{T}} w(v_i, v_j) $$
#
# ## Features
#
# The provided iPython Notebook implements the full research pipeline, including:
#
# -   **Strict Temporal Invariants:** Enforces a mathematically guaranteed $T=1319$ master calendar using `pandas_market_calendars`, preventing the silent erasure of missing days.
# -   **Single Source of Truth Indexing:** Utilizes an $O(1)$ `ticker_to_position` map to guarantee that matrix indices are perfectly synchronized with corporate entities across all centrality metrics and arborescences.
# -   **Stochastic Reproducibility:** Employs cryptographic hashing (MD5) to generate deterministic seeds for the `PCG64` random number generator, ensuring perfect reproducibility of the Markov bootstrap across parallel workers.
# -   **Exact Graph Optimization:** Replaces brittle structural heuristics with the `networkx` Edmonds algorithm, explicitly enforcing root constraints to guarantee 100% topological accuracy during MSA extraction.
# -   **Rigorous Null Model Aggregation:** Computes empirical transition matrices without artificial smoothing, ensuring the Markov bootstrap relies solely on observed state dynamics.
# -   **Configuration-Driven Design:** All study parameters, discretization thresholds, and topological policies are managed in an external `config.yaml` file, ensuring strict methodological reproducibility.
#
# ## Methodology Implemented
#
# The core analytical steps directly implement the methodology from the paper:
#
# 1.  **Data Preprocessing (Tasks 1-8):** Ingests raw Bloomberg data. Enforces strict temporal alignment, alias normalization, and missingness profiling across the 34-asset universe.
# 2.  **Stochastic Imputation (Tasks 9-12):** Diagnoses AR(1) plausibility, estimates innovation variance, and applies exponential decay imputation with additive Gaussian noise.
# 3.  **Information Quantification (Tasks 13-16):** Discretizes continuous signals via empirical quantiles, calibrates optimal lags, and computes raw and normalized Transfer Entropy for all 1,122 pairs.
# 4.  **Significance Filtering (Tasks 17-19):** Generates degree-preserving null networks via parallelized Markov Chains and filters the adjacency matrices at the $\alpha=0.10$ significance level.
# 5.  **Topological Analysis (Tasks 20-22):** Computes dynamic network density, weighted in/out-degrees, and recursive PageRank centrality to identify Information Hubs.
# 6.  **Regime & Path Optimization (Tasks 23-25):** Segments the timeline into three regimes, aggregates networks, and extracts the Maximum Spanning Arborescence (MSA) backbones.
# 7.  **Validation & Audit (Tasks 26-29):** Computes Jaccard similarity, evaluates spectral radius for convergence, generates publication-ready tables/figures, and programmatically audits the empirical outputs against the manuscript's core findings.
#
# ## Core Components (Notebook Structure)
#
# The notebook is structured as a logical pipeline with modular orchestrator functions for each of the 29 major tasks. All functions are self-contained, fully documented with strict type hints and comprehensive docstrings, and designed for professional-grade execution.
#
# ## Key Callable: `deploy_sentinel_system`
#
# The project is designed around a single, top-level user-facing interface function:
#
# -   **`deploy_sentinel_system`:** This apex orchestrator function runs the entire automated research pipeline from end-to-end. A single call to this function reproduces the entire computational portion of the project, managing data validation, stochastic imputation, TE estimation, topological extraction, and the final reproduction audit, while persisting all artifacts to disk.
#
# ## Prerequisites
#
# -   Python 3.10+
# -   Core Python dependencies: `numpy`, `pandas`, `scipy`, `statsmodels`, `networkx`, `joblib`, `matplotlib`, `seaborn`, `pyyaml`, `pandas_market_calendars`, `Faker`.
#
# ## Installation
#
# 1.  **Clone the repository:**
#     ```sh
#     git clone https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks.git
#     cd constructing_and_comparing_sentiment_spillover_networks
#     ```
#
# 2.  **Create and activate a virtual environment (recommended):**
#     ```sh
#     python -m venv venv
#     source venv/bin/activate  # On Windows, use `venv\Scripts\activate`
#     ```
#
# 3.  **Install Python dependencies:**
#     ```sh
#     pip install numpy pandas scipy statsmodels networkx joblib matplotlib seaborn pyyaml pandas_market_calendars Faker
#     ```
#
# ## Input Data Structure
#
# The pipeline requires two strictly formatted `pandas.DataFrame` objects (`df_news_sentiment_raw` and `df_social_sentiment_raw`) containing the following columns:
# -   `Date`: `datetime64[ns]` (Discrete daily timestamp index).
# -   `Ticker`: `string` (Canonical ticker identifier).
# -   `Sentiment_Score`: `float64` (Daily confidence-weighted score, range [-1, 1]).
# -   `Story_Count_K` / `Post_Count_K`: `Int64` (Total volume of items, nullable integer).
#
# *Note: The pipeline includes a high-fidelity synthetic data generator that simulates continuous sentiment scores and discrete item counts, injecting realistic missingness for testing purposes.*
#
# ## Usage
#
# The notebook provides a complete, step-by-step guide. The primary workflow is to execute the final cell, which demonstrates how to load the configuration, generate synthetic benchmark data, and use the top-level orchestrator to execute the pipeline:
#
# ```python
# import pandas as pd
# import numpy as np
# import yaml
# from faker import Faker
# from typing import Dict, Any, Tuple
#
# # ==============================================================================
# # Step 1: Synthetic Data Generation
# # ==============================================================================
# # Initialize Faker and Numpy RNG for perfect reproducibility
# fake = Faker()
# Faker.seed(123456)
# np.random.seed(123456)
#
# tech_universe_raw: Dict[str, Any] = {
#     "Tickers": [
#         "AAPL", "MSFT", "NVDA", "GOOGL", "TSLA", "META", "AMZN",
#         "V", "MA", "ADBE", "PYPL", "CRM", "CSCO", "INTC",
#         "AVGO", "ORCL", "ACN", "AMD", "TXN", "QCOM", "INTU",
#         "NOW", "IBM", "SPGI", "AMAT", "ADP", "ADI", "LRCX",
#         "SQ", "MU", "MCO", "FI", "FIS", "MCHP"
#     ],
#     "Ticker_Aliases": {"SQ": ["XYZ"]},
#     "Adjacency_Index_Order": "Tickers"
# }
#
# def generate_synthetic_sentiment_panels(
#     universe: Dict[str, Any],
#     start_date: str = "2019-09-30",
#     n_days: int = 1319
# ) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DatetimeIndex]:
#     """Generates high-fidelity synthetic sentiment panels for News and Social Media."""
#     tickers = universe["Tickers"]
#     master_calendar = pd.bdate_range(start=start_date, periods=n_days)
#     idx = pd.MultiIndex.from_product([master_calendar, tickers], names=["Date", "Ticker"])
#
#     def build_panel(count_col_name: str) -> pd.DataFrame:
#         df = pd.DataFrame(index=idx).reset_index()
#         df["Sentiment_Score"] = np.random.uniform(-1.0, 1.0, size=len(df))
#         df[count_col_name] = np.random.poisson(lam=50, size=len(df))
#
#         missing_mask = np.random.rand(len(df)) < 0.15
#         df.loc[missing_mask, "Sentiment_Score"] = np.nan
#         df.loc[missing_mask, count_col_name] = 0
#
#         df["Date"] = df["Date"].astype("datetime64[ns]")
#         df["Ticker"] = df["Ticker"].astype(str)
#         df["Sentiment_Score"] = df["Sentiment_Score"].astype("float64")
#         df[count_col_name] = df[count_col_name].astype("Int64")
#         return df
#
#     return build_panel("Story_Count_K"), build_panel("Post_Count_K"), master_calendar
#
# df_news_raw, df_social_raw, fallback_cal = generate_synthetic_sentiment_panels(tech_universe_raw)
#
# # ==============================================================================
# # Step 2: Loading the Configuration (config.yaml)
# # ==============================================================================
# def load_study_configuration(filepath: str = "config.yaml") -> Dict[str, Any]:
#     """Loads the deterministic hyperparameters and topological metrics."""
#     with open(filepath, "r") as file:
#         return yaml.safe_load(file)
#
# study_config = load_study_configuration("config.yaml")
#
# # ==============================================================================
# # Step 3: Executing the Pipeline
# # ==============================================================================
# if __name__ == "__main__":
#     print("\nInitiating High-Frequency Sentinel System Deployment...")
#     output_dir = "./sentinel_paper_artifacts"
#
#     try:
#         # Execute the deployment script
#         # Note: deploy_sentinel_system is defined in the Jupyter Notebook
#         deploy_sentinel_system(
#             tech_universe_raw=tech_universe_raw,
#             df_sector_mapping=df_sector_mapping, # Assumed generated
#             df_news_sentiment_raw=df_news_raw,
#             df_social_sentiment_raw=df_social_raw,
#             study_configuration=study_config,
#             output_directory=output_dir
#         )
#         print(f"\nDEPLOYMENT COMPLETE. Artifacts saved to: {output_dir}")
#     except RuntimeError as e:
#         print(f"\nDeployment failed: {e}")
# ```
#
# ## Output Structure
#
# The pipeline serializes artifacts to an `output_directory` containing:
# -   **`Table_1_News_Stats.csv` & `Table_2_Social_Stats.csv`**: Descriptive statistics and stationarity diagnostics.
# -   **`Table_3_Top_5_Influential.csv`**: The persistent influence rankings (PageRank, In/Out-Degree).
# -   **`Figure_5_Density.pdf`**: Time-varying network density plots.
# -   **`Figure_7_Jaccard.pdf`**: Structural similarity comparison over time.
# -   **`Figure_9_Heatmaps_News.pdf` & `Figure_10_Heatmaps_Social.pdf`**: High-dimensional nodal intensity heatmaps.
# -   **`fidelity_diagnostic_log.txt`**: A systematic audit report verifying the replication of qualitative invariants (e.g., the News density spike).
#
# ## Project Structure
#
# ```
# constructing_and_comparing_sentiment_spillover_networks/
# │
# ├── constructing_and_comparing_sentiment_spillover_networks_draft.ipynb    # Main implementation notebook
# ├── config.yaml                                                            # Master configuration file
# ├── requirements.txt                                                       # Python package dependencies
# │
# ├── LICENSE                                                                # MIT Project License File
# └── README.md                                                              # This file
# ```
#
# ## Customization
#
# The pipeline is highly customizable via the `config.yaml` file. Users can modify study parameters such as:
# -   **Stochastic Settings:** Adjust the `decay_rate_lambda` or the `ar_model_order` for the imputation engine.
# -   **Information Theory:** Modify the `optimal_lag_k` or `quantile_levels` to test structural sensitivity.
# -   **Inference Rigor:** Increase the `n_boot` for the Markov bootstrap or tighten the `alpha` threshold for significance filtering.
# -   **Topological Constraints:** Adjust the `pagerank.damping_factor_f` or modify the `regime_breakpoints` for temporal analysis.
#
# ## Contributing
#
# Contributions are welcome. Please fork the repository, create a feature branch, and submit a pull request with a clear description of your changes. Adherence to PEP 8, strict type hinting, and the 1:1 inline comment-to-code-line ratio is required.
#
# ## Recommended Extensions
#
# Future extensions, as suggested by the authors, could include:
# -   **Cross-Industry Spillovers:** Expanding the vertex set beyond the technology sector to map inter-industry sentiment contagion.
# -   **Dynamic Lead-Lag Relationships:** Investigating whether the news spillover network systematically leads the social media network (or vice versa) using cross-correlation of the density time series.
# -   **Systemic Risk Indices:** Integrating the aggregated network density metric as a real-time feature in asset pricing or market crash prediction models.
#
# ## License
#
# This project is licensed under the MIT License. See the `LICENSE` file for details.
#
# ## Citation
#
# If you use this code or the methodology in your research, please cite the original paper:
#
# ```bibtex
# @article{wu2026sentiment,
#   title={Do News and Social Media Tell the Same Story? Constructing and Comparing Sentiment Spillover Networks},
#   author={Wu, Fan and Liu, Anqi and Chen, Jing and Li, Yuhua},
#   journal={arXiv preprint arXiv:2604.26811},
#   year={2026}
# }
# ```
#
# For the implementation itself, you may cite this repository:
# ```
# Chirinda, C. (2026). Constructing and Comparing Sentiment Spillover Networks.
# GitHub repository: https://github.com/chirindaopensource/constructing_and_comparing_sentiment_spillover_networks
# ```
#
# ## Acknowledgments
#
# -   Credit to **Fan Wu, Anqi Liu, Jing Chen, and Yuhua Li** for the foundational research that forms the entire basis for this computational replication.
# -   This project is built upon the exceptional tools provided by the open-source community. Sincere thanks to the developers of the scientific Python ecosystem, particularly the **NumPy**, **Pandas**, **Statsmodels**, and **NetworkX** contributors.
#
# --
#
# *This README was generated based on the structure and content of the `constructing_and_comparing_sentiment_spillover_networks_draft.ipynb` notebook and follows best practices for research software documentation.*

# %% [markdown]
# # Paper
#
# Title: "*Do News and Social Media Tell the Same Story? Constructing and Comparing Sentiment Spillover Networks*"
#
# Authors: Fan Wu, Anqi Liu, Jing Chen, Yuhua Li
#
# E-Journal Submission Date: Submitted on 29 April 2026 (v1), last revised 6 May 2026 (this version, v2)
#
# Link: https://arxiv.org/abs/2604.26811
#
# Abstract:
#
# Investor sentiment reflects the collective attitude of investors towards the asset, whether positive, negative or neutral. Market information, such as news and relevant social media posts, plays a significant role in shaping investor sentiment, which influences investment decisions accordingly. The sentiment for one single company may spill over to other relevant companies which are in the same industry. The information spillover network pattern between news and social media may also differ, as they are two different media sources. In this study, we introduce a network-based transfer entropy method to measure and compare the information transmission of news and social media sentiment across the technology companies. We examine whether and to what extent sentiment information from one company can transfer to other companies, and how different the spillover effect is for news and social media. The result signifies a stronger intensity of news information flow among the tech companies after COVID-19. We also highlight the companies which act as information hubs in the sentiment network. Furthermore, we identify the companies which lead the strongest information flow chain. Overall, this study provides a novel perspective in modelling sentiment spillover under two different media sources, and we find that news and social media show a different information transmission pattern during the studied period.

# %% [markdown]
# # Summary
#
# ### Executive Summary
#
# This formal synthesis examines the research paper titled **"Do News and Social Media Tell the Same Story? Constructing and Comparing Sentiment Spillover Networks"** (Wu et al., 2026). The study investigates the high-frequency dynamics of investor sentiment within the U.S. technology sector, specifically focusing on the "Magnificent Seven" and 27 other influential tech entities. By integrating **Information Theory**—specifically **Transfer Entropy (TE)**—with **Network Topology**, the authors quantify how sentiment information regarding one company propagates to others.
#
# The core findings reveal a significant divergence between information transmission patterns in news versus social media. A pronounced spike in news sentiment network density occurred post-October 2021, coinciding with the post-pandemic tech boom and the subsequent tightening of monetary policy. Conversely, social media sentiment networks demonstrated a downward trend in density following Elon Musk’s acquisition and the rebranding of Twitter to X, suggesting a shift in investor engagement and platform utility. Methodologically, the study provides a robust framework for systemic risk monitoring, identifying companies like **IBM, Salesforce (CRM), and Broadcom (AVGO)** as critical information hubs in news networks, while **Tesla (TSLA)** maintains a dominant role in social media discourse.
#
# ### 1. Introduction and Theoretical Framework
#
# The paper is situated at the intersection of **Behavioral Finance** and **Computational Econometrics**. It challenges the traditional Efficient Market Hypothesis (EMH) by asserting that asset prices are driven not only by fundamentals but by investor responses to market information. The authors define **Investor Sentiment** as a latent variable quantifying collective attitudes (bullish, bearish, or neutral) toward assets.
#
# The study identifies three primary limitations in existing sentiment literature:
# 1.  **Measurement Disadvantages:** Traditional market-based indices capture macroeconomic factors rather than individual attitudes, while survey-based methods suffer from low temporal frequency.
# 2.  **Assumption Constraints:** Common spillover models, such as Vector Autoregressions (VAR) or Granger Causality, often rely on restrictive assumptions of linearity and data normality.
# 3.  **Media Homogeneity:** Most studies analyze a single information source, ignoring the distinct roles played by authoritative news outlets versus speculative social media platforms.
#
# To address these gaps, the authors propose a **Transfer Entropy-based Network** approach. This non-parametric, model-free method measures the directed information flow between companies without assuming linear relationships, making it ideal for the "fat-tailed," non-Gaussian nature of financial sentiment data.
#
#
# ### 2. Methodological Construction: Information Theory and Graph Topology
#
# #### 2.1. Mathematical Foundations of Transfer Entropy
# The study’s analytical engine is grounded in **Shannon Entropy**, which measures the average information content of a random variable $Z$. For a discretized time series, entropy is defined as:
# $H(Z) = − \sum p(z_t) \log_2 p(z_t)$.
#
# Building upon this, **Transfer Entropy (TE)** from a sentiment process $Y$ to $Z$ quantifies the reduction in uncertainty of $Z$'s future state ($z_{t+1}$) given the past of $Y$ ($y_t^{(l)}$), beyond what is already provided by $Z$'s own history ($z_t^{(k)}$). The authors utilize a **normalized TE** ($\hat{T}_{Y \to Z}$) to bound results between, facilitating a clear interpretation of information flow intensity.
#
# #### 2.2. Network Topology and Metrics
# The authors represent the tech sector as a directed, arc-weighted network $G = (V, A, w)$, where vertices ($V$) represent companies and edge weights ($w$) represent normalized TE values. Key metrics include:
# *   **Weighted In/Out-Degree:** Measures the sum of information absorbed (in-degree) and transmitted (out-degree) by a specific node.
# *   **PageRank Algorithm:** Identifies influential "information hub" companies by considering both the quantity and quality of their connections.
# *   **Maximum Spanning Arborescence (MSA):** Extracts the "strongest information flow chain" from the root vertex, highlighting the dominant paths of sentiment contagion.
#
# #### 2.3. Statistical Significance and Dynamics
# To filter noise, the authors employ a **Markov bootstrap method**. This process generates simulated time series that preserve internal dependencies but break cross-series dependencies, allowing for the calculation of p-values to identify statistically significant spillover entries at the 90% confidence level. The evolution of these networks is captured via a **rolling window technique** (200-day window with a 10-day step).
#
#
# ### 3. Data Engineering and Model Calibration
#
# #### 3.1. Dataset Characteristics
# The empirical analysis utilizes daily Bloomberg News and Twitter (X) sentiment indicators for 34 major technology companies from September 2019 to October 2024 (1,319 data points). Bloomberg uses machine-learning classifiers to assign sentiment scores (bullish/bearish/neutral) and confidence levels, which are then aggregated into a daily confidence-weighted average.
#
# #### 3.2. Missing Data Imputation
# Recognizing that sentiment signals decay over time, the authors propose a **decay-based imputation function with random noise**:
# $x_t = Be^{-\lambda t} + \epsilon_t$.
# Here, $B$ is the last available sentiment score, and $\lambda$ represents the decay rate (set to 0.23 based on half-life calibration). Including a noise term ($\epsilon_t$) derived from an **AR(1) process** ensures the imputed data maintains the stochastic properties of the original series.
#
# #### 3.3. Calibration Logic
# The authors utilize **quantile discretization** to transform continuous sentiment scores into three discrete states. Calibration plots of conditional entropy versus lag length reveal that **lag 1** is the optimal choice for sentiment prediction, as increasing lags leads to a rapid drop in entropy due to sample size constraints in the rolling windows.
#
# ### 4. Empirical Analysis: Dynamic Network Evolution
#
# #### 4.1. The Divergence of News and Social Media
# The research identifies a striking difference in the temporal evolution of news and social media networks.
# *   **News Spike (End of 2021 - Early 2022):** News sentiment network density surged during this period. The authors attribute this to the "tech hype" following COVID-19 and the subsequent market focus on semiconductors and generative AI. News agencies often report on competitors and collaborators simultaneously, creating dense information clusters.
# *   **Social Media Decay (2023 onwards):** Social media density began to decline significantly following Elon Musk's acquisition and rebranding of Twitter. The authors suggest that changes in content moderation and a reduction in active contributor usage (noted as a 60% break among U.S. users) altered the platform's role as a sentiment transmitter.
#
# #### 4.2. Structural Similarity Analysis
# Using the **Jaccard Similarity Index**, the authors quantify the overlap between news and social media network edges. The resulting scores are consistently low, providing rigorous evidence that news and social media represent fundamentally different "root information sources" with distinct transmission mechanisms.
#
# ### 5. Regime-Specific Analysis and Information Diffusion
#
# The authors segment the study period into three regimes: (1) Pre-August 2021, (2) August 2021 to October 2022, and (3) Post-October 2022.
#
# #### 5.1. News Sentiment Regimes
# *   **Regime 2 (The Spike):** Characterized by a "broadcast" pattern where information diffuses rapidly and evenly across nodes. This regime showed the highest weighted in/out-degree spreads.
# *   **Information Hubs:** **IBM** consistently acts as a net transmitter of news sentiment. **Broadcom (AVGO)** and **Salesforce (CRM)** emerged as critical bridges for information flow, particularly during the semiconductor and AI booms.
#
# #### 5.2. Social Media Sentiment Regimes
# *   **Regime Characteristics:** Social media networks remained more stable but "chaotic" compared to news. The average steps on an information path increased in Regime 3, indicating a slower ripple effect in the system.
# *   **Dominant Hubs:** **Tesla (TSLA)** is identified as the "king of social media influence," reflecting its role as a focal point for speculative and emotion-driven discourse. Other "Magnificent Seven" stocks (AAPL, MSFT, NVDA) also maintain high visibility as sentiment absorbers.
#
# #### 5.3. Maximum Spanning Arborescence (MSA) Findings
# The MSA analysis reveals that news information typically travels through a "broadcast" structure with fewer steps (average of 6 in Regime 2), whereas social media involves long chains with more steps, supporting a sequential ripple effect. Financial service providers like **Fiserv (FI)** and **Fidelity (FIS)** often act as receivers in these networks, as their operations are highly sensitive to market speculation surrounding their tech clients.
#
#
# ### 6. Critical Synthesis and Econometric Implications
#
# The paper concludes that while news and social media both influence investor sentiment, they follow unique spillover topologies. **News sentiment** is largely driven by authoritative, selective reporting on macroeconomic factors and industry-level cooperation/competition, leading to faster diffusion. **Social media sentiment** is characterized by disagreement, speculation, and emotion-driven collective influence, which often "cancels out" extreme attitudes, resulting in a less connected network.
#
# #### 6.1. Academic and Regulatory Contributions
# From an econometric perspective, the study demonstrates the superiority of **Transfer Entropy** over linear models for quantifying financial contagion. For regulators, the identified "information hub" companies and "maximum information flow paths" offer specific targets for monitoring to prevent systemic crashes. For investors, understanding these lead-lag relationships provides an additional layer of data for asset pricing and risk management.
#
# #### 6.2. Future Research Directions
# The authors acknowledge limitations, including high computational costs and the exclusion of sentiment "polarity" (positive vs. negative) in the spillover analysis. Future research may focus on cross-industry spillovers, lead-lag relationships between media types, and the integration of these networks into real-time market risk prediction indices.
#
# In summary, the paper provides a rigorous, data-driven methodology for mapping the unseen pathways of sentiment in the digital age, proving that news and social media indeed "tell different stories" through their respective network structures.

# %% [markdown]
# # Import Essential Modules

# %%
#!/usr/bin/env python3
# ==============================================================================#
#
#  Do News and Social Media Tell the Same Story? Constructing and Comparing
#  Sentiment Spillover Networks
#
#  This module provides a complete, production-grade implementation of the
#  analytical framework presented in "Do News and Social Media Tell the Same
#  Story? Constructing and Comparing Sentiment Spillover Networks" by Fan Wu,
#  Anqi Liu, Jing Chen, and Yuhua Li (2026). It delivers a computationally
#  tractable system for quantitative analysis of high-frequency sentiment
#  contagion, enabling robust, state-dependent risk assessment and topological
#  mapping of information flow across the technology sector.
#
#  Core Methodological Components:
#  • Confidence-weighted aggregation of high-frequency unstructured media data
#  • Stochastic imputation via exponential decay and AR(1) Gaussian noise
#  • Quantile discretization for non-parametric symbolic state encoding
#  • Effective Transfer Entropy (TE) estimation for directed information flow
#  • Markov bootstrap simulation for rigorous null hypothesis significance testing
#  • Dynamic rolling-window network construction and regime shift detection
#  • Recursive centrality (PageRank) for systemic "Information Hub" identification
#  • Maximum Spanning Arborescence (MSA) optimization for dominant path extraction
#  • Jaccard Similarity Index for set-theoretic comparative topology
#  • Matrix power series summation for stability and convergence analysis
#
#  Technical Implementation Features:
#  • O(1) deterministic topological indexing via Single Source of Truth mapping
#  • Multi-core parallelization for intensive pairwise entropy estimation
#  • Memory-efficient sliding window views for empirical probability counting
#  • Robust linear algebra solvers for spectral radius and matrix inversion
#  • Cryptographic hashing for perfect stochastic reproducibility across workers
#  • Comprehensive diagnostic tools for qualitative invariant verification
#
#  Paper Reference:
#  Wu, F., Liu, A., Chen, J., & Li, Y. (2026). Do News and Social Media Tell
#  the Same Story? Constructing and Comparing Sentiment Spillover Networks.
#  arXiv preprint arXiv:2604.26811v2. https://arxiv.org/abs/2604.26811
#
#  Author: CS Chirinda
#  License: MIT
#  Version: 1.0.0
#
# ==============================================================================#

# Standard Library Imports
import os
import copy
import json
import hashlib
import logging
import itertools
from collections import Counter
from pathlib import Path
from dataclasses import dataclass
from typing import Dict, List, Tuple, Set, Optional, Any, Union, Callable, NamedTuple

# Third-Party Core Scientific Libraries
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
import pandas as pd
import networkx as nx

# Third-Party Statistical and Econometric Libraries
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf, pacf, adfuller

# Third-Party Parallel Computing Libraries
from joblib import Parallel, delayed

# Third-Party Visualization Libraries
import matplotlib

# Enforce headless backend for thread-safe, non-GUI server environments
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

# Third-Party Financial Data Libraries
import pandas_market_calendars as mcal


# Configure module-level logger for clinical, professional output
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
if not logger.handlers:
    handler = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# %% [markdown]
# # Implementation

# %% [markdown]
# # Draft 1
#
# ## **Discussion of the Inputs, Processes and Outputs (IPO) of Key Callables in the Pipeline**
#
# Below is the clinical, step-by-step explication of the **31 final orchestrator callables** that govern the Directed Acyclic Graph (DAG) of this implementation-grade pipeline. Each entry defines the data structures, transformation logic, and exact mathematical equations from the LaTeX context that the callable operationalizes.
#
#
#
# ### Phase 1: Parameter Validation and Configuration Consistency
#
# **1. `orchestrate_universe_validation` (Task 1)**
# *   **Inputs:** `tech_universe_raw` (Dict), `study_configuration` (Dict).
# *   **Processes:** Validates the cardinality and uniqueness of the vertex set, verifies alias injectivity, and cross-validates the configuration metadata.
# *   **Outputs:** `UniverseValidationReport` (Dataclass containing `canonical_tickers`, `inverted_alias_map`, and the $O(1)$ `ticker_to_position` map).
# *   **Data Transformation:** Transforms raw string lists into an immutable, mathematically guaranteed $O(1)$ lookup dictionary that serves as the Single Source of Truth for all downstream matrix indexing.
# *   **LaTeX Context & Equations:** Implements the foundational graph definition from Section 2.1: *"The directed network is defined as a pair of sets $G = (V, A)$, where $V = \{v_1, v_2, \dots, v_n\}, n \in \mathbb{N}$, is the vertex set"*. It mathematically enforces $n=34$.
#
# **2. `orchestrate_config_validation` (Task 2)**
# *   **Inputs:** `study_configuration` (Dict).
# *   **Processes:** Verifies high-impact conventions, locks RNG determinism, and validates temporal parameters.
# *   **Outputs:** `ConfigValidationReport` (Dataclass).
# *   **Data Transformation:** Parses raw configuration integers to mathematically derive and lock the total number of rolling windows ($W$).
# *   **LaTeX Context & Equations:** Operationalizes the temporal parameters from Section 5.1: *"We set the rolling window length as 200 days... with a step size of 10 days."* It computes $W = \lfloor(T-L)/s\rfloor + 1$.
#
# **3. `orchestrate_sector_mapping_validation` (Task 3)**
# *   **Inputs:** `df_sector_mapping` (DataFrame), `canonical_tickers` (List).
# *   **Processes:** Validates GICS domain codes and enforces completeness.
# *   **Outputs:** `SectorMappingReport` (Dataclass).
# *   **Data Transformation:** Reindexes the raw sector DataFrame to perfectly align with the canonical ticker sequence, transforming it into a deterministic metadata lookup table.
# *   **LaTeX Context & Equations:** Implements the interpretive metadata required for **Appendix B: Table 6**, ensuring companies can be grouped by sector (e.g., Semiconductors, Financial Services) during centrality analysis.
#
# <br>
#
# ### Phase 2: Data Ingestion, Cleansing, and Alignment
#
# **4. `orchestrate_news_sentiment_ingestion` (Task 4)**
# *   **Inputs:** `df_news_sentiment_raw` (DataFrame).
# *   **Processes:** Validates schema, data types, sentiment bounds, missingness semantics, and firm-day uniqueness.
# *   **Outputs:** `NewsSentimentIngestionReport` (Dataclass).
# *   **Data Transformation:** Coerces raw strings and floats into strict pandas types (e.g., `Int64` for nullable counts) and filters out Cartesian duplicates.
# *   **LaTeX Context & Equations:** Validates the output of the aggregation logic defined in Section 4.1, **Equation 15**: $Sentiment_{i,t} = \frac{\sum_{k \in K(i,T)} S_i^k C_i^k}{K_{i,T}}, \quad T \in (t-1, t]$. It enforces the bounds $[-1, 1]$.
#
# **5. `orchestrate_social_sentiment_ingestion` (Task 5)**
# *   **Inputs:** `df_social_sentiment_raw` (DataFrame).
# *   **Processes:** Identical to Task 4, applied to the Social Media channel.
# *   **Outputs:** `SocialSentimentIngestionReport` (Dataclass).
# *   **Data Transformation:** Same as Task 4.
# *   **LaTeX Context & Equations:** Validates the social media equivalent of **Equation 15**, ensuring structural parity between the two distinct media sources.
#
# **6. `orchestrate_data_cleansing_and_alignment` (Task 6)**
# *   **Inputs:** Validated News/Social DataFrames, `inverted_alias_map`, `canonical_tickers`, `study_configuration`, `fallback_calendar` (DatetimeIndex).
# *   **Processes:** Normalizes aliases, constructs the master calendar, and aligns data to a Cartesian grid.
# *   **Outputs:** `AlignedSentimentReport` (Dataclass).
# *   **Data Transformation:** Transforms asynchronous, irregularly spaced time series into a mathematically complete $T \times n$ grid, exposing missing firm-days as explicit `NaN` rows.
# *   **LaTeX Context & Equations:** Enforces the temporal invariant stated in Section 4.1: *"The sentiment time series spans from September 30, 2019 to October 17, 2024, totalling 1319 sentiment data points."* It guarantees $T=1319$.
#
# **7. `orchestrate_matrix_pivoting` (Task 7)**
# *   **Inputs:** Aligned DataFrames, master calendar, `ticker_to_position` (Dict).
# *   **Processes:** Pivots long-form data into wide-form matrices and validates isomorphism.
# *   **Outputs:** `PivotedSentimentMatrices` (Dataclass).
# *   **Data Transformation:** Reshapes the 1D sentiment vectors into 2D matrices $\mathbf{X} \in \mathbb{R}^{T \times n}$, strictly ordering the columns using the $O(1)$ position map.
# *   **LaTeX Context & Equations:** Prepares the data structure required for Section 3: *"Let $X_i = \{x_{i,t}, t = 1, 2, \dots, T, i = 1, 2, \dots, n\}$, denote the news (or social media) sentiment time series"*.
#
# **8. `orchestrate_missingness_profiling` (Task 8)**
# *   **Inputs:** Aligned data report, pivoted matrices report.
# *   **Processes:** Computes exact missing rates and audits missingness semantics.
# *   **Outputs:** `MissingnessProfileReport` (Dataclass).
# *   **Data Transformation:** Aggregates `NaN` counts across the temporal dimension to produce a 1D array of missingness proportions per ticker.
# *   **LaTeX Context & Equations:** Validates the empirical observation in Section 4.2: *"a varying proportion of missing data, ranging from 0.758% to 24.56% across different companies."*
#
# <br>
#
# ### Phase 3: Stochastic Imputation and Diagnostics
#
# **9. `orchestrate_ar1_diagnostics` (Task 9)**
# *   **Inputs:** Pivoted matrices report.
# *   **Processes:** Computes ACF/PACF on contiguous segments and evaluates the AR(1) signature.
# *   **Outputs:** `AR1DiagnosticReport` (Dataclass).
# *   **Data Transformation:** Transforms time series into autocovariance arrays to quantitatively verify the "tails off" heuristic.
# *   **LaTeX Context & Equations:** Operationalizes the justification in Appendix A: *"autocorrelation (ACF) and partial autocorrelation function (PACF) indicate that the sentiment series show statistically significant dependence at lag one... consistent with the autoregressive process of order one AR(1)."*
#
# **10. `orchestrate_ar1_variance_estimation` (Task 10)**
# *   **Inputs:** Pivoted matrices report.
# *   **Processes:** Extracts strictly adjacent pairs, fits OLS models, and computes innovation variance.
# *   **Outputs:** `AR1EstimationReport` (Dataclass).
# *   **Data Transformation:** Regresses $x_t$ on $x_{t-1}$ to extract the scalar parameters $o$, $\psi_1$, and $\sigma^2$ for each ticker.
# *   **LaTeX Context & Equations:** Implements Appendix A, **Equation 17**: $x_t = o + \psi_1 x_{t-1} + \epsilon_t$, and **Equation 18**: $\text{Var}(x_t) = \frac{\sigma^2}{1 - \psi_1^2}$.
#
# **11. `orchestrate_stochastic_imputation` (Task 11)**
# *   **Inputs:** Pivoted matrices, AR(1) estimation report, `study_configuration`.
# *   **Processes:** Computes decay components ($B, \Delta_t$) and applies stochastic imputation.
# *   **Outputs:** `ImputedSentimentReport` (Dataclass).
# *   **Data Transformation:** Replaces `NaN` values in the $T \times n$ matrices with deterministically generated floats, preserving observed values.
# *   **LaTeX Context & Equations:** Implements Section 4.2, **Equation 16**: $x_t = B e^{-\lambda t} + \epsilon_t, \quad \epsilon_t \sim \mathcal{N}(0, \sigma^2)$.
#
# **12. `orchestrate_post_imputation_diagnostics` (Task 12)**
# *   **Inputs:** Imputed data report.
# *   **Processes:** Executes ADF and Shapiro-Wilk tests; validates $[-1, 1]$ bounds.
# *   **Outputs:** `PostImputationDiagnosticReport` (Dataclass).
# *   **Data Transformation:** Reduces the $T \times n$ imputed matrices into a tidy DataFrame of test statistics and p-values.
# *   **LaTeX Context & Equations:** Validates the claims in Section 4.3: *"The Augmented Dickey-Fuller (ADF) tests... show that all the sentiment data are stationary. The Shapiro-Wilk tests... reject the null hypothesis of normal distribution"*.
#
# <br>
#
# ### Phase 4: Information Theory Preparation
#
# **13. `orchestrate_quantile_discretization` (Task 13)**
# *   **Inputs:** Imputed data report, `study_configuration`.
# *   **Processes:** Computes windowed quantiles, encodes symbolic states, and validates support.
# *   **Outputs:** `SymbolicEncodingReport` (Dataclass).
# *   **Data Transformation:** Maps continuous floats $\in [-1, 1]$ into a discrete integer alphabet $\{1, 2, 3\}$ using rolling empirical tertiles.
# *   **LaTeX Context & Equations:** Implements Section 2.2, **Equation 1**:
#     $Z = z_t = \begin{cases} 1 & \text{for } z_t \le q_1 \\ 2 & \text{for } q_1 < z_t < q_2 \\ 3 & \text{for } z_t \ge q_2 \end{cases}$
#
# **14. `orchestrate_lag_calibration` (Task 14)**
# *   **Inputs:** `study_configuration`.
# *   **Processes:** Simulates AR(1) processes, computes conditional entropy decay, and locks TE lags.
# *   **Outputs:** `TECalibrationReport` (Dataclass).
# *   **Data Transformation:** Generates synthetic data to produce the calibration matrix (Lags $\times$ Sample Sizes) mapping to entropy bits.
# *   **LaTeX Context & Equations:** Implements Section 2.2, **Equation 3**: $H(z_{t+1}|z_t^{(k)}) = H(z_{t+1}, z_t^{(k)}) - H(z_t^{(k)})$, justifying the conclusion that *"only lag 1 can be chosen to be the optimal past information"*.
#
# **15. `orchestrate_window_enumeration` (Task 15)**
# *   **Inputs:** Aligned data report, `study_configuration`.
# *   **Processes:** Generates window metadata, validates total count, and locks regime assignment dates.
# *   **Outputs:** `WindowMetadataReport` (Dataclass).
# *   **Data Transformation:** Maps 112 integer Window IDs to exact 0-based array slice indices and calendar timestamps.
# *   **LaTeX Context & Equations:** Operationalizes Section 5.1: *"We set the rolling window length as 200 days... with a step size of 10 days."*
#
# <br>
#
# ### Phase 5: Transfer Entropy and Network Assembly
#
# **16. `orchestrate_transfer_entropy_estimation` (Task 16)**
# *   **Inputs:** Encoding report, `study_configuration`, `n_jobs`.
# *   **Processes:** Computes raw and normalized TE for all $n(n-1)$ pairs across all windows in parallel.
# *   **Outputs:** `TransferEntropyReport` (Dataclass).
# *   **Data Transformation:** Transforms 1D symbolic arrays into scalar information-flow weights (bits), normalized to $[0, 1]$.
# *   **LaTeX Context & Equations:** Implements Section 2.3, **Equation 4**: $T_{Y \to Z}^{k,l} = H(z_{t+1}|z_t^{(k)}) - H(z_{t+1}|z_t^{(k)}, y_t^{(l)})$, and **Equation 5**: $\hat{T}_{Y \to Z} = \frac{T_{Y \to Z}}{H(z_{t+1}|z_t)}$.
#
# **17. `orchestrate_adjacency_assembly` (Task 17)**
# *   **Inputs:** TE report, `ticker_to_position`.
# *   **Processes:** Assembles $n \times n$ matrices and enforces the zero-diagonal policy.
# *   **Outputs:** `AdjacencyMatrixReport` (Dataclass).
# *   **Data Transformation:** Maps pairwise scalar dictionaries into dense 2D numpy arrays using the $O(1)$ position map.
# *   **LaTeX Context & Equations:** Implements Section 3.1, **Equation 12**:
#     $\mathbf{W}_w = \begin{bmatrix} 0 & \hat{T}_{12,w} & \cdots & \hat{T}_{1n,w} \\ \vdots & \vdots & \ddots & \vdots \\ \hat{T}_{n1,w} & \cdots & \cdots & 0 \end{bmatrix}$
#
# **18. `orchestrate_markov_bootstrap` (Task 18)**
# *   **Inputs:** Encoding report, `study_configuration`, `n_jobs`.
# *   **Processes:** Estimates empirical Markov parameters, simulates $N_{boot}$ series, and computes null TE distributions.
# *   **Outputs:** `MarkovBootstrapReport` (Dataclass).
# *   **Data Transformation:** Transforms empirical transition matrices into $N_{boot}$ synthetic time series, yielding a 1D array of null TE values for every edge.
# *   **LaTeX Context & Equations:** Operationalizes Section 3.1: *"Markov bootstrap preserves the dependency within $x_i$, but breaks any potential dependencies between $x_i$ and $x_j$."*
#
# **19. `orchestrate_bootstrap_significance_filtering` (Task 19)**
# *   **Inputs:** TE report, Bootstrap report, Adjacency report, `study_configuration`, `ticker_to_position`.
# *   **Processes:** Computes p-values, evaluates significance threshold, and builds filtered matrices.
# *   **Outputs:** `FilteredAdjacencyReport` (Dataclass).
# *   **Data Transformation:** Applies a boolean mask to the dense adjacency matrices, zeroing out non-significant edges to create sparse topologies.
# *   **LaTeX Context & Equations:** Implements Section 3.1, **Equation 7**: $\text{p-value} = \frac{M}{N_{boot}}$. *"If p-value < $\alpha$, then we reject the null hypothesis"*.
#
# <br>
#
# ### Phase 6: Topological Metrics and Centrality
#
# **20. `orchestrate_network_density_computation` (Task 20)**
# *   **Inputs:** Adjacency reports, window metadata, `study_configuration`.
# *   **Processes:** Computes density and edge counts; validates qualitative spikes.
# *   **Outputs:** `NetworkDensityReport` (Dataclass).
# *   **Data Transformation:** Reduces $34 \times 34$ matrices into scalar density values over time.
# *   **LaTeX Context & Equations:** Implements Section 3.2.1, **Equation 8**: $D = \frac{\sum_{i=1}^n \sum_{j=1}^n \hat{T}_{ij}}{n(n-1)}$.
#
# **21. `orchestrate_node_influence_computation` (Task 21)**
# *   **Inputs:** Adjacency reports, window metadata, `study_configuration`, `ticker_to_position`.
# *   **Processes:** Computes in/out degrees and generates heatmap panels.
# *   **Outputs:** `NodeInfluenceReport` (Dataclass).
# *   **Data Transformation:** Collapses matrix rows/columns into 1D degree arrays, then pivots them into $n \times W$ panels for visualization.
# *   **LaTeX Context & Equations:** Implements Section 3.2.2, **Equation 9**: $d_{v_i}^{in} = \sum_{j=1}^n \hat{T}_{ji}$, and **Equation 10**: $d_{v_i}^{out} = \sum_{j=1}^n \hat{T}_{ij}$.
#
# **22. `orchestrate_pagerank_and_rankings` (Task 22)**
# *   **Inputs:** Filtered report, influence report, `study_configuration`, `ticker_to_position`.
# *   **Processes:** Computes PageRank via power iteration and extracts top-5 rankings.
# *   **Outputs:** `PageRankAndRankingReport` (Dataclass).
# *   **Data Transformation:** Transforms the adjacency matrix into a row-stochastic transition matrix, iteratively solving for the dominant eigenvector.
# *   **LaTeX Context & Equations:** Implements Section 3.2.3, **Equation 11**: $PR(v_i) = \frac{1-f}{n} + f \sum_{v_j \in V_m} \frac{\hat{T}_{ji}}{d_{v_j}^{out}} PR(v_j)$.
#
# <br>
#
# ### Phase 7: Regime Analysis and Optimization
#
# **23. `orchestrate_regime_segmentation` (Task 23)**
# *   **Inputs:** Window metadata, `study_configuration`.
# *   **Processes:** Locks boundaries, assigns regimes, and partitions window sets.
# *   **Outputs:** `RegimeSegmentationReport` (Dataclass).
# *   **Data Transformation:** Maps continuous datetime indices into discrete categorical sets $\mathcal{W}_r \in \{1, 2, 3\}$.
# *   **LaTeX Context & Equations:** Operationalizes Section 5.2: *"The three regime periods are before 2021-08-02, 2021-08-02 to 2022-10-03 and after 2022-10-03."*
#
# **24. `orchestrate_regime_network_construction` (Task 24)**
# *   **Inputs:** Filtered report, segmentation report, `study_configuration`.
# *   **Processes:** Aggregates matrices per regime and computes regime densities.
# *   **Outputs:** `RegimeNetworkReport` (Dataclass).
# *   **Data Transformation:** Collapses the temporal dimension (112 windows) into 3 static regime matrices via elementwise averaging.
# *   **LaTeX Context & Equations:** Prepares the aggregated topology required for the regime-specific visualizations in Figures 11 and 15.
#
# **25. `orchestrate_msa_extraction` (Task 25)**
# *   **Inputs:** Regime network report, `study_configuration`, `ticker_to_position`.
# *   **Processes:** Selects roots, applies Edmonds algorithm, and computes path statistics.
# *   **Outputs:** `MSAReport` (Dataclass).
# *   **Data Transformation:** Transforms dense cyclic graphs into directed acyclic trees (arborescences), extracting path lengths and weights.
# *   **LaTeX Context & Equations:** Implements Section 3.2.4: $\max \sum_{(v_i, v_j) \in \mathbb{T}} w(v_i, v_j)$ subject to $\mathbb{T}$ being an arborescence rooted at $r^* = \arg\max_i d_{v_i}^{\text{out}}$.
#
# <br>
#
# ### Phase 8: Comparative Topology and Stability
#
# **26. `orchestrate_jaccard_similarity_comparison` (Task 26)**
# *   **Inputs:** Filtered report, window metadata.
# *   **Processes:** Extracts edge sets, computes Jaccard index, and validates low similarity.
# *   **Outputs:** `JaccardSimilarityReport` (Dataclass).
# *   **Data Transformation:** Converts numerical matrices into binary sets to compute intersection over union.
# *   **LaTeX Context & Equations:** Implements Section 3.3.1, **Equation 13**: $J(G_1, G_2) = \frac{|A_1 \cap A_2|}{|A_1 \cup A_2|}$.
#
# **27. `orchestrate_stability_and_convergence` (Task 27)**
# *   **Inputs:** Filtered report, `study_configuration`.
# *   **Processes:** Evaluates spectral radius and computes power series summation.
# *   **Outputs:** `StabilityAndConvergenceReport` (Dataclass).
# *   **Data Transformation:** Computes matrix eigenvalues and performs infinite series summation via matrix inversion $(I-W)^{-1}W$.
# *   **LaTeX Context & Equations:** Implements Section 3.3.2, **Equation 14**: $\sum_{\omega=1}^{\infty} \mathbf{W}_w^\omega = \mathbf{W}_w + \mathbf{W}_w^2 + \mathbf{W}_w^3 + \dots$ subject to $\max |\lambda_k| < 1$.
#
# <br>
#
# ### Top-Level Execution and Deployment
#
# **28. `orchestrate_sentinel_system_pipeline` (Task 28)**
# *   **Inputs:** 5 raw data structures + `fallback_calendar`.
# *   **Processes:** Enforces the strict DAG, routing $O(1)$ maps and calendars to all 27 sub-orchestrators.
# *   **Outputs:** `SentinelSystemReport` (Dataclass).
# *   **Data Transformation:** Synthesizes all intermediate artifacts into a single, immutable, hashed master record.
# *   **LaTeX Context & Equations:** Represents the programmatic execution of the entire methodological pipeline from Section 2 to Section 5.
#
# **29. `orchestrate_paper_deliverables` (Task 29)**
# *   **Inputs:** `SentinelSystemReport`.
# *   **Processes:** Generates tables, figures, and diagnostic logs.
# *   **Outputs:** `PaperDeliverablesReport` (Dataclass).
# *   **Data Transformation:** Formats raw numerical arrays into publication-ready pandas DataFrames and matplotlib Figure objects.
# *   **LaTeX Context & Equations:** Synthesizes outputs for Tables 1-5 and Figures 1-18.
#
# **30. `run_sentinel_system_pipeline` (Task 29-plus, API)**
# *   **Inputs:** 5 raw data structures + `fallback_calendar`.
# *   **Processes:** Wraps Task 28 and Task 29 in a fail-safe `try-except` block.
# *   **Outputs:** `Dict[str, Any]` containing the reports and fidelity flags.
# *   **Data Transformation:** Provides a clean, dictionary-based API for external scripts.
# *   **LaTeX Context & Equations:** The programmatic entry point for the "Sentinel" system.
#
# **31. `deploy_sentinel_system` (Task 29-plus, Deployment)**
# *   **Inputs:** 5 raw data structures, config, output directory.
# *   **Processes:** Generates exact NYSE calendar, runs pipeline, saves artifacts to disk.
# *   **Outputs:** None (Side-effect: saves CSVs and PDFs).
# *   **Data Transformation:** Transforms in-memory Python objects into physical files.
# *   **LaTeX Context & Equations:** Operationalizes the system for real-world deployment, mathematically guaranteeing the $T=1319$ invariant via the `pandas_market_calendars` library.
#
# <br><br>
#
# ## **Usage Example**
#
# Here is a granular, step-by-step guide to executing the end-to-end pipeline for the **"Do News and Social Media Tell the Same Story? Constructing and Comparing Sentiment Spillover Networks"** study. This example demonstrates how to synthetically generate the required high-frequency sentiment data, load the study configuration from a YAML file, and execute the full research pipeline using the `deploy_sentinel_system` orchestrator.
#
# *Note: It is assumed that all the callables that are provided in this notebook (e.g., `run_sentinel_system_pipeline`, `deploy_sentinel_system`, and their dependencies) are available in the current working environment (e.g., a single Jupyter notebook), and that the `config.yaml` file is saved in the working directory.*
#
# <br>
#
# ### **Step 1: Synthetic Data Generation (`tech_universe_raw`, `df_sector_mapping`, `df_news_sentiment_raw`, `df_social_sentiment_raw`)**
#
# The first requirement is a high-fidelity synthetic representation of the foundational data structures. These datasets must adhere strictly to the schemas defined in the study, including exact temporal dimensions ($T=1319$), canonical ticker ordering, and specific missingness semantics.
#
# **Methodology:**
# 1.  **Universe Definition:** We define the `tech_universe_raw` dictionary exactly as prescribed, establishing the 34 canonical nodes.
# 2.  **Sector Mapping:** We construct `df_sector_mapping` using the provided GICS classifications, utilizing the `Faker` library to generate plausible corporate names for realism.
# 3.  **Date Generation:** We generate a sequence of exactly 1,319 business days to simulate the master trading calendar, ensuring the temporal invariant is mathematically guaranteed.
# 4.  **Sentiment Simulation:** We simulate continuous sentiment scores $S \in [-1, 1]$ and discrete item counts using uniform and Poisson distributions, respectively.
# 5.  **Missingness Injection:** We randomly inject missing data (setting counts to 0 and scores to `NaN`) at a rate of ~15% to mimic the empirical sparsity of Bloomberg feeds, strictly enforcing the logical implication $K=0 \implies S=\text{NaN}$.
#
# ```python
# import pandas as pd
# import numpy as np
# import yaml
# from faker import Faker
# from typing import Dict, Any, Tuple
#
# # Initialize Faker and Numpy RNG for perfect reproducibility
# fake = Faker()
# Faker.seed(123456)
# np.random.seed(123456)
#
# # ------------------------------------------------------------------------------
# # 1. Define the Technology Company Universe
# # ------------------------------------------------------------------------------
# tech_universe_raw: Dict[str, Any] = {
#     "Tickers": [
#         "AAPL", "MSFT", "NVDA", "GOOGL", "TSLA", "META", "AMZN",
#         "V", "MA", "ADBE", "PYPL", "CRM", "CSCO", "INTC",
#         "AVGO", "ORCL", "ACN", "AMD", "TXN", "QCOM", "INTU",
#         "NOW", "IBM", "SPGI", "AMAT", "ADP", "ADI", "LRCX",
#         "SQ", "MU", "MCO", "FI", "FIS", "MCHP"
#     ],
#     "Ticker_Aliases": {
#         "SQ": ["XYZ"]
#     },
#     "Adjacency_Index_Order": "Tickers"
# }
#
# # ------------------------------------------------------------------------------
# # 2. Generate Sector Mapping DataFrame
# # ------------------------------------------------------------------------------
# def generate_sector_mapping(universe: Dict[str, Any]) -> pd.DataFrame:
#     """
#     Generates the GICS sector mapping DataFrame for the 34 canonical tickers.
#     """
#     sector_map_complete = {
#         "AAPL": "TH", "MSFT": "SW", "NVDA": "SC", "GOOGL": "CS", "TSLA": "CC",
#         "META": "CS", "AMZN": "CC", "V": "FS", "MA": "FS", "ADBE": "SW",
#         "PYPL": "FS", "CRM": "SW", "CSCO": "CE", "INTC": "SC", "AVGO": "SC",
#         "ORCL": "SW", "ACN": "IT", "AMD": "SC", "TXN": "SC", "QCOM": "SC",
#         "INTU": "SW", "NOW": "SW", "IBM": "IT", "SPGI": "CM", "AMAT": "SC",
#         "ADP": "PS", "ADI": "SC", "LRCX": "SC", "SQ": "FS", "MU": "SC",
#         "MCO": "CM", "FI": "FS", "FIS": "FS", "MCHP": "SC"
#     }
#
#     records = []
#     for ticker in universe["Tickers"]:
#         records.append({
#             "Ticker": ticker,
#             # Generate a plausible corporate name using Faker
#             "Company_Name": f"{fake.company()} Inc.",
#             "GICS_Classification": sector_map_complete[ticker]
#         })
#
#     return pd.DataFrame(records)
#
# df_sector_mapping = generate_sector_mapping(tech_universe_raw)
#
# # ------------------------------------------------------------------------------
# # 3. Generate Synthetic Sentiment Panels (News and Social)
# # ------------------------------------------------------------------------------
# def generate_synthetic_sentiment_panels(
#     universe: Dict[str, Any],
#     start_date: str = "2019-09-30",
#     n_days: int = 1319
# ) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DatetimeIndex]:
#     """
#     Generates high-fidelity synthetic sentiment panels for News and Social Media.
#
#     Processes:
#         1. Generates a strict master calendar of length T=1319.
#         2. Creates a Cartesian product of Dates x Tickers.
#         3. Simulates continuous sentiment scores and discrete item counts.
#         4. Injects ~15% missingness, enforcing K=0 => Score=NaN.
#         5. Casts columns to strict pandas types (datetime64[ns], float64, Int64).
#     """
#     tickers = universe["Tickers"]
#
#     # Generate exactly 1319 business days to mathematically guarantee the temporal invariant
#     master_calendar = pd.bdate_range(start=start_date, periods=n_days)
#
#     # Create the Cartesian grid
#     idx = pd.MultiIndex.from_product([master_calendar, tickers], names=["Date", "Ticker"])
#
#     def build_panel(count_col_name: str) -> pd.DataFrame:
#         df = pd.DataFrame(index=idx).reset_index()
#
#         # Simulate continuous sentiment scores in [-1, 1]
#         df["Sentiment_Score"] = np.random.uniform(-1.0, 1.0, size=len(df))
#
#         # Simulate discrete item volumes using a Poisson distribution
#         df[count_col_name] = np.random.poisson(lam=50, size=len(df))
#
#         # Inject missingness: ~15% of firm-days have no media coverage
#         missing_mask = np.random.rand(len(df)) < 0.15
#         df.loc[missing_mask, "Sentiment_Score"] = np.nan
#         df.loc[missing_mask, count_col_name] = 0
#
#         # Enforce strict schema types
#         df["Date"] = df["Date"].astype("datetime64[ns]")
#         df["Ticker"] = df["Ticker"].astype(str)
#         df["Sentiment_Score"] = df["Sentiment_Score"].astype("float64")
#         # Use pandas nullable integer type to safely handle counts
#         df[count_col_name] = df[count_col_name].astype("Int64")
#
#         return df
#
#     df_news = build_panel("Story_Count_K")
#     df_social = build_panel("Post_Count_K")
#
#     return df_news, df_social, master_calendar
#
# df_news_sentiment_raw, df_social_sentiment_raw, fallback_calendar = generate_synthetic_sentiment_panels(tech_universe_raw)
#
# print("Synthetic Data Generation Complete.")
# print(f"News Panel Shape: {df_news_sentiment_raw.shape}")
# print(f"Social Panel Shape: {df_social_sentiment_raw.shape}")
# ```
#
# <br>
#
# ### **Step 2: Loading the Configuration (`config.yaml`)**
#
# The study relies on a deterministic configuration file (`config.yaml`) that defines all hyperparameters, discretization thresholds, and topological metrics. We assume this file has been saved in the working directory.
#
# **Methodology:**
# 1.  **File I/O:** Open `config.yaml` in read mode.
# 2.  **Parsing:** Use `yaml.safe_load` to convert the YAML structure into a nested Python dictionary.
# 3.  **Validation:** Catch file existence errors and parsing errors to ensure the pipeline does not proceed with an empty or corrupted state.
#
# ```python
# import yaml
#
# def load_study_configuration(filepath: str = "config.yaml") -> Dict[str, Any]:
#     """
#     Loads the study configuration parameters from a YAML file into a Python dictionary.
#
#     Purpose:
#         To ingest the deterministic hyperparameters, lag calibrations, and
#         significance thresholds defined in the external configuration file. This ensures
#         perfect reproducibility by separating the mathematical engine from its parameters.
#
#     Inputs:
#         filepath (str): The relative or absolute path to the YAML configuration file.
#                         Default is "config.yaml".
#
#     Outputs:
#         Dict[str, Any]: A nested dictionary containing the study configuration.
#
#     Raises:
#         TypeError: If filepath is not a string.
#         FileNotFoundError: If the configuration file does not exist.
#         yaml.YAMLError: If the file contains invalid YAML syntax.
#     """
#     if not isinstance(filepath, str):
#         raise TypeError(f"filepath must be a string, got {type(filepath)}.")
#
#     try:
#         # Open the file stream securely
#         with open(filepath, "r") as file:
#             # Parse the YAML content safely to prevent arbitrary code execution
#             config = yaml.safe_load(file)
#
#         logger.info(f"Successfully loaded configuration from {filepath}")
#         return config
#
#     except FileNotFoundError:
#         logger.error(f"Configuration file {filepath} not found. Pipeline execution blocked.")
#         raise
#     except yaml.YAMLError as e:
#         logger.error(f"Error parsing YAML file {filepath}: {e}")
#         raise
#
# # Load the configuration into memory
# study_config = load_study_configuration("config.yaml")
# ```
#
# <br>
#
# ### **Step 3: Executing the Pipeline (`deploy_sentinel_system`)**
#
# With the raw data structures and configuration dictionary in memory, we invoke the top-level deployment script. This function manages the entire lifecycle: data cleansing, stochastic imputation, quantile discretization, Transfer Entropy estimation, Markov bootstrapping, topological metric extraction, and the generation of paper-grade deliverables.
#
# **Methodology:**
# 1.  **Function Call:** Pass the DataFrames, Dictionaries, and the `fallback_calendar` to `deploy_sentinel_system`.
# 2.  **Execution:** The orchestrator will process the data through the strict Directed Acyclic Graph (DAG), logging its progress at each phase.
# 3.  **Artifact Persistence:** Upon successful completion and qualitative fidelity verification, the script will automatically save the resulting CSV tables and high-resolution PDF figures to the specified output directory.
#
# ```python
# # ==============================================================================
# # Execution of the End-to-End Sentinel System Pipeline
# # ==============================================================================
#
# if __name__ == "__main__":
#     # Ensure we have valid inputs before initiating the deployment
#     if not df_news_sentiment_raw.empty and not df_social_sentiment_raw.empty and study_config:
#
#         print("\nInitiating High-Frequency Sentinel System Deployment...")
#
#         # Define the output directory for the paper-grade deliverables
#         output_dir = "./sentinel_paper_artifacts"
#
#         try:
#             # Execute the deployment script
#             # We pass the fallback_calendar generated in Step 1 to mathematically
#             # guarantee the T=1319 temporal invariant, bypassing potential
#             # anomalies in standard business day generation.
#             deploy_sentinel_system(
#                 tech_universe_raw=tech_universe_raw,
#                 df_sector_mapping=df_sector_mapping,
#                 df_news_sentiment_raw=df_news_sentiment_raw,
#                 df_social_sentiment_raw=df_social_sentiment_raw,
#                 study_configuration=study_config,
#                 output_directory=output_dir
#             )
#
#             print("\n" + "="*80)
#             print(f"DEPLOYMENT COMPLETE. Artifacts saved to: {os.path.abspath(output_dir)}")
#             print("="*80)
#
#             # Verify the existence of the generated artifacts
#             if os.path.exists(output_dir):
#                 files = os.listdir(output_dir)
#                 print(f"\nGenerated Files ({len(files)} total):")
#                 for file in sorted(files):
#                     print(f" - {file}")
#
#         except RuntimeError as e:
#             print(f"\nDeployment failed: {e}")
#             print("Please review the diagnostic logs for upstream methodological deviations.")
#
#     else:
#         print("Error: Missing foundational data structures or configuration. Cannot proceed.")
# ```
#
# <br><br>
#
# ## **Implemented Callables**

# %%
# Task 1 — Validate universe cardinality, canonical ordering, and alias policy coherence

# ======================================================================================
# Task 1: Validate universe cardinality, canonical ordering, and alias policy coherence
# ======================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 1: Confirm vertex set cardinality and uniqueness
# -------------------------------------------------------------------------------------------------------------------------------
def validate_vertex_set_cardinality(tech_universe_raw: Dict[str, Any]) -> Tuple[List[str], Dict[str, int]]:
    """
    Validates the cardinality and uniqueness of the canonical vertex set V without silent mutation.

    This function extracts the canonical tickers and mathematically guarantees that exactly
    34 unique nodes exist. Crucially, it abandons the previous implementation's silent
    string manipulation (stripping/uppercasing). If the input data is malformed, it raises
    a strict ValueError, forcing the user to provide clean data and preventing the masking
    of upstream pipeline defects.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe.

    Returns
    -------
    Tuple[List[str], Dict[str, int]]
        - canonical_tickers: The immutable, ordered list of 34 unique ticker strings.
        - ticker_to_position: A dictionary mapping each ticker to its integer index (0 to 33).

    Raises
    ------
    KeyError
        If the 'Tickers' key is missing from the input dictionary.
    ValueError
        If the cardinality is not exactly 34, if duplicates exist, or if strings are malformed.
    """
    # Verify that the 'Tickers' key exists in the raw universe dictionary
    if "Tickers" not in tech_universe_raw:
        raise KeyError("The key 'Tickers' is missing from tech_universe_raw.")

    # Extract the raw list of tickers
    raw_tickers: List[Any] = tech_universe_raw["Tickers"]

    # Enforce the mathematical constraint: |V| = 34
    if len(raw_tickers) != 34:
        raise ValueError(f"Expected exactly 34 tickers, but found {len(raw_tickers)}.")

    # Enforce absolute uniqueness by comparing list length to set length
    if len(set(raw_tickers)) != 34:
        raise ValueError("Duplicate tickers detected in the universe definition. All 34 tickers must be unique.")

    # Strict Data Engineering Audit: No silent mutation allowed.
    # Iterate through the list and assert that each element is a clean, uppercase string.
    for i, ticker in enumerate(raw_tickers):
        if not isinstance(ticker, str):
            raise ValueError(f"Ticker at index {i} ({ticker}) is not a string.")
        if ticker != ticker.strip():
            raise ValueError(f"Ticker at index {i} ('{ticker}') contains leading/trailing whitespace. "
                             f"Silent normalization is forbidden. Please clean the input data.")
        if ticker != ticker.upper():
            raise ValueError(f"Ticker at index {i} ('{ticker}') is not uppercase. "
                             f"Silent normalization is forbidden. Please clean the input data.")

    # The raw_tickers list is now certified as clean and canonical
    canonical_tickers: List[str] = list(raw_tickers)

    # Construct the O(1) lookup map for downstream matrix population
    ticker_to_position: Dict[str, int] = {ticker: idx for idx, ticker in enumerate(canonical_tickers)}

    logger.info("Successfully validated vertex set cardinality: |V| = 34 unique, clean nodes.")

    return canonical_tickers, ticker_to_position

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 2: Validate ticker alias mapping is injective after inversion
# -------------------------------------------------------------------------------------------------------------------------------
def validate_alias_injectivity(tech_universe_raw: Dict[str, Any], canonical_tickers: List[str]) -> Dict[str, str]:
    """
    Validates and inverts the ticker alias mapping to ensure strict injectivity.

    This function guarantees that every alias maps to exactly one canonical ticker
    and that no alias collides with an existing canonical ticker. This is required
    to prevent ambiguity during firm-day aggregation.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings.

    Returns
    -------
    Dict[str, str]
        An inverted dictionary mapping alias strings to their canonical ticker strings.

    Raises
    ------
    ValueError
        If an alias maps to multiple canonical tickers, or if an alias is identical
        to a canonical ticker.
    """
    # Initialize an empty dictionary to hold the inverted alias-to-canonical mapping
    inverted_alias_map: Dict[str, str] = {}

    # Safely retrieve the alias dictionary, defaulting to an empty dict if unspecified
    raw_aliases: Dict[str, List[str]] = tech_universe_raw.get("Ticker_Aliases", {})

    # Convert the canonical tickers list to a set for O(1) collision lookups
    canonical_set = set(canonical_tickers)

    # Iterate over each canonical ticker and its associated list of aliases
    for canonical, aliases in raw_aliases.items():
        # Normalize the canonical ticker key
        norm_canonical = str(canonical).strip().upper()

        # Verify that the canonical ticker defined in the alias map actually exists in V
        if norm_canonical not in canonical_set:
            # Raise an error if an alias is defined for a ticker not in the universe
            raise ValueError(f"Alias defined for '{norm_canonical}', which is not in the canonical vertex set.")

        # Iterate over each alias provided for the current canonical ticker
        for alias in aliases:
            # Normalize the alias string
            norm_alias = str(alias).strip().upper()

            # Check if the alias is identical to any canonical ticker
            if norm_alias in canonical_set:
                # Raise an error to prevent circular logic or overwriting canonical nodes
                raise ValueError(f"Alias '{norm_alias}' collides with an existing canonical ticker.")

            # Check if the alias has already been mapped to a different canonical ticker
            if norm_alias in inverted_alias_map:
                # Raise an error because injectivity is violated (one alias -> multiple canonicals)
                raise ValueError(f"Injectivity violation: Alias '{norm_alias}' maps to multiple canonical tickers.")

            # Map the normalized alias to its normalized canonical ticker
            inverted_alias_map[norm_alias] = norm_canonical

    # Log the successful validation and inversion of the alias mapping
    logger.info(f"Successfully validated alias injectivity. Generated {len(inverted_alias_map)} alias mappings.")

    # Return the safe, inverted lookup dictionary
    return inverted_alias_map

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Step 3: Cross-validate configuration metadata against universe
# -------------------------------------------------------------------------------------------------------------------------------
def cross_validate_configuration_metadata(
    study_configuration: Dict[str, Any],
    canonical_tickers: List[str]
) -> bool:
    """
    Cross-validates the study configuration metadata against the validated vertex set.

    This function ensures that the configuration dictionary perfectly matches the
    canonical ticker list in both content and exact sequence order. Furthermore, it
    explicitly validates the 'Adjacency_Index_Order' parameter to guarantee that
    downstream matrix dimensions map correctly to the vertex set.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings.

    Returns
    -------
    bool
        True if validation passes.

    Raises
    ------
    KeyError
        If required metadata keys are missing from the configuration.
    ValueError
        If the configuration node count is not 34, if the sequence order mismatches,
        or if the adjacency index order rule is violated.
    """
    # Verify that the 'metadata' key exists in the study configuration
    if "metadata" not in study_configuration:
        raise KeyError("The key 'metadata' is missing from study_configuration.")

    metadata: Dict[str, Any] = study_configuration["metadata"]

    # Verify that the configured node count is exactly 34
    if metadata.get("nodes_total") != 34:
        raise ValueError(f"Configuration nodes_total must be 34, found {metadata.get('nodes_total')}.")

    # Verify that the 'canonical_tickers' key exists
    if "canonical_tickers" not in metadata:
        raise KeyError("The key 'canonical_tickers' is missing from study_configuration['metadata'].")

    # Extract the configuration's ticker list
    config_tickers: List[str] = metadata["canonical_tickers"]

    # Perform a strict sequence equality check (order-sensitive)
    if config_tickers != canonical_tickers:
        raise ValueError("Configuration canonical_tickers sequence does not perfectly match the tech_universe_raw sequence.")

    # Validate the Adjacency_Index_Order rule
    # This is critical to ensure that W[i,j] maps to the correct corporate entities
    if "Adjacency_Index_Order" not in study_configuration:
        raise KeyError("The key 'Adjacency_Index_Order' is missing from study_configuration.")

    adjacency_rule = study_configuration["Adjacency_Index_Order"]
    if adjacency_rule != "Tickers":
        raise ValueError(f"Adjacency_Index_Order must be explicitly set to 'Tickers'. Found: '{adjacency_rule}'. "
                         f"This rule is required to guarantee matrix dimension alignment.")

    logger.info("Successfully cross-validated configuration metadata and adjacency ordering rules.")
    return True

# -------------------------------------------------------------------------------------------------------------------------------
# Task 1, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class UniverseValidationReport:
    """
    Immutable data container for the validated universe artifacts.

    This dataclass serves as the definitive record of the vertex set V. It has been
    refactored to include an O(1) lookup dictionary, ensuring deterministic mapping
    between ticker strings and matrix indices across the entire pipeline.

    Attributes
    ----------
    canonical_tickers : List[str]
        The canonically ordered, normalized list of 34 unique ticker strings.
    inverted_alias_map : Dict[str, str]
        The inverted dictionary mapping alias strings to canonical ticker strings.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer
        matrix indices (0 to 33). Critical for downstream adjacency matrix population.
    """
    canonical_tickers: List[str]
    inverted_alias_map: Dict[str, str]
    ticker_to_position: Dict[str, int]


def orchestrate_universe_validation(
    tech_universe_raw: Dict[str, Any],
    study_configuration: Dict[str, Any]
) -> UniverseValidationReport:
    """
    Orchestrates Task 1: Validates universe cardinality, ordering, and alias coherence.

    This function executes the validation steps in a strict Directed Acyclic Graph (DAG)
    order. It has been refactored to correctly unpack the tuple returned by the stricter
    vertex validation step and populate the expanded UniverseValidationReport dataclass.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.

    Returns
    -------
    UniverseValidationReport
        An immutable dataclass containing the validated canonical tickers, alias map,
        and the O(1) position lookup dictionary.
    """
    logger.info("Starting Task 1 Orchestration: Universe Validation.")

    # Step 1: Validate the cardinality and uniqueness of the vertex set V
    # REFACTORED: Explicitly unpack the tuple to capture both the list and the lookup map.
    canonical_tickers, ticker_to_position = validate_vertex_set_cardinality(tech_universe_raw)

    # Step 2: Validate and invert the alias mapping to ensure strict injectivity
    # This prevents data corruption during the firm-day aggregation phase
    inverted_alias_map: Dict[str, str] = validate_alias_injectivity(tech_universe_raw, canonical_tickers)

    # Step 3: Cross-validate the study configuration against the validated universe
    # This ensures no silent numerical drift occurs due to configuration mismatches
    cross_validate_configuration_metadata(study_configuration, canonical_tickers)

    # Package the validated artifacts into the refactored immutable dataclass
    # REFACTORED: Passed the newly captured ticker_to_position dictionary.
    report = UniverseValidationReport(
        canonical_tickers=canonical_tickers,
        inverted_alias_map=inverted_alias_map,
        ticker_to_position=ticker_to_position
    )

    logger.info("=== Task 1 completed successfully. Universe artifacts locked. ===")

    # Return the immutable validation report
    return report

# %%
# Task 2 — Validate completeness and integrity of study configuration dictionary

# ==============================================================================
# Task 2: Validate completeness and integrity of study configuration dictionary
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 1: Verify all high-impact conventions are explicitly present
# -------------------------------------------------------------------------------------------------------------------------------
def verify_high_impact_conventions(study_configuration: Dict[str, Any]) -> bool:
    """
    Verifies the presence and non-null status of all high-impact conventions in the configuration.

    This function traverses the configuration dictionary to ensure that critical operational
    parameters (which are often unspecified in the manuscript but required for replication)
    are explicitly defined, thereby preventing silent numerical drift.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.

    Returns
    -------
    bool
        True if all high-impact conventions are present and valid.

    Raises
    ------
    KeyError
        If any required configuration path is missing.
    ValueError
        If a required configuration value is None or empty.
    """
    # Define the definitive list of required hierarchical paths for high-impact conventions
    required_paths: List[Tuple[str, ...]] = [
        ("reproducibility", "global_random_seed"),
        ("calendar_conventions", "calendar_type"),
        ("discretization_parameters", "quantile_levels"),
        ("discretization_parameters", "quantile_scope"),
        ("te_calibration", "probability_estimation", "zero_joint_probability_handling"),
        ("inference_parameters", "bootstrap_mechanics", "unobserved_transition_policy"),
        ("topological_metrics", "pagerank", "dangling_node_policy"),
        ("comparative_methodology", "stability_convergence", "if_diverges_policy")
    ]

    # Initialize a list to accumulate any missing or invalid paths for comprehensive error reporting
    missing_or_invalid_paths: List[str] = []

    # Iterate through each required path to verify its existence and validity
    for path in required_paths:
        # Start traversal from the root of the configuration dictionary
        current_level = study_configuration
        path_valid = True

        # Traverse the nested dictionary key by key
        for key in path:
            # Check if the current key exists in the current dictionary level
            if isinstance(current_level, dict) and key in current_level:
                # Move one level deeper into the dictionary
                current_level = current_level[key]
            else:
                # Mark the path as invalid if a key is missing or the structure is not a dict
                path_valid = False
                break

        # If the path exists, verify that the terminal value is not None or empty
        if path_valid:
            if current_level is None or (isinstance(current_level, (str, list, dict)) and not current_level):
                path_valid = False

        # If the path is invalid or the value is empty, record it for the error report
        if not path_valid:
            # Join the path tuple into a string representation for readability
            missing_or_invalid_paths.append(" -> ".join(path))

    # If any paths were missing or invalid, raise a blocking KeyError with the full list
    if missing_or_invalid_paths:
        error_msg = f"Missing or invalid high-impact conventions detected:\n" + "\n".join(missing_or_invalid_paths)
        raise KeyError(error_msg)

    # Log the successful verification of all high-impact conventions
    logger.info("Successfully verified the presence of all high-impact configuration conventions.")

    # Return True to indicate successful validation
    return True

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 2: Lock determinism and RNG conventions
# -------------------------------------------------------------------------------------------------------------------------------
def lock_determinism_and_rng(study_configuration: Dict[str, Any]) -> bool:
    """
    Validates that the stochastic parameters exactly match the locked replication conventions.

    This function enforces the exact global random seed, the specific RNG library, and the
    presence of distinct seed offsets for imputation and bootstrapping to guarantee that
    stochastic processes remain mathematically independent and perfectly reproducible.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.

    Returns
    -------
    bool
        True if all determinism and RNG conventions are perfectly locked.

    Raises
    ------
    ValueError
        If the seed, RNG library, or offsets deviate from the required replication standards.
    """
    # Extract the reproducibility sub-dictionary (guaranteed to exist by Step 1)
    repro_config: Dict[str, Any] = study_configuration["reproducibility"]

    # Extract the global random seed
    global_seed = repro_config.get("global_random_seed")

    # Enforce strict type and value equality for the global random seed
    if not isinstance(global_seed, int) or global_seed != 123456:
        # Raise a blocking error if the seed deviates from the locked replication value
        raise ValueError(f"Global random seed must be exactly the integer 123456. Found: {global_seed}")

    # Extract the RNG library string
    rng_lib = repro_config.get("rng_library")

    # Enforce exact string matching for the RNG library to prevent algorithmic drift
    expected_rng_lib = "numpy.random.Generator(PCG64)"
    if rng_lib != expected_rng_lib:
        # Raise a blocking error if the RNG engine is altered
        raise ValueError(f"RNG library must be exactly '{expected_rng_lib}'. Found: '{rng_lib}'")

    # Extract the seed partitioning dictionary
    seed_partitioning = repro_config.get("seed_partitioning", {})

    # Extract the specific offsets for imputation and bootstrapping
    imputation_offset = seed_partitioning.get("imputation_noise_seed_offset")
    bootstrap_offset = seed_partitioning.get("markov_bootstrap_seed_offset")

    # Enforce that both offsets exist, are integers, and are strictly positive
    if not isinstance(imputation_offset, int) or imputation_offset <= 0:
        raise ValueError("imputation_noise_seed_offset must be a positive integer.")
    if not isinstance(bootstrap_offset, int) or bootstrap_offset <= 0:
        raise ValueError("markov_bootstrap_seed_offset must be a positive integer.")

    # Enforce that the offsets are distinct to prevent correlation between stochastic streams
    if imputation_offset == bootstrap_offset:
        raise ValueError("Imputation and bootstrap seed offsets must be distinct to ensure independence.")

    # Log the successful locking of determinism and RNG conventions
    logger.info("Successfully locked determinism and RNG conventions (Seed: 123456, Engine: PCG64).")

    # Return True to indicate successful validation
    return True

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Step 3: Validate temporal and sample-size parameters against manuscript
# -------------------------------------------------------------------------------------------------------------------------------
def validate_temporal_parameters(study_configuration: Dict[str, Any]) -> int:
    """
    Validates the temporal parameters (T, L, s) and computes the total number of rolling windows (W).

    This function extracts the total observations (T), window length (L), and step size (s),
    validates them against the manuscript's stated values, and mathematically derives the
    number of rolling windows using the formula: W = floor((T - L) / s) + 1.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.

    Returns
    -------
    int
        The computed total number of rolling windows (W).

    Raises
    ------
    ValueError
        If T, L, or s deviate from the manuscript, or if the computed W is not 112.
    """
    # Extract the metadata and network architecture sub-dictionaries
    metadata: Dict[str, Any] = study_configuration.get("metadata", {})
    network_arch: Dict[str, Any] = study_configuration.get("network_architecture", {})

    # Extract the total number of observations (T)
    T = metadata.get("observations_total_T")
    # Enforce exact equality with the manuscript's stated sample size
    if T != 1319:
        raise ValueError(f"Total observations (T) must be exactly 1319. Found: {T}")

    # Extract the rolling window length (L)
    L = network_arch.get("rolling_window_length_L")
    # Enforce exact equality with the manuscript's stated window length
    if L != 200:
        raise ValueError(f"Rolling window length (L) must be exactly 200. Found: {L}")

    # Extract the step size (s)
    s = network_arch.get("step_size_s")
    # Enforce exact equality with the manuscript's stated step size
    if s != 10:
        raise ValueError(f"Step size (s) must be exactly 10. Found: {s}")

    # Mathematically derive the total number of rolling windows (W)
    # Equation: W = floor((T - L) / s) + 1
    # Using integer floor division (//) to guarantee exact arithmetic without floating-point errors
    W: int = ((T - L) // s) + 1

    # Enforce that the derived window count exactly matches the expected value of 112
    if W != 112:
        raise ValueError(f"Computed window count (W) must be exactly 112. Computed: {W}")

    # Log the successful validation of temporal parameters and the derived window count
    logger.info(f"Successfully validated temporal parameters. Computed rolling windows (W) = {W}.")

    # Return the computed window count for downstream use
    return W

# -------------------------------------------------------------------------------------------------------------------------------
# Task 2, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class ConfigValidationReport:
    """
    Immutable data container for the configuration validation artifacts.

    Attributes
    ----------
    is_valid : bool
        Boolean flag indicating that all configuration parameters passed strict validation.
    total_rolling_windows_W : int
        The mathematically derived total number of rolling windows (W = 112).
    """
    is_valid: bool
    total_rolling_windows_W: int


def orchestrate_config_validation(study_configuration: Dict[str, Any]) -> ConfigValidationReport:
    """
    Orchestrates Task 2: Validates completeness and integrity of the study configuration.

    This function executes the configuration validation steps in a strict Directed Acyclic
    Graph (DAG) order, ensuring that all high-impact conventions, RNG locks, and temporal
    parameters are mathematically certified before any data processing begins.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing study parameters.

    Returns
    -------
    ConfigValidationReport
        An immutable dataclass containing the validation status and derived window count.
    """
    logger.info("Starting Task 2 Orchestration: Configuration Validation.")

    # Step 1: Verify the presence of all high-impact conventions
    # This prevents silent numerical drift caused by missing operational definitions
    verify_high_impact_conventions(study_configuration)

    # Step 2: Lock determinism and RNG conventions
    # This guarantees that stochastic imputation and bootstrapping are perfectly reproducible
    lock_determinism_and_rng(study_configuration)

    # Step 3: Validate temporal parameters and compute the rolling window count (W)
    # This ensures that tensor dimensions for dynamic network construction are correct
    total_windows_W: int = validate_temporal_parameters(study_configuration)

    # Package the validation results and derived parameters into an immutable dataclass
    report = ConfigValidationReport(
        is_valid=True,
        total_rolling_windows_W=total_windows_W
    )

    logger.info("=== Task 2 completed successfully. Configuration integrity locked. ===")

    # Return the immutable validation report
    return report

# %%
# Task 3 — Validate sector mapping DataFrame schema and coverage

# ==============================================================================
# Task 3: Validate sector mapping DataFrame schema and coverage
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 1: Confirm row count and key integrity
# -------------------------------------------------------------------------------------------------------------------------------
def validate_sector_mapping_keys(df_sector_mapping: pd.DataFrame, canonical_tickers: List[str]) -> pd.DataFrame:
    """
    Validates the cardinality and key integrity of the sector mapping DataFrame.

    This function ensures that the DataFrame contains exactly 34 rows, contains no
    duplicate tickers, and that the set of tickers perfectly matches the canonical
    vertex set V.

    Parameters
    ----------
    df_sector_mapping : pd.DataFrame
        The raw sector mapping DataFrame containing 'Ticker', 'Company_Name', and 'GICS_Classification'.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings.

    Returns
    -------
    pd.DataFrame
        A cleaned copy of the DataFrame with normalized 'Ticker' strings.

    Raises
    ------
    TypeError
        If the input is not a pandas DataFrame.
    KeyError
        If the 'Ticker' column is missing.
    ValueError
        If the row count is not 34, duplicates exist, or the ticker set mismatches V.
    """
    # Enforce strict type checking for the input data structure
    if not isinstance(df_sector_mapping, pd.DataFrame):
        raise TypeError("df_sector_mapping must be a pandas DataFrame.")

    # Create a deep copy to adhere to immutability principles and prevent side effects
    df_clean = df_sector_mapping.copy(deep=True)

    # Verify the existence of the primary key column
    if "Ticker" not in df_clean.columns:
        raise KeyError("The required column 'Ticker' is missing from df_sector_mapping.")

    # Normalize the 'Ticker' column to prevent false mismatches due to whitespace or casing
    df_clean["Ticker"] = df_clean["Ticker"].astype(str).str.strip().str.upper()

    # Enforce the mathematical constraint: |rows| = 34
    if len(df_clean) != 34:
        raise ValueError(f"Sector mapping must contain exactly 34 rows. Found: {len(df_clean)}")

    # Check for duplicate tickers which would corrupt downstream joins
    if df_clean["Ticker"].duplicated().any():
        duplicates = df_clean[df_clean["Ticker"].duplicated()]["Ticker"].tolist()
        raise ValueError(f"Duplicate tickers detected in sector mapping: {duplicates}")

    # Enforce strict set equality: {Ticker} == V
    mapping_tickers_set: Set[str] = set(df_clean["Ticker"])
    canonical_tickers_set: Set[str] = set(canonical_tickers)

    if mapping_tickers_set != canonical_tickers_set:
        missing_in_mapping = canonical_tickers_set - mapping_tickers_set
        extra_in_mapping = mapping_tickers_set - canonical_tickers_set
        error_msg = "Sector mapping tickers do not perfectly match the canonical vertex set V.\n"
        if missing_in_mapping:
            error_msg += f"Missing from mapping: {missing_in_mapping}\n"
        if extra_in_mapping:
            error_msg += f"Extra in mapping: {extra_in_mapping}"
        raise ValueError(error_msg)

    logger.info("Successfully validated sector mapping row count and key integrity.")
    return df_clean

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 2: Validate GICS classification domain
# -------------------------------------------------------------------------------------------------------------------------------
def validate_gics_domain(df_sector_mapping: pd.DataFrame) -> pd.DataFrame:
    """
    Validates that all GICS classifications belong to the manuscript-defined domain.

    This function normalizes the 'GICS_Classification' column and enforces strict
    membership against the allowed set of 10 sector abbreviations.

    Parameters
    ----------
    df_sector_mapping : pd.DataFrame
        The DataFrame output from Step 1.

    Returns
    -------
    pd.DataFrame
        The DataFrame with normalized and validated GICS classifications.

    Raises
    ------
    KeyError
        If the 'GICS_Classification' column is missing.
    ValueError
        If any out-of-domain classification codes are detected.
    """
    # Verify the existence of the classification column
    if "GICS_Classification" not in df_sector_mapping.columns:
        raise KeyError("The required column 'GICS_Classification' is missing.")

    # Normalize the classification strings to ensure accurate membership checking
    df_sector_mapping["GICS_Classification"] = df_sector_mapping["GICS_Classification"].astype(str).str.strip().str.upper()

    # Define the strict mathematical domain of allowed GICS codes per the manuscript
    allowed_gics_domain: Set[str] = {"TH", "SW", "SC", "FS", "CC", "CS", "IT", "PS", "CM", "CE"}

    # Create a boolean mask identifying rows with out-of-domain codes
    invalid_mask = ~df_sector_mapping["GICS_Classification"].isin(allowed_gics_domain)

    # If any invalid codes exist, extract them and raise a blocking error
    if invalid_mask.any():
        invalid_rows = df_sector_mapping[invalid_mask]
        invalid_codes = invalid_rows["GICS_Classification"].unique().tolist()
        raise ValueError(
            f"Out-of-domain GICS classifications detected: {invalid_codes}. "
            f"Allowed domain is: {allowed_gics_domain}"
        )

    logger.info("Successfully validated GICS classification domain.")
    return df_sector_mapping

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Step 3: Enforce no missing classifications and canonical ordering
# -------------------------------------------------------------------------------------------------------------------------------
def enforce_completeness_and_canonical_order(df_sector_mapping: pd.DataFrame, canonical_tickers: List[str]) -> pd.DataFrame:
    """
    Enforces data completeness and aligns the DataFrame to the canonical vertex order.

    This function checks for NaN values in required columns and mathematically forces
    the row order of the DataFrame to perfectly match the canonical_tickers list,
    ensuring deterministic alignment for downstream adjacency matrix operations.

    Parameters
    ----------
    df_sector_mapping : pd.DataFrame
        The domain-validated DataFrame from Step 2.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings.

    Returns
    -------
    pd.DataFrame
        The finalized, complete, and canonically ordered sector metadata DataFrame.

    Raises
    ------
    KeyError
        If the 'Company_Name' column is missing.
    ValueError
        If NaN values are detected in required columns.
    """
    # Verify the existence of the Company_Name column
    if "Company_Name" not in df_sector_mapping.columns:
        raise KeyError("The required column 'Company_Name' is missing.")

    # Check for any missing (NaN) values in the required metadata columns
    if df_sector_mapping[["Company_Name", "GICS_Classification"]].isna().any().any():
        # Identify which tickers have missing data for precise error reporting
        missing_data_rows = df_sector_mapping[df_sector_mapping[["Company_Name", "GICS_Classification"]].isna().any(axis=1)]
        problem_tickers = missing_data_rows["Ticker"].tolist()
        raise ValueError(f"Missing classifications or company names detected for tickers: {problem_tickers}")

    # Temporarily set the 'Ticker' column as the index to facilitate structural alignment
    df_indexed = df_sector_mapping.set_index("Ticker")

    # Reindex the DataFrame using the canonical list. This mathematically forces the
    # row order to match the canonical vertex set V exactly.
    df_canonically_ordered = df_indexed.reindex(canonical_tickers)

    # Reset the index to restore 'Ticker' as a standard column, maintaining the new order
    df_final = df_canonically_ordered.reset_index()

    logger.info("Successfully enforced completeness and canonical row ordering.")
    return df_final

# -------------------------------------------------------------------------------------------------------------------------------
# Task 3, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class SectorMappingReport:
    """
    Immutable data container for the validated sector mapping artifacts.

    Attributes
    ----------
    df_sector_metadata : pd.DataFrame
        The fully validated, complete, and canonically ordered sector metadata table.
    """
    df_sector_metadata: pd.DataFrame


def orchestrate_sector_mapping_validation(df_sector_mapping_raw: pd.DataFrame, canonical_tickers: List[str]) -> SectorMappingReport:
    """
    Orchestrates Task 3: Validates sector mapping schema, domain, and coverage.

    This function executes the validation steps in a strict Directed Acyclic Graph (DAG)
    order, ensuring that the sector metadata is mathematically certified and structurally
    aligned with the canonical vertex set before it is used for interpretation.

    Parameters
    ----------
    df_sector_mapping_raw : pd.DataFrame
        The raw sector mapping DataFrame.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings (from Task 1).

    Returns
    -------
    SectorMappingReport
        An immutable dataclass containing the finalized sector metadata DataFrame.
    """
    logger.info("Starting Task 3 Orchestration: Sector Mapping Validation.")

    # Step 1: Confirm row count, uniqueness, and set equality with the canonical universe
    df_step1 = validate_sector_mapping_keys(df_sector_mapping_raw, canonical_tickers)

    # Step 2: Validate that all GICS codes belong to the manuscript-defined domain
    df_step2 = validate_gics_domain(df_step1)

    # Step 3: Enforce completeness (no NaNs) and align rows to the canonical ticker order
    df_final = enforce_completeness_and_canonical_order(df_step2, canonical_tickers)

    # Package the validated DataFrame into an immutable dataclass for downstream use
    report = SectorMappingReport(
        df_sector_metadata=df_final
    )

    logger.info("=== Task 3 completed successfully. Sector metadata locked and aligned. ===")

    # Return the immutable validation report
    return report

# %%
# Task 4 — Ingest raw daily sentiment panels and validate hard schema constraints (News)

# ======================================================================================
# Task 4: Ingest raw daily sentiment panels and validate hard schema constraints (News)
# ======================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 1: Validate required columns and data types
# -------------------------------------------------------------------------------------------------------------------------------
def validate_news_schema_and_types(df_news_raw: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the presence of required columns and safely coerces data types for News sentiment.

    This function enforces the exact schema prescribed by the study configuration. It ensures
    that Date is a datetime64 object, Ticker is a string, Sentiment_Score is a float64, and
    Story_Count_K is a 64-bit integer.

    Parameters
    ----------
    df_news_raw : pd.DataFrame
        The raw ingested Bloomberg News daily sentiment DataFrame.

    Returns
    -------
    pd.DataFrame
        A deep copy of the DataFrame with mathematically enforced data types.

    Raises
    ------
    TypeError
        If the input is not a pandas DataFrame.
    KeyError
        If any of the required columns are missing.
    ValueError
        If the data cannot be safely coerced into the required mathematical domains.
    """
    # Enforce strict type checking for the input data structure
    if not isinstance(df_news_raw, pd.DataFrame):
        raise TypeError("Input df_news_raw must be a pandas DataFrame.")

    # Create a deep copy to adhere to immutability principles and prevent side effects
    df_clean = df_news_raw.copy(deep=True)

    # Define the strict set of required columns based on the manuscript's data aggregation logic
    required_columns: List[str] = ["Date", "Ticker", "Sentiment_Score", "Story_Count_K"]

    # Identify any missing columns by comparing sets
    missing_cols = set(required_columns) - set(df_clean.columns)

    # Raise a blocking error if the schema is structurally deficient
    if missing_cols:
        raise KeyError(f"Missing required columns in News sentiment data: {missing_cols}")

    try:
        # Coerce the Date column to datetime64[ns], raising an error for unparseable formats
        df_clean["Date"] = pd.to_datetime(df_clean["Date"], errors="raise")

        # Coerce the Ticker column to string, ensuring categorical consistency
        df_clean["Ticker"] = df_clean["Ticker"].astype(str)

        # Coerce the Sentiment_Score to float64, allowing for continuous latent variable representation
        df_clean["Sentiment_Score"] = df_clean["Sentiment_Score"].astype(float)

        # Coerce Story_Count_K to the pandas nullable integer type (Int64)
        # This safely handles potential NaNs while enforcing discrete integer mathematics for counts
        df_clean["Story_Count_K"] = pd.to_numeric(df_clean["Story_Count_K"], errors="raise").astype("Int64")

    except Exception as e:
        # Catch any coercion failures and raise a descriptive ValueError
        raise ValueError(f"Data type coercion failed. Ensure data conforms to the required domains. Details: {str(e)}")

    # Log the successful validation and coercion of the schema
    logger.info("Successfully validated columns and coerced data types for News sentiment.")

    # Return the schema-compliant DataFrame
    return df_clean

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 2: Validate sentiment bounds and missingness semantics
# -------------------------------------------------------------------------------------------------------------------------------
def validate_news_bounds_and_semantics(df_news_typed: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the mathematical bounds of the sentiment scores and the logical missingness semantics.

    This function enforces that all non-missing sentiment scores fall within the [-1.0, 1.0] interval.
    It also mathematically enforces the implication: Story_Count_K == 0 => Sentiment_Score is NaN.

    Parameters
    ----------
    df_news_typed : pd.DataFrame
        The schema-compliant DataFrame output from Step 1.

    Returns
    -------
    pd.DataFrame
        The identical DataFrame, having passed all mathematical and logical audits.

    Raises
    ------
    ValueError
        If sentiment scores exceed the [-1.0, 1.0] bounds, or if the missingness logic is violated.
    """
    # Create a boolean mask for rows where the sentiment score is not missing
    valid_scores_mask = df_news_typed["Sentiment_Score"].notna()

    # Create a boolean mask for rows where the non-missing score violates the [-1.0, 1.0] bounds
    # Using a small tolerance (1e-9) to account for standard floating-point arithmetic inaccuracies
    out_of_bounds_mask = valid_scores_mask & ~df_news_typed["Sentiment_Score"].between(-1.0 - 1e-9, 1.0 + 1e-9)

    # If any scores violate the bounds, raise a blocking error
    if out_of_bounds_mask.any():
        # Extract the violating rows for the error message
        violating_rows = df_news_typed[out_of_bounds_mask][["Date", "Ticker", "Sentiment_Score"]]
        raise ValueError(f"Sentiment scores detected outside the [-1.0, 1.0] bounds:\n{violating_rows.head()}")

    # Enforce the logical implication: K == 0 implies Score == NaN
    # Create a mask for rows where the count is zero but the score is NOT missing
    logical_violation_mask = (df_news_typed["Story_Count_K"] == 0) & valid_scores_mask

    # If the implication is violated, raise a blocking error
    if logical_violation_mask.any():
        # Extract the violating rows for the error message
        violating_rows = df_news_typed[logical_violation_mask][["Date", "Ticker", "Sentiment_Score", "Story_Count_K"]]
        raise ValueError(f"Logical violation: Story_Count_K is 0 but Sentiment_Score is not NaN:\n{violating_rows.head()}")

    # Audit the reverse implication: Score == NaN implies K == 0
    # Create a mask for rows where the score is missing but the count is NOT zero
    reverse_violation_mask = df_news_typed["Sentiment_Score"].isna() & (df_news_typed["Story_Count_K"] != 0)

    # If the reverse implication is violated, log it as a documented exception (vendor feed absence)
    if reverse_violation_mask.any():
        violation_count = reverse_violation_mask.sum()
        # Log a warning rather than raising an error, preserving the fidelity of the raw missingness profile
        logger.warning(f"Documented exception: {violation_count} rows have NaN Sentiment_Score despite Story_Count_K != 0. "
                       f"This is attributed to vendor feed absence and is permitted.")

    # Log the successful validation of bounds and semantics
    logger.info("Successfully validated sentiment bounds and missingness semantics for News.")

    # Return the validated DataFrame
    return df_news_typed

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Step 3: Validate uniqueness of firm-day observations
# -------------------------------------------------------------------------------------------------------------------------------
def validate_news_firm_day_uniqueness(df_news_semantic: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the bijective mapping of observations to firm-days.

    This function ensures that each (Date, Ticker) pair appears exactly once in the panel,
    mathematically precluding Cartesian explosions during downstream matrix pivoting.

    Parameters
    ----------
    df_news_semantic : pd.DataFrame
        The bounds-validated DataFrame output from Step 2.

    Returns
    -------
    pd.DataFrame
        The identical DataFrame, having passed the uniqueness audit.

    Raises
    ------
    ValueError
        If duplicate (Date, Ticker) pairs are detected.
    """
    # Create a temporary normalized Ticker column to ensure formatting issues don't mask duplicates
    # This strip and upper operation is a preliminary safeguard; full alias normalization occurs in Task 6
    normalized_tickers = df_news_semantic["Ticker"].str.strip().str.upper()

    # Create a temporary DataFrame containing the Date and the normalized Tickers
    df_check = pd.DataFrame({
        "Date": df_news_semantic["Date"],
        "Ticker_Norm": normalized_tickers
    })

    # Generate a boolean mask identifying all rows that share a (Date, Ticker_Norm) combination
    # keep=False ensures that all instances of the duplicate are flagged
    duplicates_mask = df_check.duplicated(subset=["Date", "Ticker_Norm"], keep=False)

    # If any duplicates exist, raise a blocking error
    if duplicates_mask.any():
        # Extract the specific duplicated rows to provide actionable diagnostic information
        duplicate_rows = df_news_semantic[duplicates_mask].sort_values(by=["Date", "Ticker"])
        raise ValueError(f"Duplicate firm-day observations detected. Each (Date, Ticker) must be unique.\n"
                         f"Sample of duplicates:\n{duplicate_rows.head(10)}")

    # Log the successful validation of firm-day uniqueness
    logger.info("Successfully validated firm-day uniqueness for News sentiment.")

    # Return the validated DataFrame
    return df_news_semantic

# -------------------------------------------------------------------------------------------------------------------------------
# Task 4, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class NewsSentimentIngestionReport:
    """
    Immutable data container for the validated News sentiment artifacts.

    Attributes
    ----------
    df_news_validated : pd.DataFrame
        The fully validated, schema-compliant News sentiment DataFrame.
    """
    df_news_validated: pd.DataFrame


def orchestrate_news_sentiment_ingestion(df_news_sentiment_raw: pd.DataFrame) -> NewsSentimentIngestionReport:
    """
    Orchestrates Task 4: Ingests and validates hard schema constraints for News sentiment.

    This function executes the validation steps in a strict Directed Acyclic Graph (DAG)
    order, ensuring that the News sentiment data is mathematically certified, logically
    sound, and structurally unique before it enters the econometric preprocessing phases.

    Parameters
    ----------
    df_news_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg News daily sentiment DataFrame.

    Returns
    -------
    NewsSentimentIngestionReport
        An immutable dataclass containing the finalized, validated News DataFrame.
    """
    logger.info("Starting Task 4 Orchestration: News Sentiment Ingestion and Validation.")

    # Step 1: Validate the presence of required columns and safely coerce data types
    # This mathematically enforces the domains (datetime, string, float, int)
    df_step1 = validate_news_schema_and_types(df_news_sentiment_raw)

    # Step 2: Validate the [-1, 1] bounds and the logical missingness semantics
    # This ensures the latent sentiment variable adheres to the study's axioms
    df_step2 = validate_news_bounds_and_semantics(df_step1)

    # Step 3: Validate the uniqueness of the (Date, Ticker) composite key
    # This precludes Cartesian explosions during downstream matrix pivoting
    df_final = validate_news_firm_day_uniqueness(df_step2)

    # Package the validated DataFrame into an immutable dataclass for downstream use
    report = NewsSentimentIngestionReport(
        df_news_validated=df_final
    )

    logger.info("=== Task 4 completed successfully. News sentiment data locked and certified. ===")

    # Return the immutable validation report
    return report

# %%
# Task 5 — Ingest raw daily sentiment panels and validate hard schema constraints (Social)

# ========================================================================================
# Task 5: Ingest raw daily sentiment panels and validate hard schema constraints (Social)
# ========================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 1: Validate required columns and data types
# -------------------------------------------------------------------------------------------------------------------------------
def validate_social_schema_and_types(df_social_raw: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the presence of required columns and safely coerces data types for Social Media sentiment.

    This function enforces the exact schema prescribed by the study configuration. It ensures
    that Date is a datetime64 object, Ticker is a string, Sentiment_Score is a float64, and
    Post_Count_K is a 64-bit integer.

    Parameters
    ----------
    df_social_raw : pd.DataFrame
        The raw ingested Bloomberg Social Media daily sentiment DataFrame.

    Returns
    -------
    pd.DataFrame
        A deep copy of the DataFrame with mathematically enforced data types.

    Raises
    ------
    TypeError
        If the input is not a pandas DataFrame.
    KeyError
        If any of the required columns are missing.
    ValueError
        If the data cannot be safely coerced into the required mathematical domains.
    """
    # Enforce strict type checking for the input data structure
    if not isinstance(df_social_raw, pd.DataFrame):
        raise TypeError("Input df_social_raw must be a pandas DataFrame.")

    # Create a deep copy to adhere to immutability principles and prevent side effects
    df_clean = df_social_raw.copy(deep=True)

    # Define the strict set of required columns based on the manuscript's data aggregation logic
    required_columns: List[str] = ["Date", "Ticker", "Sentiment_Score", "Post_Count_K"]

    # Identify any missing columns by comparing sets
    missing_cols = set(required_columns) - set(df_clean.columns)

    # Raise a blocking error if the schema is structurally deficient
    if missing_cols:
        raise KeyError(f"Missing required columns in Social Media sentiment data: {missing_cols}")

    try:
        # Coerce the Date column to datetime64[ns], raising an error for unparseable formats
        df_clean["Date"] = pd.to_datetime(df_clean["Date"], errors="raise")

        # Coerce the Ticker column to string, ensuring categorical consistency
        df_clean["Ticker"] = df_clean["Ticker"].astype(str)

        # Coerce the Sentiment_Score to float64, allowing for continuous latent variable representation
        df_clean["Sentiment_Score"] = df_clean["Sentiment_Score"].astype(float)

        # Coerce Post_Count_K to the pandas nullable integer type (Int64)
        # This safely handles potential NaNs while enforcing discrete integer mathematics for counts
        df_clean["Post_Count_K"] = pd.to_numeric(df_clean["Post_Count_K"], errors="raise").astype("Int64")

    except Exception as e:
        # Catch any coercion failures and raise a descriptive ValueError
        raise ValueError(f"Data type coercion failed. Ensure data conforms to the required domains. Details: {str(e)}")

    # Log the successful validation and coercion of the schema
    logger.info("Successfully validated columns and coerced data types for Social Media sentiment.")

    # Return the schema-compliant DataFrame
    return df_clean

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 2: Validate sentiment bounds and missingness semantics
# -------------------------------------------------------------------------------------------------------------------------------
def validate_social_bounds_and_semantics(df_social_typed: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the mathematical bounds of the sentiment scores and the logical missingness semantics.

    This function enforces that all non-missing sentiment scores fall within the [-1.0, 1.0] interval.
    It also mathematically enforces the implication: Post_Count_K == 0 => Sentiment_Score is NaN.

    Parameters
    ----------
    df_social_typed : pd.DataFrame
        The schema-compliant DataFrame output from Step 1.

    Returns
    -------
    pd.DataFrame
        The identical DataFrame, having passed all mathematical and logical audits.

    Raises
    ------
    ValueError
        If sentiment scores exceed the [-1.0, 1.0] bounds, or if the missingness logic is violated.
    """
    # Create a boolean mask for rows where the sentiment score is not missing
    valid_scores_mask = df_social_typed["Sentiment_Score"].notna()

    # Create a boolean mask for rows where the non-missing score violates the [-1.0, 1.0] bounds
    # Using a small tolerance (1e-9) to account for standard floating-point arithmetic inaccuracies
    out_of_bounds_mask = valid_scores_mask & ~df_social_typed["Sentiment_Score"].between(-1.0 - 1e-9, 1.0 + 1e-9)

    # If any scores violate the bounds, raise a blocking error
    if out_of_bounds_mask.any():
        # Extract the violating rows for the error message
        violating_rows = df_social_typed[out_of_bounds_mask][["Date", "Ticker", "Sentiment_Score"]]
        raise ValueError(f"Sentiment scores detected outside the [-1.0, 1.0] bounds:\n{violating_rows.head()}")

    # Enforce the logical implication: K == 0 implies Score == NaN
    # Create a mask for rows where the count is zero but the score is NOT missing
    logical_violation_mask = (df_social_typed["Post_Count_K"] == 0) & valid_scores_mask

    # If the implication is violated, raise a blocking error
    if logical_violation_mask.any():
        # Extract the violating rows for the error message
        violating_rows = df_social_typed[logical_violation_mask][["Date", "Ticker", "Sentiment_Score", "Post_Count_K"]]
        raise ValueError(f"Logical violation: Post_Count_K is 0 but Sentiment_Score is not NaN:\n{violating_rows.head()}")

    # Audit the reverse implication: Score == NaN implies K == 0
    # Create a mask for rows where the score is missing but the count is NOT zero
    reverse_violation_mask = df_social_typed["Sentiment_Score"].isna() & (df_social_typed["Post_Count_K"] != 0)

    # If the reverse implication is violated, log it as a documented exception (vendor feed absence)
    if reverse_violation_mask.any():
        violation_count = reverse_violation_mask.sum()
        # Log a warning rather than raising an error, preserving the fidelity of the raw missingness profile
        logger.warning(f"Documented exception: {violation_count} rows have NaN Sentiment_Score despite Post_Count_K != 0. "
                       f"This is attributed to vendor feed absence and is permitted.")

    # Log the successful validation of bounds and semantics
    logger.info("Successfully validated sentiment bounds and missingness semantics for Social Media.")

    # Return the validated DataFrame
    return df_social_typed

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Step 3: Validate uniqueness of firm-day observations
# -------------------------------------------------------------------------------------------------------------------------------
def validate_social_firm_day_uniqueness(df_social_semantic: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the bijective mapping of observations to firm-days.

    This function ensures that each (Date, Ticker) pair appears exactly once in the panel,
    mathematically precluding Cartesian explosions during downstream matrix pivoting.

    Parameters
    ----------
    df_social_semantic : pd.DataFrame
        The bounds-validated DataFrame output from Step 2.

    Returns
    -------
    pd.DataFrame
        The identical DataFrame, having passed the uniqueness audit.

    Raises
    ------
    ValueError
        If duplicate (Date, Ticker) pairs are detected.
    """
    # Create a temporary normalized Ticker column to ensure formatting issues don't mask duplicates
    # This strip and upper operation is a preliminary safeguard; full alias normalization occurs in Task 6
    normalized_tickers = df_social_semantic["Ticker"].str.strip().str.upper()

    # Create a temporary DataFrame containing the Date and the normalized Tickers
    df_check = pd.DataFrame({
        "Date": df_social_semantic["Date"],
        "Ticker_Norm": normalized_tickers
    })

    # Generate a boolean mask identifying all rows that share a (Date, Ticker_Norm) combination
    # keep=False ensures that all instances of the duplicate are flagged
    duplicates_mask = df_check.duplicated(subset=["Date", "Ticker_Norm"], keep=False)

    # If any duplicates exist, raise a blocking error
    if duplicates_mask.any():
        # Extract the specific duplicated rows to provide actionable diagnostic information
        duplicate_rows = df_social_semantic[duplicates_mask].sort_values(by=["Date", "Ticker"])
        raise ValueError(f"Duplicate firm-day observations detected. Each (Date, Ticker) must be unique.\n"
                         f"Sample of duplicates:\n{duplicate_rows.head(10)}")

    # Log the successful validation of firm-day uniqueness
    logger.info("Successfully validated firm-day uniqueness for Social Media sentiment.")

    # Return the validated DataFrame
    return df_social_semantic

# -------------------------------------------------------------------------------------------------------------------------------
# Task 5, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class SocialSentimentIngestionReport:
    """
    Immutable data container for the validated Social Media sentiment artifacts.

    Attributes
    ----------
    df_social_validated : pd.DataFrame
        The fully validated, schema-compliant Social Media sentiment DataFrame.
    """
    df_social_validated: pd.DataFrame


def orchestrate_social_sentiment_ingestion(df_social_sentiment_raw: pd.DataFrame) -> SocialSentimentIngestionReport:
    """
    Orchestrates Task 5: Ingests and validates hard schema constraints for Social Media sentiment.

    This function executes the validation steps in a strict Directed Acyclic Graph (DAG)
    order, ensuring that the Social Media sentiment data is mathematically certified, logically
    sound, and structurally unique before it enters the econometric preprocessing phases.

    Parameters
    ----------
    df_social_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg Social Media daily sentiment DataFrame.

    Returns
    -------
    SocialSentimentIngestionReport
        An immutable dataclass containing the finalized, validated Social Media DataFrame.
    """
    logger.info("Starting Task 5 Orchestration: Social Media Sentiment Ingestion and Validation.")

    # Step 1: Validate the presence of required columns and safely coerce data types
    # This mathematically enforces the domains (datetime, string, float, int)
    df_step1 = validate_social_schema_and_types(df_social_sentiment_raw)

    # Step 2: Validate the [-1, 1] bounds and the logical missingness semantics
    # This ensures the latent sentiment variable adheres to the study's axioms
    df_step2 = validate_social_bounds_and_semantics(df_step1)

    # Step 3: Validate the uniqueness of the (Date, Ticker) composite key
    # This precludes Cartesian explosions during downstream matrix pivoting
    df_final = validate_social_firm_day_uniqueness(df_step2)

    # Package the validated DataFrame into an immutable dataclass for downstream use
    report = SocialSentimentIngestionReport(
        df_social_validated=df_final
    )

    logger.info("=== Task 5 completed successfully. Social Media sentiment data locked and certified. ===")

    # Return the immutable validation report
    return report

# %%
# Task 6 — Cleanse data via canonical ticker normalization and master calendar alignment

# ======================================================================================
# Task 6: Cleanse data via canonical ticker normalization and master calendar alignment
# ======================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 1: Apply ticker alias normalization
# -------------------------------------------------------------------------------------------------------------------------------
def apply_ticker_alias_normalization(
    df_sentiment: pd.DataFrame,
    inverted_alias_map: Dict[str, str],
    canonical_tickers: List[str],
    channel_name: str
) -> pd.DataFrame:
    """
    Normalizes ticker aliases to their canonical forms and enforces universe membership.

    This function applies the inverted alias mapping to the 'Ticker' column. It mathematically
    guarantees that post-normalization, every row maps to a valid node in the canonical
    vertex set V, and that no duplicate (Date, Ticker) pairs were created by the merge.

    Parameters
    ----------
    df_sentiment : pd.DataFrame
        The schema-validated long-form sentiment DataFrame (News or Social).
    inverted_alias_map : Dict[str, str]
        The validated dictionary mapping alias strings to canonical ticker strings.
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings (Set V).
    channel_name : str
        Identifier for logging purposes (e.g., "News" or "Social").

    Returns
    -------
    pd.DataFrame
        A deep copy of the DataFrame with normalized canonical tickers.

    Raises
    ------
    ValueError
        If any ticker remains outside the canonical set V, or if normalization creates duplicates.
    """
    # Create a deep copy to adhere to immutability principles
    df_clean = df_sentiment.copy(deep=True)

    # Normalize the strings to ensure exact dictionary key matching
    df_clean["Ticker"] = df_clean["Ticker"].str.strip().str.upper()

    # Apply the alias mapping. The .replace() method only modifies values that match the keys.
    # This is highly efficient and leaves already-canonical tickers untouched.
    if inverted_alias_map:
        df_clean["Ticker"] = df_clean["Ticker"].replace(inverted_alias_map)

    # Convert the canonical list to a set for O(1) membership checking
    canonical_set = set(canonical_tickers)

    # Identify any tickers that do not belong to the canonical vertex set V
    invalid_tickers = set(df_clean["Ticker"]) - canonical_set

    # Enforce the mathematical condition: ∀ rows, Ticker ∈ V
    if invalid_tickers:
        raise ValueError(f"[{channel_name}] Tickers detected outside the canonical universe V after normalization: {invalid_tickers}")

    # Check if alias normalization created duplicate firm-day observations
    # e.g., if both 'SQ' and 'XYZ' existed on the same date, they now collide as 'SQ'
    duplicates_mask = df_clean.duplicated(subset=["Date", "Ticker"], keep=False)

    if duplicates_mask.any():
        duplicate_rows = df_clean[duplicates_mask].sort_values(by=["Date", "Ticker"])
        raise ValueError(f"[{channel_name}] Alias normalization created duplicate (Date, Ticker) pairs. "
                         f"Resolution rule is unspecified in manuscript.\nSample:\n{duplicate_rows.head()}")

    logger.info(f"Successfully applied alias normalization for {channel_name} channel.")
    return df_clean

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 2: Construct the master calendar of length T=1319
# -------------------------------------------------------------------------------------------------------------------------------
def construct_master_calendar(
    study_configuration: Dict[str, Any],
    fallback_calendar: Optional[pd.DatetimeIndex] = None
) -> pd.DatetimeIndex:
    """
    Constructs and validates the master date grid, mathematically guaranteeing T=1319.

    This function extracts the study boundaries and generates a strict US business day
    calendar. It abandons the flawed empirical union method to prevent the silent erasure
    of missing days. If exchange holidays cause the generated length to deviate from 1,319,
    it requires a pre-validated fallback calendar to ensure perfect temporal alignment.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the date range and expected T.
    fallback_calendar : Optional[pd.DatetimeIndex], optional
        A pre-validated, exact calendar of length 1319 to use if standard business
        days do not align perfectly with the manuscript's count, by default None.

    Returns
    -------
    pd.DatetimeIndex
        The validated, chronologically sorted master calendar of exact length T=1319.

    Raises
    ------
    ValueError
        If the generated calendar length != 1319 and no valid fallback is provided.
    """
    # Extract the configured date range bounds
    start_date_str, end_date_str = study_configuration["metadata"]["date_range"]

    # Extract the mathematically required temporal dimension T
    expected_T: int = study_configuration["metadata"]["observations_total_T"]

    # Parse the bounds to strict, timezone-naive pandas Timestamps to prevent alignment crashes
    start_date = pd.to_datetime(start_date_str).tz_localize(None)
    end_date = pd.to_datetime(end_date_str).tz_localize(None)

    # Generate a standard US business day calendar (Monday-Friday)
    generated_calendar = pd.bdate_range(start=start_date, end=end_date)

    # Check if the generated calendar perfectly matches the manuscript's required length
    if len(generated_calendar) == expected_T:
        logger.info(f"Successfully generated master calendar. T = {expected_T}.")
        return generated_calendar
    else:
        # If lengths mismatch (due to market holidays), evaluate the fallback calendar
        logger.warning(f"Generated business calendar length ({len(generated_calendar)}) "
                       f"does not match expected T ({expected_T}).")

        # Validate the fallback calendar if provided
        if fallback_calendar is not None:
            if len(fallback_calendar) == expected_T:
                # Ensure the fallback calendar is timezone-naive and sorted
                validated_fallback = fallback_calendar.tz_localize(None).sort_values()
                logger.info("Utilizing provided fallback calendar to guarantee T=1319.")
                return validated_fallback
            else:
                # Raise an error if the fallback also fails the length constraint
                raise ValueError(f"Fallback calendar length ({len(fallback_calendar)}) "
                                 f"must exactly equal T ({expected_T}).")
        else:
            # Raise a strict error demanding an exact calendar to prevent temporal corruption
            raise ValueError(f"Cannot guarantee T={expected_T} using standard business days. "
                             f"Please provide a pre-validated fallback_calendar containing "
                             f"the exact exchange trading days.")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Step 3: Align both channels to the master calendar
# -------------------------------------------------------------------------------------------------------------------------------
def align_to_cartesian_grid(
    df_sentiment: pd.DataFrame,
    master_calendar: pd.DatetimeIndex,
    canonical_tickers: List[str],
    channel_name: str
) -> pd.DataFrame:
    """
    Aligns the sentiment DataFrame to the complete Cartesian grid (MasterCalendar x V).

    This function mathematically enforces structural equivalence by reindexing the data
    against a MultiIndex. Missing firm-days are explicitly represented as NaN rows,
    preserving the exact missingness profile required for stochastic imputation.

    Parameters
    ----------
    df_sentiment : pd.DataFrame
        The alias-normalized sentiment DataFrame.
    master_calendar : pd.DatetimeIndex
        The validated master date grid (T=1319).
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings (Set V).
    channel_name : str
        Identifier for logging purposes.

    Returns
    -------
    pd.DataFrame
        The structurally complete long-form DataFrame with exactly T * n rows.

    Raises
    ------
    ValueError
        If the resulting row count does not equal T * n.
    """
    # Define the expected dimensions
    T = len(master_calendar)
    n = len(canonical_tickers)
    expected_rows = T * n

    # Create the Cartesian MultiIndex (Date x Ticker)
    # The order of levels is critical: Date first, then Ticker
    cartesian_index = pd.MultiIndex.from_product(
        [master_calendar, canonical_tickers],
        names=["Date", "Ticker"]
    )

    # Set the index of the input DataFrame to match the MultiIndex structure
    df_indexed = df_sentiment.set_index(["Date", "Ticker"])

    # Reindex against the Cartesian grid. Missing combinations will be filled with NaN.
    df_aligned = df_indexed.reindex(cartesian_index)

    # Reset the index to return to a flat, long-form DataFrame
    df_final = df_aligned.reset_index()

    # Enforce the structural constraint: exactly T * n rows
    if len(df_final) != expected_rows:
        raise ValueError(f"[{channel_name}] Alignment failed. Expected {expected_rows} rows, got {len(df_final)}.")

    logger.info(f"Successfully aligned {channel_name} to Cartesian grid ({T} dates x {n} tickers).")
    return df_final

# -------------------------------------------------------------------------------------------------------------------------------
# Task 6, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class AlignedSentimentReport:
    """
    Immutable data container for the aligned and cleansed sentiment artifacts.

    Attributes
    ----------
    master_calendar : pd.DatetimeIndex
        The validated master date grid of length T=1319.
    df_news_aligned : pd.DataFrame
        The structurally complete, Cartesian-aligned News sentiment DataFrame.
    df_social_aligned : pd.DataFrame
        The structurally complete, Cartesian-aligned Social Media sentiment DataFrame.
    """
    master_calendar: pd.DatetimeIndex
    df_news_aligned: pd.DataFrame
    df_social_aligned: pd.DataFrame


def orchestrate_data_cleansing_and_alignment(
    df_news_validated: pd.DataFrame,
    df_social_validated: pd.DataFrame,
    inverted_alias_map: Dict[str, str],
    canonical_tickers: List[str],
    study_configuration: Dict[str, Any],
    fallback_calendar: Optional[pd.DatetimeIndex] = None
) -> Any: # Returns AlignedSentimentReport (type hinted as Any to avoid circular imports in this isolated block)
    """
    Orchestrates Task 6: Cleanses data via alias normalization and aligns to a master calendar.

    This function executes the alignment steps in a strict Directed Acyclic Graph (DAG)
    order. It has been refactored to accommodate the stricter mathematical requirements
    of the master calendar construction, accepting an optional fallback calendar to
    guarantee T=1319 if standard business day generation fails due to exchange anomalies.

    Parameters
    ----------
    df_news_validated : pd.DataFrame
        The schema-validated News sentiment DataFrame (from Task 4).
    df_social_validated : pd.DataFrame
        The schema-validated Social Media sentiment DataFrame (from Task 5).
    inverted_alias_map : Dict[str, str]
        The validated alias mapping dictionary (from Task 1).
    canonical_tickers : List[str]
        The validated canonical vertex set V (from Task 1).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.
    fallback_calendar : Optional[pd.DatetimeIndex], optional
        A pre-validated, exact calendar of length 1319 to use if standard business
        days do not align perfectly with the manuscript's count, by default None.

    Returns
    -------
    AlignedSentimentReport
        An immutable dataclass containing the master calendar and aligned DataFrames.
    """
    logger.info("Starting Task 6 Orchestration: Data Cleansing and Calendar Alignment.")

    # Step 1: Apply alias normalization to both channels
    # This guarantees that all rows map to the canonical vertex set V
    df_news_norm = apply_ticker_alias_normalization(
        df_news_validated, inverted_alias_map, canonical_tickers, "News"
    )
    df_social_norm = apply_ticker_alias_normalization(
        df_social_validated, inverted_alias_map, canonical_tickers, "Social"
    )

    # Step 2: Construct the master calendar
    # REFACTORED: Removed obsolete DataFrame arguments. Passed configuration and fallback.
    # This mathematically enforces the T=1319 constraint without relying on empirical unions.
    master_calendar = construct_master_calendar(
        study_configuration=study_configuration,
        fallback_calendar=fallback_calendar
    )

    # Step 3: Align both channels to the Cartesian grid
    # This ensures structural equivalence (T x n) for downstream matrix operations
    df_news_aligned = align_to_cartesian_grid(
        df_news_norm, master_calendar, canonical_tickers, "News"
    )
    df_social_aligned = align_to_cartesian_grid(
        df_social_norm, master_calendar, canonical_tickers, "Social"
    )

    # Package the aligned artifacts into an immutable dataclass
    # Note: AlignedSentimentReport is assumed to be available in the working environment
    report = AlignedSentimentReport(
        master_calendar=master_calendar,
        df_news_aligned=df_news_aligned,
        df_social_aligned=df_social_aligned
    )

    logger.info("=== Task 6 completed successfully. Data cleansed and structurally aligned. ===")

    # Return the immutable alignment report
    return report

# %%
# Task 7 — Pivot sentiment panels into firm-indexed matrices with canonical vertex ordering

# =========================================================================================
# Task 7: Pivot sentiment panels into firm-indexed matrices with canonical vertex ordering
# =========================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 1: Pivot News sentiment into matrix form
# -------------------------------------------------------------------------------------------------------------------------------
def pivot_news_to_matrix(
    df_news_aligned: pd.DataFrame,
    ticker_to_position: Dict[str, int]
) -> pd.DataFrame:
    """
    Transforms the aligned long-form News DataFrame into a wide-form matrix X^(News).

    This function pivots the data such that rows represent the master calendar dates (T)
    and columns represent the canonical tickers (n). It mathematically enforces the
    column order by extracting the exact sequence dictated by the O(1) ticker_to_position map.

    Parameters
    ----------
    df_news_aligned : pd.DataFrame
        The structurally complete, Cartesian-aligned News sentiment DataFrame.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    pd.DataFrame
        The wide-form matrix X^(News) of shape (T, n).

    Raises
    ------
    ValueError
        If the pivot operation fails or if the final shape is incorrect.
    """
    # Extract only the necessary columns to optimize memory during the pivot operation
    df_subset = df_news_aligned[["Date", "Ticker", "Sentiment_Score"]]

    try:
        # Pivot the DataFrame, strictly enforcing unique index/column combinations
        df_pivoted = df_subset.pivot(index="Date", columns="Ticker", values="Sentiment_Score")
    except ValueError as e:
        raise ValueError(f"Pivot operation failed for News sentiment. Details: {str(e)}")

    # Extract the ordered list of tickers strictly based on their assigned integer positions
    # This guarantees perfect alignment with the vertex set V
    ordered_tickers: List[str] = [k for k, v in sorted(ticker_to_position.items(), key=lambda item: item[1])]

    # Mathematically enforce the canonical column order
    df_ordered = df_pivoted.reindex(columns=ordered_tickers)

    # Ensure the temporal index is strictly chronological
    df_ordered = df_ordered.sort_index()

    # Validate the final dimensions (T=1319, n=34)
    expected_T = len(df_news_aligned["Date"].unique())
    expected_n = len(ordered_tickers)

    if df_ordered.shape != (expected_T, expected_n):
        raise ValueError(f"News matrix shape mismatch. Expected ({expected_T}, {expected_n}), got {df_ordered.shape}.")

    logger.info(f"Successfully pivoted News sentiment into matrix form. Shape: {df_ordered.shape}.")
    return df_ordered

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 2: Pivot Social sentiment into matrix form
# -------------------------------------------------------------------------------------------------------------------------------
def pivot_social_to_matrix(
    df_social_aligned: pd.DataFrame,
    ticker_to_position: Dict[str, int]
) -> pd.DataFrame:
    """
    Transforms the aligned long-form Social Media DataFrame into a wide-form matrix X^(Social).

    This function pivots the data such that rows represent the master calendar dates (T)
    and columns represent the canonical tickers (n). It mathematically enforces the
    column order by extracting the exact sequence dictated by the O(1) ticker_to_position map.

    Parameters
    ----------
    df_social_aligned : pd.DataFrame
        The structurally complete, Cartesian-aligned Social Media sentiment DataFrame.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    pd.DataFrame
        The wide-form matrix X^(Social) of shape (T, n).

    Raises
    ------
    ValueError
        If the pivot operation fails or if the final shape is incorrect.
    """
    # Extract only the necessary columns to optimize memory during the pivot operation
    df_subset = df_social_aligned[["Date", "Ticker", "Sentiment_Score"]]

    try:
        # Pivot the DataFrame, strictly enforcing unique index/column combinations
        df_pivoted = df_subset.pivot(index="Date", columns="Ticker", values="Sentiment_Score")
    except ValueError as e:
        raise ValueError(f"Pivot operation failed for Social sentiment. Details: {str(e)}")

    # Extract the ordered list of tickers strictly based on their assigned integer positions
    ordered_tickers: List[str] = [k for k, v in sorted(ticker_to_position.items(), key=lambda item: item[1])]

    # Mathematically enforce the canonical column order
    df_ordered = df_pivoted.reindex(columns=ordered_tickers)

    # Ensure the temporal index is strictly chronological
    df_ordered = df_ordered.sort_index()

    # Validate the final dimensions (T=1319, n=34)
    expected_T = len(df_social_aligned["Date"].unique())
    expected_n = len(ordered_tickers)

    if df_ordered.shape != (expected_T, expected_n):
        raise ValueError(f"Social matrix shape mismatch. Expected ({expected_T}, {expected_n}), got {df_ordered.shape}.")

    logger.info(f"Successfully pivoted Social Media sentiment into matrix form. Shape: {df_ordered.shape}.")
    return df_ordered

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Step 3: Validate alignment of the two matrices
# -------------------------------------------------------------------------------------------------------------------------------
def validate_matrix_isomorphism(
    matrix_news: pd.DataFrame,
    matrix_social: pd.DataFrame,
    master_calendar: pd.DatetimeIndex,
    canonical_tickers: List[str]
) -> bool:
    """
    Mathematically proves the structural isomorphism of the News and Social matrices.

    This function certifies that both matrices share the exact same temporal index
    (MasterCalendar) and the exact same cross-sectional columns (Set V), ensuring
    they are perfectly aligned for comparative topological analysis.

    Parameters
    ----------
    matrix_news : pd.DataFrame
        The wide-form News sentiment matrix.
    matrix_social : pd.DataFrame
        The wide-form Social Media sentiment matrix.
    master_calendar : pd.DatetimeIndex
        The validated master date grid (from Task 6).
    canonical_tickers : List[str]
        The validated canonical vertex set V (from Task 1).

    Returns
    -------
    bool
        True if the matrices are structurally isomorphic and aligned to the ground truth.

    Raises
    ------
    ValueError
        If the indices or columns deviate from the master calendar or canonical tickers,
        or if the matrices do not perfectly match each other.
    """
    # 1. Validate News matrix against ground truth
    if not matrix_news.index.equals(master_calendar):
        raise ValueError("News matrix row index does not perfectly match the Master Calendar.")
    if not matrix_news.columns.equals(pd.Index(canonical_tickers)):
        raise ValueError("News matrix columns do not perfectly match the Canonical Tickers sequence.")

    # 2. Validate Social matrix against ground truth
    if not matrix_social.index.equals(master_calendar):
        raise ValueError("Social matrix row index does not perfectly match the Master Calendar.")
    if not matrix_social.columns.equals(pd.Index(canonical_tickers)):
        raise ValueError("Social matrix columns do not perfectly match the Canonical Tickers sequence.")

    # 3. Validate cross-matrix equivalence (redundant but mathematically rigorous)
    if not matrix_news.index.equals(matrix_social.index):
        raise ValueError("Critical Alignment Failure: News and Social matrices have divergent row indices.")
    if not matrix_news.columns.equals(matrix_social.columns):
        raise ValueError("Critical Alignment Failure: News and Social matrices have divergent column indices.")

    # Lightweight diagnostic: Warn if a matrix is entirely NaN (indicates upstream failure)
    if matrix_news.isna().all().all():
        logger.warning("Diagnostic Alert: The News matrix is entirely composed of NaN values.")
    if matrix_social.isna().all().all():
        logger.warning("Diagnostic Alert: The Social matrix is entirely composed of NaN values.")

    logger.info("Successfully certified structural isomorphism of News and Social matrices.")
    return True

# -------------------------------------------------------------------------------------------------------------------------------
# Task 7, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class PivotedSentimentMatrices:
    """
    Immutable data container for the certified wide-form sentiment matrices.

    Attributes
    ----------
    matrix_news : pd.DataFrame
        The wide-form News sentiment matrix X^(News) of shape (T, n).
    matrix_social : pd.DataFrame
        The wide-form Social Media sentiment matrix X^(Social) of shape (T, n).
    T_observations : int
        The number of temporal observations (rows).
    n_nodes : int
        The number of canonical tickers (columns).
    """
    matrix_news: pd.DataFrame
    matrix_social: pd.DataFrame
    T_observations: int
    n_nodes: int


def orchestrate_matrix_pivoting(
    df_news_aligned: pd.DataFrame,
    df_social_aligned: pd.DataFrame,
    master_calendar: pd.DatetimeIndex,
    ticker_to_position: Dict[str, int]
) -> Any: # Returns PivotedSentimentMatrices
    """
    Orchestrates Task 7: Pivots sentiment panels into firm-indexed matrices.

    This function executes the pivoting steps in a strict Directed Acyclic Graph (DAG)
    order. It has been refactored to accept the ticker_to_position map, ensuring that
    the resulting wide-form matrices are perfectly synchronized with the global vertex set.

    Parameters
    ----------
    df_news_aligned : pd.DataFrame
        The structurally complete News sentiment DataFrame.
    df_social_aligned : pd.DataFrame
        The structurally complete Social Media sentiment DataFrame.
    master_calendar : pd.DatetimeIndex
        The validated master date grid.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    PivotedSentimentMatrices
        An immutable dataclass containing the certified wide-form matrices.
    """
    logger.info("Starting Task 7 Orchestration: Matrix Pivoting and Alignment Certification.")

    # Step 1: Pivot News sentiment into matrix form, enforcing canonical column order via the map
    matrix_news = pivot_news_to_matrix(df_news_aligned, ticker_to_position)

    # Step 2: Pivot Social sentiment into matrix form, enforcing canonical column order via the map
    matrix_social = pivot_social_to_matrix(df_social_aligned, ticker_to_position)

    # Extract the ordered list of tickers for the isomorphism validation
    ordered_tickers: List[str] = [k for k, v in sorted(ticker_to_position.items(), key=lambda item: item[1])]

    # Step 3: Mathematically prove the structural isomorphism of the two matrices
    validate_matrix_isomorphism(matrix_news, matrix_social, master_calendar, ordered_tickers)

    # Package the certified matrices into an immutable dataclass
    report = PivotedSentimentMatrices(
        matrix_news=matrix_news,
        matrix_social=matrix_social,
        T_observations=len(master_calendar),
        n_nodes=len(ordered_tickers)
    )

    logger.info("=== Task 7 completed successfully. Matrices pivoted and certified. ===")
    return report

# %%
# Task 8 — Profile missingness and validate against manuscript-stated magnitudes

# ==============================================================================
# Task 8: Profile missingness and validate against manuscript-stated magnitudes
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 1: Compute missing rate per firm per channel
# -------------------------------------------------------------------------------------------------------------------------------
def compute_missingness_profile(pivoted_matrices: Any) -> pd.DataFrame:
    """
    Computes the exact missing rate for each ticker and channel.

    This function implements the mathematical definition:
    MissingRate_i = #{t: x_{i,t} is NaN} / T
    It processes the certified wide-form matrices and returns a tidy DataFrame
    suitable for downstream validation and manuscript table generation.

    Parameters
    ----------
    pivoted_matrices : PivotedSentimentMatrices
        The dataclass containing the certified wide-form matrices and metadata (from Task 7).

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Ticker, Missing_Count, Total_T, and Missing_Rate.
    """
    # Extract the certified matrices and the exact temporal length T
    matrix_news: pd.DataFrame = pivoted_matrices.matrix_news
    matrix_social: pd.DataFrame = pivoted_matrices.matrix_social
    T: int = pivoted_matrices.T_observations

    # Vectorized computation of missing counts per column (ticker) for News
    # .isna().sum(axis=0) returns a Series indexed by the canonical tickers
    news_missing_counts = matrix_news.isna().sum(axis=0)

    # Construct a tidy DataFrame for News
    df_profile_news = pd.DataFrame({
        "Channel": "News",
        "Ticker": news_missing_counts.index,
        "Missing_Count": news_missing_counts.values,
        "Total_T": T
    })

    # Mathematically derive the missing rate
    df_profile_news["Missing_Rate"] = df_profile_news["Missing_Count"] / df_profile_news["Total_T"]

    # Vectorized computation of missing counts per column (ticker) for Social
    social_missing_counts = matrix_social.isna().sum(axis=0)

    # Construct a tidy DataFrame for Social
    df_profile_social = pd.DataFrame({
        "Channel": "Social",
        "Ticker": social_missing_counts.index,
        "Missing_Count": social_missing_counts.values,
        "Total_T": T
    })

    # Mathematically derive the missing rate
    df_profile_social["Missing_Rate"] = df_profile_social["Missing_Count"] / df_profile_social["Total_T"]

    # Concatenate the two profiles into a single comprehensive reporting table
    df_missingness_profile = pd.concat([df_profile_news, df_profile_social], ignore_index=True)

    logger.info("Successfully computed missingness profile for all tickers across both channels.")
    return df_missingness_profile

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 2: Validate missing rates are manuscript-consistent
# -------------------------------------------------------------------------------------------------------------------------------
def validate_missingness_bounds(df_missingness_profile: pd.DataFrame) -> pd.DataFrame:
    """
    Validates the computed missing rates against the manuscript's stated magnitudes.

    This function audits the rates against the [0.00758, 0.2456] range. Deviations are
    logged as warnings. However, if any ticker is 100% missing (rate == 1.0), a blocking
    ValueError is raised, as this mathematically precludes AR(1) estimation.

    Parameters
    ----------
    df_missingness_profile : pd.DataFrame
        The tidy missingness profile DataFrame generated in Step 1.

    Returns
    -------
    pd.DataFrame
        The identical DataFrame, having passed the fatal structural checks.

    Raises
    ------
    ValueError
        If any ticker has a missing rate of 1.0 (100% missing data).
    """
    # 1. Fatal Structural Check: 100% Missing Data
    # A ticker with no observations cannot be imputed or analyzed.
    fatal_mask = df_missingness_profile["Missing_Rate"] == 1.0

    if fatal_mask.any():
        fatal_rows = df_missingness_profile[fatal_mask]
        raise ValueError(f"Fatal Error: The following tickers have 100% missing data, "
                         f"precluding AR(1) estimation:\n{fatal_rows}")

    # 2. Diagnostic Bounds Check: Manuscript Consistency
    # The manuscript states missingness ranges from 0.758% to 24.56%.
    lower_bound = 0.00758
    upper_bound = 0.2456
    epsilon = 1e-6 # Tolerance for floating-point comparisons

    # Identify rows that fall outside the manuscript's stated range
    out_of_bounds_mask = ~df_missingness_profile["Missing_Rate"].between(
        lower_bound - epsilon, upper_bound + epsilon
    )

    if out_of_bounds_mask.any():
        out_of_bounds_rows = df_missingness_profile[out_of_bounds_mask]
        # Log a warning rather than raising an error, as this is a descriptive range,
        # not a hard mathematical theorem. It flags potential upstream data drift.
        logger.warning(f"Diagnostic Alert: {len(out_of_bounds_rows)} series deviate from the "
                       f"manuscript's missingness range [{lower_bound}, {upper_bound}].\n"
                       f"Sample deviations:\n{out_of_bounds_rows.head()}")

    logger.info("Successfully validated missingness bounds. No fatal structural missingness detected.")
    return df_missingness_profile

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Step 3: Validate missingness co-occurs with zero item counts
# -------------------------------------------------------------------------------------------------------------------------------
def audit_missingness_semantics(aligned_report: Any) -> None:
    """
    Audits the logical implication: x_{i,t} == NaN => K_{i,t} == 0.

    This function quantifies the instances where the vendor feed failed to provide a
    sentiment score despite non-zero item counts. These are expected exceptions
    (vendor feed absence) and are logged for methodological transparency.

    Parameters
    ----------
    aligned_report : AlignedSentimentReport
        The dataclass containing the aligned long-form DataFrames (from Task 6).
    """
    # Extract the aligned long-form DataFrames
    df_news: pd.DataFrame = aligned_report.df_news_aligned
    df_social: pd.DataFrame = aligned_report.df_social_aligned

    def audit_channel(df: pd.DataFrame, count_col: str, channel_name: str) -> None:
        # We are auditing: Score is NaN AND Count is NOT zero.
        # Due to Cartesian alignment, Count might be NaN. We only care about explicit non-zero counts.
        # Therefore, we check: Score is NaN AND Count is notna AND Count != 0.
        exception_mask = df["Sentiment_Score"].isna() & df[count_col].notna() & (df[count_col] != 0)

        if exception_mask.any():
            exception_count = exception_mask.sum()
            # Aggregate the exceptions by ticker to provide a concise diagnostic summary
            ticker_summary = df[exception_mask].groupby("Ticker").size().sort_values(ascending=False)

            logger.info(f"[{channel_name}] Methodological Audit: {exception_count} observations have NaN sentiment "
                        f"despite explicit non-zero item counts ({count_col} > 0). "
                        f"This is attributed to vendor feed absence. Top affected tickers:\n{ticker_summary.head()}")
        else:
            logger.info(f"[{channel_name}] Methodological Audit: Perfect logical consistency. "
                        f"All NaN sentiment scores co-occur with zero or NaN item counts.")

    # Execute the audit for both channels using their respective count column names
    audit_channel(df_news, "Story_Count_K", "News")
    audit_channel(df_social, "Post_Count_K", "Social")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 8, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class MissingnessProfileReport:
    """
    Immutable data container for the missingness profile artifacts.

    Attributes
    ----------
    df_missingness_profile : pd.DataFrame
        The tidy DataFrame containing exact missing rates per ticker and channel.
    passed_fatal_checks : bool
        Boolean flag indicating that no ticker is 100% missing.
    """
    df_missingness_profile: pd.DataFrame
    passed_fatal_checks: bool


def orchestrate_missingness_profiling(
    aligned_report: Any,
    pivoted_matrices: Any
) -> MissingnessProfileReport:
    """
    Orchestrates Task 8: Profiles missingness and validates against manuscript magnitudes.

    This function executes the profiling steps in a strict Directed Acyclic Graph (DAG)
    order, ensuring that the sparsity of the data is mathematically quantified and
    certified before the pipeline attempts to fit autoregressive models.

    Parameters
    ----------
    aligned_report : AlignedSentimentReport
        The dataclass containing the aligned long-form DataFrames (from Task 6).
    pivoted_matrices : PivotedSentimentMatrices
        The dataclass containing the certified wide-form matrices (from Task 7).

    Returns
    -------
    MissingnessProfileReport
        An immutable dataclass containing the tidy missingness profile.
    """
    logger.info("Starting Task 8 Orchestration: Missingness Profiling and Validation.")

    # Step 1: Compute the exact missing rate for each ticker and channel
    # This translates the wide-form sparsity into a tidy reporting structure
    df_profile = compute_missingness_profile(pivoted_matrices)

    # Step 2: Validate the computed rates against the manuscript's stated bounds
    # This enforces the fatal structural check (no 100% missing tickers)
    df_profile_validated = validate_missingness_bounds(df_profile)

    # Step 3: Audit the logical implication (Score=NaN => K=0) on the long-form data
    # This provides methodological transparency regarding vendor feed absences
    audit_missingness_semantics(aligned_report)

    # Package the validated profile into an immutable dataclass
    report = MissingnessProfileReport(
        df_missingness_profile=df_profile_validated,
        passed_fatal_checks=True
    )

    logger.info("=== Task 8 completed successfully. Missingness profile certified. ===")

    # Return the immutable profiling report
    return report

# %%
# Task 9 — Diagnose AR(1) plausibility via ACF/PACF

# ==============================================================================
# Task 9: Diagnose AR(1) plausibility via ACF/PACF
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 1: Compute ACF and PACF for representative series
# -------------------------------------------------------------------------------------------------------------------------------
def compute_acf_pacf_diagnostics(
    matrix_news: pd.DataFrame,
    matrix_social: pd.DataFrame,
    nlags: int = 10,
    min_obs: int = 30
) -> Dict[str, Dict[str, Dict[str, np.ndarray]]]:
    """
    Computes the sample ACF and PACF for the longest contiguous non-missing segment of each series.

    This function isolates the longest unbroken temporal sequence for each ticker to compute
    autocorrelations without distorting the time topology (which would occur if NaNs were simply dropped).
    This contiguous-segment extraction is an engineering convention marked as UNSPECIFIED IN MANUSCRIPT.

    Parameters
    ----------
    matrix_news : pd.DataFrame
        The wide-form News sentiment matrix of shape (T, n).
    matrix_social : pd.DataFrame
        The wide-form Social Media sentiment matrix of shape (T, n).
    nlags : int, optional
        The number of lags to compute for ACF and PACF, by default 10.
    min_obs : int, optional
        The minimum number of contiguous observations required to compute diagnostics, by default 30.

    Returns
    -------
    Dict[str, Dict[str, Dict[str, np.ndarray]]]
        A nested dictionary containing the ACF, PACF, confidence intervals, and observation counts
        for each channel and ticker.

    Raises
    ------
    TypeError
        If the input matrices are not pandas DataFrames.
    """
    # Enforce strict type checking for the input matrices
    if not isinstance(matrix_news, pd.DataFrame) or not isinstance(matrix_social, pd.DataFrame):
        raise TypeError("Input matrices must be pandas DataFrames.")

    # Initialize the master dictionary to store the diagnostic results
    results: Dict[str, Dict[str, Dict[str, np.ndarray]]] = {"News": {}, "Social": {}}

    # Map the channel names to their respective DataFrame objects for iterative processing
    channels = {"News": matrix_news, "Social": matrix_social}

    # Iterate over each channel and its corresponding matrix
    for channel_name, matrix in channels.items():
        # Iterate over each canonical ticker (column) in the matrix
        for ticker in matrix.columns:
            # Extract the time series for the current ticker
            series = matrix[ticker]

            # Create a boolean mask where True indicates a non-missing (valid) observation
            valid_mask = series.notna()

            # Identify contiguous blocks of valid observations by taking the cumulative sum of the inverted mask
            # Every time a NaN is encountered, the block ID increments, grouping contiguous True values together
            block_ids = (~valid_mask).cumsum()

            # Filter the block IDs to only include those corresponding to valid observations
            valid_blocks = block_ids[valid_mask]

            # Check if there are any valid observations at all
            if valid_blocks.empty:
                # If entirely NaN, record zeroed/NaN diagnostics and continue to the next ticker
                results[channel_name][ticker] = {
                    "acf": np.full(nlags + 1, np.nan),
                    "pacf": np.full(nlags + 1, np.nan),
                    "n_obs": 0
                }
                continue

            # Find the block ID that has the maximum number of contiguous valid observations
            largest_block_id = valid_blocks.value_counts().idxmax()

            # Extract the actual contiguous time series segment corresponding to the largest block
            contiguous_segment = series[block_ids == largest_block_id].values

            # Determine the number of observations in this contiguous segment
            n_obs = len(contiguous_segment)

            # Check if the segment meets the minimum length requirement for statistical validity
            if n_obs < min_obs:
                # Log a warning indicating the segment is too short for reliable ACF/PACF estimation
                logger.warning(f"[{channel_name}] {ticker}: Longest contiguous segment ({n_obs} obs) is below minimum ({min_obs}).")
                # Record NaN diagnostics due to insufficient data
                results[channel_name][ticker] = {
                    "acf": np.full(nlags + 1, np.nan),
                    "pacf": np.full(nlags + 1, np.nan),
                    "n_obs": n_obs
                }
                continue

            try:
                # Compute the Autocorrelation Function (ACF) and its 95% confidence intervals
                # alpha=0.05 requests the confidence intervals; missing='none' is safe as we extracted a contiguous block
                acf_vals, acf_confint = acf(contiguous_segment, nlags=nlags, alpha=0.05, missing='none')

                # Compute the Partial Autocorrelation Function (PACF) and its 95% confidence intervals
                # method='yw' uses Yule-Walker equations, which are robust for standard AR diagnostics
                pacf_vals, pacf_confint = pacf(contiguous_segment, nlags=nlags, alpha=0.05, method='yw')

                # Store the successfully computed arrays and metadata in the results dictionary
                results[channel_name][ticker] = {
                    "acf": acf_vals,
                    "pacf": pacf_vals,
                    "acf_confint": acf_confint,
                    "pacf_confint": pacf_confint,
                    "n_obs": n_obs
                }
            except Exception as e:
                # Catch any numerical instability errors (e.g., zero variance in the segment)
                logger.error(f"[{channel_name}] {ticker}: ACF/PACF computation failed. Details: {str(e)}")
                # Record NaN diagnostics in the event of a numerical failure
                results[channel_name][ticker] = {
                    "acf": np.full(nlags + 1, np.nan),
                    "pacf": np.full(nlags + 1, np.nan),
                    "n_obs": n_obs
                }

    # Log the successful completion of the ACF/PACF computation step
    logger.info("Successfully computed ACF and PACF diagnostics for all contiguous segments.")

    # Return the nested dictionary containing all diagnostic arrays
    return results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Step 2 & 3: Validate AR(1) signature and document non-AR(1) behavior
# -------------------------------------------------------------------------------------------------------------------------------
def evaluate_ar1_signature(acf_pacf_results: Dict[str, Dict[str, Dict[str, np.ndarray]]]) -> pd.DataFrame:
    """
    Evaluates the AR(1) plausibility heuristic and compiles a diagnostic report.

    This function translates the manuscript's qualitative visual check ("tails off") into a
    strict quantitative heuristic: an AR(1) process should exhibit a statistically significant
    PACF at lag 1, and a non-significant (or substantially smaller) PACF at lag 2.
    This heuristic is an engineering convention marked as UNSPECIFIED IN MANUSCRIPT.

    Parameters
    ----------
    acf_pacf_results : Dict[str, Dict[str, Dict[str, np.ndarray]]]
        The nested dictionary containing ACF/PACF arrays generated in Step 1.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing the diagnostic metrics and AR(1) plausibility flags.
    """
    # Initialize an empty list to accumulate the diagnostic records for each series
    records: List[Dict[str, Any]] = []

    # Iterate over the channels (News, Social) in the results dictionary
    for channel, tickers_data in acf_pacf_results.items():
        # Iterate over each ticker and its corresponding diagnostic data
        for ticker, data in tickers_data.items():
            # Extract the number of observations used for the computation
            n_obs = data.get("n_obs", 0)

            # If the data was insufficient or computation failed, record a failure state
            if n_obs == 0 or np.isnan(data["acf"][0]):
                records.append({
                    "Channel": channel,
                    "Ticker": ticker,
                    "N_Obs_Contiguous": n_obs,
                    "Lag1_ACF": np.nan,
                    "Lag1_PACF": np.nan,
                    "Lag2_PACF": np.nan,
                    "Is_AR1_Plausible": False,
                    "Diagnostic_Note": "Insufficient data or numerical failure."
                })
                continue

            # Extract the ACF value at lag 1 (index 1, since index 0 is lag 0 = 1.0)
            lag1_acf = data["acf"][1]
            # Extract the PACF value at lag 1
            lag1_pacf = data["pacf"][1]
            # Extract the PACF value at lag 2
            lag2_pacf = data["pacf"][2]

            # Compute the approximate 95% confidence bound under the null hypothesis of no autocorrelation
            # Equation: CI_bound = 1.96 / sqrt(N)
            ci_bound = 1.96 / np.sqrt(n_obs)

            # Heuristic Condition 1: Is the lag 1 PACF statistically significant?
            lag1_significant = abs(lag1_pacf) > ci_bound

            # Heuristic Condition 2: Is the lag 2 PACF statistically insignificant?
            lag2_insignificant = abs(lag2_pacf) < ci_bound

            # Determine overall AR(1) plausibility based on the strict quantitative heuristic
            is_ar1_plausible = bool(lag1_significant and lag2_insignificant)

            # Formulate a descriptive diagnostic note based on the heuristic evaluation
            if is_ar1_plausible:
                note = "AR(1) signature detected: Significant Lag 1 PACF, insignificant Lag 2 PACF."
            elif not lag1_significant:
                note = "Weak dependence: Lag 1 PACF is not statistically significant."
            else:
                note = "Higher-order dependence: Lag 2 PACF remains statistically significant."

            # Append the evaluated record to the list
            records.append({
                "Channel": channel,
                "Ticker": ticker,
                "N_Obs_Contiguous": n_obs,
                "Lag1_ACF": float(lag1_acf),
                "Lag1_PACF": float(lag1_pacf),
                "Lag2_PACF": float(lag2_pacf),
                "Is_AR1_Plausible": is_ar1_plausible,
                "Diagnostic_Note": note
            })

    # Convert the accumulated list of records into a tidy pandas DataFrame
    df_diagnostics = pd.DataFrame(records)

    # Calculate the percentage of series that passed the AR(1) heuristic for logging
    plausible_count = df_diagnostics["Is_AR1_Plausible"].sum()
    total_valid = len(df_diagnostics[df_diagnostics["N_Obs_Contiguous"] > 0])

    # Log the summary of the diagnostic evaluation
    if total_valid > 0:
        logger.info(f"AR(1) evaluation complete. {plausible_count}/{total_valid} valid series exhibit strict AR(1) signatures.")
    else:
        logger.warning("AR(1) evaluation complete, but no valid series were found.")

    # Return the tidy diagnostic DataFrame
    return df_diagnostics

# -------------------------------------------------------------------------------------------------------------------------------
# Task 9, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class AR1DiagnosticReport:
    """
    Immutable data container for the AR(1) plausibility diagnostic artifacts.

    Attributes
    ----------
    acf_pacf_raw_arrays : Dict[str, Dict[str, Dict[str, np.ndarray]]]
        The nested dictionary containing the raw ACF and PACF arrays and confidence intervals.
    df_ar1_diagnostics : pd.DataFrame
        The tidy DataFrame containing the evaluated AR(1) heuristics and diagnostic notes.
    """
    acf_pacf_raw_arrays: Dict[str, Dict[str, Dict[str, np.ndarray]]]
    df_ar1_diagnostics: pd.DataFrame


def orchestrate_ar1_diagnostics(pivoted_matrices: Any) -> AR1DiagnosticReport:
    """
    Orchestrates Task 9: Diagnoses AR(1) plausibility via ACF/PACF.

    This function executes the diagnostic steps in a strict Directed Acyclic Graph (DAG)
    order. It extracts contiguous segments, computes the autocovariances, and evaluates
    the AR(1) signature heuristic. It acts purely as an observer and does not mutate
    the underlying sentiment data or block the pipeline.

    Parameters
    ----------
    pivoted_matrices : PivotedSentimentMatrices
        The dataclass containing the certified wide-form matrices (from Task 7).

    Returns
    -------
    AR1DiagnosticReport
        An immutable dataclass containing the raw arrays and the tidy diagnostic report.
    """
    logger.info("Starting Task 9 Orchestration: AR(1) Plausibility Diagnostics.")

    # Extract the wide-form matrices from the input dataclass
    matrix_news: pd.DataFrame = pivoted_matrices.matrix_news
    matrix_social: pd.DataFrame = pivoted_matrices.matrix_social

    # Step 1: Compute the sample ACF and PACF for the longest contiguous segment of each series
    # This preserves temporal topology while handling missing data
    acf_pacf_results = compute_acf_pacf_diagnostics(matrix_news, matrix_social)

    # Steps 2 & 3: Evaluate the AR(1) signature heuristic and document non-AR(1) behavior
    # This translates the manuscript's visual check into a strict quantitative report
    df_diagnostics = evaluate_ar1_signature(acf_pacf_results)

    # Package the diagnostic artifacts into an immutable dataclass
    report = AR1DiagnosticReport(
        acf_pacf_raw_arrays=acf_pacf_results,
        df_ar1_diagnostics=df_diagnostics
    )

    logger.info("=== Task 9 completed successfully. AR(1) diagnostics compiled. ===")

    # Return the immutable diagnostic report
    return report

# %%
# Task 10 — Fit AR(1) model and estimate innovation variance (\sigma^2) via stationarity identity (Eqs. 17–18)

# ============================================================================================
# Task 10: Fit AR(1) model and estimate innovation variance sigma^2 via stationarity identity
# ============================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 1: Extract valid adjacent pairs and fit AR(1) model
# -------------------------------------------------------------------------------------------------------------------------------
def extract_and_fit_ar1(
    series: pd.Series,
    min_valid_pairs: int = 30
) -> Tuple[float, float, float, float, int]:
    """
    Extracts strictly adjacent non-missing pairs and fits an AR(1) model via OLS.

    This function implements Equation 17: x_t = o + psi_1 * x_{t-1} + epsilon_t.
    It mathematically guarantees that only consecutive calendar days are paired by
    shifting the series along the continuous master calendar prior to dropping NaNs.
    This prevents the bridging of missing gaps, which would severely bias psi_1.

    Parameters
    ----------
    series : pd.Series
        The time series of sentiment scores for a single ticker, strictly indexed
        by the continuous master calendar.
    min_valid_pairs : int, optional
        The minimum number of valid adjacent pairs required to fit the model, by default 30.

    Returns
    -------
    Tuple[float, float, float, float, int]
        A tuple containing:
        - o (intercept)
        - psi_1 (AR(1) coefficient)
        - mse_resid (empirical residual variance of the OLS fit)
        - var_x (sample variance of the valid x_t array)
        - n_pairs (number of valid adjacent pairs used)

    Raises
    ------
    ValueError
        If the series does not contain enough valid pairs or if OLS fitting fails.
    """
    # Create a DataFrame to align x_t and x_{t-1}
    # Because the index is the continuous master calendar, .shift(1) shifts by exactly
    # one valid trading day. This is the critical step to enforce strict temporal adjacency.
    df_pairs = pd.DataFrame({
        'x_t': series,
        'x_t_1': series.shift(1)
    })

    # Drop rows where either x_t or x_{t-1} is NaN
    # This mathematically isolates only those pairs that are strictly adjacent and observed
    df_valid = df_pairs.dropna()

    # Count the number of valid adjacent pairs
    n_pairs: int = len(df_valid)

    # Enforce the minimum sample size constraint to prevent spurious regressions
    if n_pairs < min_valid_pairs:
        raise ValueError(f"Insufficient valid adjacent pairs ({n_pairs} < {min_valid_pairs}).")

    # Extract the endogenous (y) and exogenous (x) variables as 1D numpy arrays
    y: np.ndarray = df_valid['x_t'].values
    x: np.ndarray = df_valid['x_t_1'].values

    # Compute the sample variance of the valid x_t array (using Bessel's correction, ddof=1)
    # This is required for the theoretical variance identity in Equation 18
    var_x: float = float(np.var(y, ddof=1))

    # Add a constant term to the exogenous variable array to estimate the intercept (o)
    X: np.ndarray = sm.add_constant(x)

    try:
        # Fit the Ordinary Least Squares (OLS) regression model
        model = sm.OLS(y, X)
        results = model.fit()

        # Extract the intercept (o) and the AR(1) coefficient (psi_1)
        # Safely handle cases where the constant is dropped due to collinearity
        if len(results.params) == 2:
            o: float = float(results.params[0])
            psi_1: float = float(results.params[1])
        else:
            o = 0.0
            psi_1 = float(results.params[0])

        # Extract the empirical residual variance (Mean Squared Error of the residuals)
        mse_resid: float = float(results.mse_resid)

    except Exception as e:
        # Catch singular matrix errors or other numerical instabilities
        raise ValueError(f"OLS fitting failed due to numerical instability: {str(e)}")

    # Return the extracted parameters and diagnostics
    return o, psi_1, mse_resid, var_x, n_pairs

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Step 2 & 3: Compute sigma^2 via variance identity and enforce stationarity
# -------------------------------------------------------------------------------------------------------------------------------
def compute_innovation_variance(
    psi_1: float,
    var_x: float,
    mse_resid: float
) -> Tuple[float, bool, str]:
    """
    Computes the innovation variance sigma^2 using the stationary variance identity.

    This function implements Equation 18: Var(x_t) = sigma^2 / (1 - psi_1^2), rearranged as
    sigma^2 = Var(x_t) * (1 - psi_1^2). It enforces the stationarity condition |psi_1| < 1.
    If stationarity is violated, it falls back to the empirical residual variance to prevent
    negative or undefined variances (an engineering convention marked UNSPECIFIED IN MANUSCRIPT).

    Parameters
    ----------
    psi_1 : float
        The estimated AR(1) coefficient.
    var_x : float
        The sample variance of the valid x_t array.
    mse_resid : float
        The empirical residual variance from the OLS fit.

    Returns
    -------
    Tuple[float, bool, str]
        A tuple containing:
        - sigma_2 (the finalized innovation variance)
        - is_stationary (boolean flag indicating if |psi_1| < 1)
        - diagnostic_note (string detailing the computation path or fallback applied)
    """
    # Step 3: Enforce the stationarity sanity check
    is_stationary = abs(psi_1) < 1.0

    if is_stationary:
        # Step 2: Compute sigma^2 using the theoretical variance identity (Equation 18)
        # Equation: sigma^2 = Var(x_t) * (1 - psi_1^2)
        sigma_2 = var_x * (1.0 - (psi_1 ** 2))
        diagnostic_note = "Theoretical identity applied successfully."

        # Safeguard against floating-point inaccuracies that might push sigma_2 slightly below zero
        if sigma_2 <= 0:
            sigma_2 = mse_resid
            diagnostic_note = "Theoretical identity yielded <= 0 due to float precision; fallback to mse_resid applied."
    else:
        # Fallback for non-stationary series (|psi_1| >= 1)
        # The theoretical identity would yield a negative variance, which is mathematically invalid.
        # We use the empirical residual variance from the OLS fit as a robust proxy.
        # [UNSPECIFIED IN MANUSCRIPT]
        sigma_2 = mse_resid
        diagnostic_note = "Stationarity violated (|psi_1| >= 1); fallback to empirical mse_resid applied [UNSPECIFIED IN MANUSCRIPT]."

    # Enforce a strict positivity floor to prevent degenerate Gaussian noise during downstream imputation
    epsilon_floor = 1e-8
    if sigma_2 < epsilon_floor:
        sigma_2 = epsilon_floor
        diagnostic_note += f" Variance floored to {epsilon_floor} to prevent degenerate noise."

    return sigma_2, is_stationary, diagnostic_note

# -------------------------------------------------------------------------------------------------------------------------------
# Task 10, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class AR1EstimationReport:
    """
    Immutable data container for the AR(1) parameter estimation artifacts.

    Attributes
    ----------
    df_ar1_parameters : pd.DataFrame
        A tidy DataFrame containing the estimated AR(1) parameters (o, psi_1, sigma^2)
        for every ticker and channel, ready for use in the stochastic imputation phase.
    """
    df_ar1_parameters: pd.DataFrame


def orchestrate_ar1_variance_estimation(pivoted_matrices: Any) -> AR1EstimationReport:
    """
    Orchestrates Task 10: Fits AR(1) models and estimates innovation variance sigma^2.

    This function executes the estimation steps in a strict Directed Acyclic Graph (DAG)
    order. It iterates over all channels and tickers, extracts valid adjacent pairs, fits
    the OLS models, and computes the theoretical innovation variance while safely handling
    non-stationary edge cases.

    Parameters
    ----------
    pivoted_matrices : PivotedSentimentMatrices
        The dataclass containing the certified wide-form matrices (from Task 7).

    Returns
    -------
    AR1EstimationReport
        An immutable dataclass containing the tidy DataFrame of AR(1) parameters.
    """
    logger.info("Starting Task 10 Orchestration: AR(1) Parameter Estimation (Eqs. 17-18).")

    # Extract the wide-form matrices from the input dataclass
    matrix_news: pd.DataFrame = pivoted_matrices.matrix_news
    matrix_social: pd.DataFrame = pivoted_matrices.matrix_social

    # Map the channel names to their respective DataFrame objects for iterative processing
    channels = {"News": matrix_news, "Social": matrix_social}

    # Initialize an empty list to accumulate the parameter records for each series
    records: List[Dict[str, Any]] = []

    # Iterate over each channel and its corresponding matrix
    for channel_name, matrix in channels.items():
        # Iterate over each canonical ticker (column) in the matrix
        for ticker in matrix.columns:
            # Extract the time series for the current ticker
            series = matrix[ticker]

            try:
                # Step 1: Extract valid adjacent pairs and fit the AR(1) model via OLS
                o, psi_1, mse_resid, var_x, n_pairs = extract_and_fit_ar1(series)

                # Steps 2 & 3: Compute sigma^2 via the variance identity and enforce stationarity
                sigma_2, is_stationary, note = compute_innovation_variance(psi_1, var_x, mse_resid)

                # Append the successfully estimated parameters to the records list
                records.append({
                    "Channel": channel_name,
                    "Ticker": ticker,
                    "Intercept_o": float(o),
                    "AR1_Coefficient_psi1": float(psi_1),
                    "Innovation_Variance_sigma2": float(sigma_2),
                    "Innovation_StdDev_sigma": float(np.sqrt(sigma_2)),
                    "Sample_Variance_varx": float(var_x),
                    "N_Valid_Pairs": n_pairs,
                    "Is_Stationary": is_stationary,
                    "Diagnostic_Note": note
                })

            except ValueError as e:
                # Catch insufficient data or numerical instability errors
                logger.warning(f"[{channel_name}] {ticker}: AR(1) estimation failed. Details: {str(e)}")

                # Append a NaN record to maintain structural completeness for downstream auditing
                records.append({
                    "Channel": channel_name,
                    "Ticker": ticker,
                    "Intercept_o": np.nan,
                    "AR1_Coefficient_psi1": np.nan,
                    "Innovation_Variance_sigma2": np.nan,
                    "Innovation_StdDev_sigma": np.nan,
                    "Sample_Variance_varx": np.nan,
                    "N_Valid_Pairs": 0,
                    "Is_Stationary": False,
                    "Diagnostic_Note": f"Failed: {str(e)}"
                })

    # Convert the accumulated list of records into a tidy pandas DataFrame
    df_parameters = pd.DataFrame(records)

    # Calculate the percentage of series that were successfully estimated for logging
    success_count = df_parameters["Innovation_Variance_sigma2"].notna().sum()
    total_series = len(df_parameters)

    logger.info(f"AR(1) estimation complete. Successfully estimated parameters for {success_count}/{total_series} series.")

    # Package the parameter artifacts into an immutable dataclass
    report = AR1EstimationReport(
        df_ar1_parameters=df_parameters
    )

    logger.info("=== Task 10 completed successfully. AR(1) parameters and sigma^2 locked. ===")

    # Return the immutable estimation report
    return report

# %%
# Task 11 — Impute missing sentiment using exponential decay with additive Gaussian noise (Eq. 16)

# =======================================================================================
# Task 11: Impute missing sentiment using exponential decay with additive Gaussian noise
# =======================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 1: Lock the operational time variable for decay
# -------------------------------------------------------------------------------------------------------------------------------
def compute_decay_components(matrix: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Computes the base value (B) and the operational time variable (Delta) for exponential decay.

    This function mathematically defines Delta_t as the number of master-calendar steps
    since the most recent observed value B_t. It uses vectorized pandas operations to
    efficiently compute these components across the entire T x n matrix.
    Leading NaNs (where no prior B exists) are intentionally left as NaN to prevent
    look-ahead bias [UNSPECIFIED IN MANUSCRIPT].

    Parameters
    ----------
    matrix : pd.DataFrame
        The wide-form sentiment matrix containing missing values (NaNs).

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - B_matrix: DataFrame containing the most recent observed values (forward-filled).
        - delta_matrix: DataFrame containing the discrete count of steps since the last observation.

    Raises
    ------
    TypeError
        If the input matrix is not a pandas DataFrame.
    """
    # Enforce strict type checking
    if not isinstance(matrix, pd.DataFrame):
        raise TypeError("Input matrix must be a pandas DataFrame.")

    # Compute B_t: The most recent available non-missing value prior to time t.
    # The forward-fill (ffill) operation perfectly implements this mathematical requirement.
    # Leading NaNs will remain NaN, which is the mathematically correct behavior.
    B_matrix = matrix.ffill()

    # Compute Delta_t: The number of calendar steps since B_t.
    # First, create a boolean mask where True (1) indicates a missing value.
    isna_mask = matrix.isna()

    # Create grouping blocks to identify contiguous sequences of NaNs.
    # By taking the cumulative sum of the inverted mask (~isna_mask), every valid
    # observation increments the block ID. Thus, a valid observation and all subsequent
    # NaNs share the same block ID.
    blocks = (~isna_mask).cumsum()

    # Group the isna_mask by the blocks and compute the cumulative sum.
    # Because True evaluates to 1, this counts the number of consecutive NaNs within each block,
    # perfectly yielding the discrete time distance Delta_t.
    delta_matrix = isna_mask.groupby(blocks).cumsum()

    logger.debug("Successfully computed B_matrix and delta_matrix for exponential decay.")

    return B_matrix, delta_matrix

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Step 2 & 3: Apply decay imputation with noise and lock stochastic determinism
# -------------------------------------------------------------------------------------------------------------------------------
def apply_stochastic_decay_imputation(
    matrix: pd.DataFrame,
    B_matrix: pd.DataFrame,
    delta_matrix: pd.DataFrame,
    df_ar1_params: pd.DataFrame,
    channel_name: str,
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Applies Equation 16: x_t = B * e^(-lambda * Delta_t) + epsilon_t.

    This function computes the deterministic exponential decay and adds Gaussian noise
    calibrated from the AR(1) innovation variance. It enforces perfect stochastic
    determinism by instantiating a unique, seeded PCG64 random number generator for
    each ticker, preventing parallel execution drift.

    Parameters
    ----------
    matrix : pd.DataFrame
        The original wide-form sentiment matrix containing missing values.
    B_matrix : pd.DataFrame
        The matrix of base values (from Step 1).
    delta_matrix : pd.DataFrame
        The matrix of time distances (from Step 1).
    df_ar1_params : pd.DataFrame
        The tidy DataFrame containing the estimated AR(1) parameters (sigma).
    channel_name : str
        The name of the channel ("News" or "Social") for parameter filtering and seed derivation.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing lambda and RNG seeds.

    Returns
    -------
    pd.DataFrame
        The fully imputed sentiment matrix. Observed values remain strictly untouched.

    Raises
    ------
    KeyError
        If required configuration parameters are missing.
    """
    # Extract the decay rate lambda (0.23) from the configuration
    lambda_decay = study_configuration["imputation_parameters"]["decay_rate_lambda"]

    # Extract the global seed and the specific offset for imputation noise
    global_seed = study_configuration["reproducibility"]["global_random_seed"]
    imputation_offset = study_configuration["reproducibility"]["seed_partitioning"]["imputation_noise_seed_offset"]

    # Calculate the base seed for this specific stochastic process
    base_seed = global_seed + imputation_offset

    # Define a channel-specific integer offset to ensure News and Social streams are independent
    channel_offset = 10000 if channel_name == "Social" else 0

    # Initialize an empty DataFrame to hold the generated Gaussian noise
    noise_matrix = pd.DataFrame(index=matrix.index, columns=matrix.columns, dtype=float)

    # Iterate over each canonical ticker to generate deterministic, parallel-safe noise
    for i, ticker in enumerate(matrix.columns):
        # Derive a strictly deterministic seed for this specific ticker and channel
        ticker_seed = base_seed + channel_offset + i

        # Instantiate a modern, robust PCG64 random number generator
        rng = np.random.Generator(np.random.PCG64(ticker_seed))

        # Extract the innovation standard deviation (sigma) for this ticker/channel
        param_row = df_ar1_params[(df_ar1_params["Channel"] == channel_name) & (df_ar1_params["Ticker"] == ticker)]

        if param_row.empty or pd.isna(param_row["Innovation_StdDev_sigma"].iloc[0]):
            # If AR(1) estimation failed, we cannot generate mathematically valid noise.
            # Leave the noise as NaN. The imputation will subsequently yield NaN.
            noise_matrix[ticker] = np.nan
            logger.warning(f"[{channel_name}] {ticker}: Missing sigma. Imputation will be bypassed for this ticker.")
        else:
            # Extract the scalar sigma value
            sigma = param_row["Innovation_StdDev_sigma"].iloc[0]

            # Generate the Gaussian noise vector: epsilon_t ~ N(0, sigma^2)
            noise_matrix[ticker] = rng.normal(loc=0.0, scale=sigma, size=len(matrix))

    # Compute the deterministic exponential decay component: B * e^(-lambda * Delta_t)
    # np.exp is fully vectorized and highly optimized
    decay_component = B_matrix * np.exp(-lambda_decay * delta_matrix)

    # Compute the final imputed values by adding the stochastic noise
    imputed_values = decay_component + noise_matrix

    # Apply the imputed values ONLY to the missing slots in the original matrix.
    # The fillna() method mathematically guarantees that original observed values are untouched.
    matrix_imputed = matrix.fillna(imputed_values)

    logger.info(f"Successfully applied stochastic decay imputation (Eq. 16) for {channel_name}.")

    return matrix_imputed

# -------------------------------------------------------------------------------------------------------------------------------
# Task 11, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class ImputedSentimentReport:
    """
    Immutable data container for the fully imputed sentiment matrices.

    Attributes
    ----------
    matrix_news_imputed : pd.DataFrame
        The wide-form News sentiment matrix with missing values stochastically imputed.
    matrix_social_imputed : pd.DataFrame
        The wide-form Social Media sentiment matrix with missing values stochastically imputed.
    mask_news_imputed : pd.DataFrame
        A boolean DataFrame indicating which values in the News matrix were imputed (True).
    mask_social_imputed : pd.DataFrame
        A boolean DataFrame indicating which values in the Social matrix were imputed (True).
    """
    matrix_news_imputed: pd.DataFrame
    matrix_social_imputed: pd.DataFrame
    mask_news_imputed: pd.DataFrame
    mask_social_imputed: pd.DataFrame


def orchestrate_stochastic_imputation(
    pivoted_matrices: Any,
    ar1_report: Any,
    study_configuration: Dict[str, Any]
) -> ImputedSentimentReport:
    """
    Orchestrates Task 11: Imputes missing sentiment using exponential decay with noise.

    This function executes the imputation steps in a strict Directed Acyclic Graph (DAG)
    order. It computes the operational time variables, generates deterministic Gaussian
    noise, and applies Equation 16 independently to both the News and Social media channels.

    Parameters
    ----------
    pivoted_matrices : PivotedSentimentMatrices
        The dataclass containing the certified wide-form matrices (from Task 7).
    ar1_report : AR1EstimationReport
        The dataclass containing the estimated AR(1) parameters (from Task 10).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    ImputedSentimentReport
        An immutable dataclass containing the imputed matrices and their boolean masks.
    """
    logger.info("Starting Task 11 Orchestration: Stochastic Decay Imputation (Eq. 16).")

    # Extract the wide-form matrices and the AR(1) parameter DataFrame
    matrix_news: pd.DataFrame = pivoted_matrices.matrix_news
    matrix_social: pd.DataFrame = pivoted_matrices.matrix_social
    df_ar1_params: pd.DataFrame = ar1_report.df_ar1_parameters

    # --- Process News Channel ---
    # Step 1: Compute B_t and Delta_t
    B_news, delta_news = compute_decay_components(matrix_news)

    # Steps 2 & 3: Apply Equation 16 with deterministic RNG
    matrix_news_imputed = apply_stochastic_decay_imputation(
        matrix=matrix_news,
        B_matrix=B_news,
        delta_matrix=delta_news,
        df_ar1_params=df_ar1_params,
        channel_name="News",
        study_configuration=study_configuration
    )

    # Generate a boolean mask identifying exactly which values were imputed
    # This is critical for downstream diagnostic transparency
    mask_news_imputed = matrix_news.isna() & matrix_news_imputed.notna()

    # --- Process Social Media Channel ---
    # Step 1: Compute B_t and Delta_t
    B_social, delta_social = compute_decay_components(matrix_social)

    # Steps 2 & 3: Apply Equation 16 with deterministic RNG
    matrix_social_imputed = apply_stochastic_decay_imputation(
        matrix=matrix_social,
        B_matrix=B_social,
        delta_matrix=delta_social,
        df_ar1_params=df_ar1_params,
        channel_name="Social",
        study_configuration=study_configuration
    )

    # Generate a boolean mask identifying exactly which values were imputed
    mask_social_imputed = matrix_social.isna() & matrix_social_imputed.notna()

    # Package the imputed artifacts into an immutable dataclass
    report = ImputedSentimentReport(
        matrix_news_imputed=matrix_news_imputed,
        matrix_social_imputed=matrix_social_imputed,
        mask_news_imputed=mask_news_imputed,
        mask_social_imputed=mask_social_imputed
    )

    logger.info("=== Task 11 completed successfully. Missing data stochastically imputed. ===")

    # Return the immutable imputation report
    return report

# %%
# Task 12 — Post-imputation diagnostics: stationarity and non-normality validation (paper gates)

# ================================================================================
# Task 12: Post-imputation diagnostics: stationarity and non-normality validation
# ================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 1: Run Augmented Dickey-Fuller tests on imputed series
# -------------------------------------------------------------------------------------------------------------------------------
def execute_adf_test(valid_array: np.ndarray) -> Tuple[float, float, int, bool]:
    """
    Executes the Augmented Dickey-Fuller (ADF) test to evaluate stationarity.

    This function tests the null hypothesis that a unit root is present in the time series.
    It uses a constant deterministic term and AIC for lag selection [UNSPECIFIED IN MANUSCRIPT].
    Rejection of the null hypothesis (p < 0.05) indicates stationarity, aligning with the
    manuscript's reported findings.

    Parameters
    ----------
    valid_array : np.ndarray
        A 1D numpy array of contiguous, non-missing imputed sentiment scores.

    Returns
    -------
    Tuple[float, float, int, bool]
        A tuple containing:
        - adf_stat (the test statistic)
        - p_value (the MacKinnon approximate p-value)
        - used_lag (the number of lags used in the regression)
        - is_stationary (boolean flag indicating if p < 0.05)

    Raises
    ------
    ValueError
        If the array is too short or constant, causing the statsmodels implementation to fail.
    """
    try:
        # Execute the ADF test using standard econometric defaults
        # regression='c' includes a constant; autolag='AIC' selects the optimal lag length
        adf_result = adfuller(valid_array, regression='c', autolag='AIC')

        adf_stat = float(adf_result[0])
        p_value = float(adf_result[1])
        used_lag = int(adf_result[2])

        # Evaluate stationarity based on a standard alpha = 0.05 threshold
        is_stationary = p_value < 0.05

        return adf_stat, p_value, used_lag, is_stationary

    except Exception as e:
        # Catch numerical instabilities (e.g., perfectly constant arrays)
        raise ValueError(f"ADF test failed: {str(e)}")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 2: Run Shapiro-Wilk tests on imputed series
# -------------------------------------------------------------------------------------------------------------------------------
def execute_shapiro_wilk_test(valid_array: np.ndarray) -> Tuple[float, float, bool]:
    """
    Executes the Shapiro-Wilk test to evaluate non-normality.

    This function tests the null hypothesis that the data was drawn from a normal distribution.
    Rejection of the null hypothesis (p < 0.05) indicates non-normality, aligning with the
    manuscript's reported findings regarding the fat-tailed nature of sentiment data.

    Parameters
    ----------
    valid_array : np.ndarray
        A 1D numpy array of contiguous, non-missing imputed sentiment scores.

    Returns
    -------
    Tuple[float, float, bool]
        A tuple containing:
        - shapiro_stat (the test statistic)
        - p_value (the p-value for the hypothesis test)
        - is_non_normal (boolean flag indicating if p < 0.05)

    Raises
    ------
    ValueError
        If the array is too short (N < 3) or constant, causing the scipy implementation to fail.
    """
    try:
        # Execute the Shapiro-Wilk test
        shapiro_result = stats.shapiro(valid_array)

        shapiro_stat = float(shapiro_result.statistic)
        p_value = float(shapiro_result.pvalue)

        # Evaluate non-normality based on a standard alpha = 0.05 threshold
        is_non_normal = p_value < 0.05

        return shapiro_stat, p_value, is_non_normal

    except Exception as e:
        # Catch numerical instabilities (e.g., N < 3)
        raise ValueError(f"Shapiro-Wilk test failed: {str(e)}")

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Step 3: Validate post-imputation values remain in plausible range
# -------------------------------------------------------------------------------------------------------------------------------
def validate_imputation_bounds(valid_array: np.ndarray, epsilon: float = 1e-9) -> Tuple[float, float, int, float]:
    """
    Audits the imputed array to quantify values falling outside the theoretical [-1, 1] bounds.

    The additive Gaussian noise from Equation 16 can mathematically push values outside the
    original Bloomberg sentiment range. This function strictly observes and reports these
    occurrences without silently clipping the data, preserving methodological transparency.

    Parameters
    ----------
    valid_array : np.ndarray
        A 1D numpy array of contiguous, non-missing imputed sentiment scores.
    epsilon : float, optional
        Tolerance for floating-point arithmetic comparisons, by default 1e-9.

    Returns
    -------
    Tuple[float, float, int, float]
        A tuple containing:
        - min_val (the minimum value in the array)
        - max_val (the maximum value in the array)
        - out_of_bounds_count (number of observations outside [-1, 1])
        - out_of_bounds_prop (proportion of observations outside [-1, 1])
    """
    # Compute the absolute minimum and maximum values
    min_val = float(np.min(valid_array))
    max_val = float(np.max(valid_array))

    # Create a boolean mask for values strictly outside the [-1.0, 1.0] interval, accounting for float precision
    out_of_bounds_mask = (valid_array < -1.0 - epsilon) | (valid_array > 1.0 + epsilon)

    # Count the number of out-of-bounds observations
    out_of_bounds_count = int(np.sum(out_of_bounds_mask))

    # Calculate the proportion relative to the valid array length
    out_of_bounds_prop = float(out_of_bounds_count / len(valid_array)) if len(valid_array) > 0 else 0.0

    return min_val, max_val, out_of_bounds_count, out_of_bounds_prop

# -------------------------------------------------------------------------------------------------------------------------------
# Task 12, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class PostImputationDiagnosticReport:
    """
    Immutable data container for the post-imputation diagnostic artifacts.

    Attributes
    ----------
    df_diagnostics : pd.DataFrame
        A comprehensive tidy DataFrame containing the ADF, Shapiro-Wilk, and bounds
        validation metrics for every ticker and channel.
    """
    df_diagnostics: pd.DataFrame


def orchestrate_post_imputation_diagnostics(imputed_report: Any) -> PostImputationDiagnosticReport:
    """
    Orchestrates Task 12: Post-imputation diagnostics (stationarity and non-normality).

    This function executes the diagnostic steps in a strict Directed Acyclic Graph (DAG)
    order. It iterates over all channels and tickers, extracts the valid imputed arrays,
    and applies the ADF, Shapiro-Wilk, and bounds validation tests. It acts purely as an
    observer and does not mutate the underlying imputed sentiment data.

    Parameters
    ----------
    imputed_report : ImputedSentimentReport
        The dataclass containing the fully imputed matrices (from Task 11).

    Returns
    -------
    PostImputationDiagnosticReport
        An immutable dataclass containing the comprehensive diagnostic DataFrame.
    """
    logger.info("Starting Task 12 Orchestration: Post-Imputation Diagnostics (Paper Gates).")

    # Extract the imputed wide-form matrices from the input dataclass
    matrix_news: pd.DataFrame = imputed_report.matrix_news_imputed
    matrix_social: pd.DataFrame = imputed_report.matrix_social_imputed

    # Map the channel names to their respective DataFrame objects for iterative processing
    channels = {"News": matrix_news, "Social": matrix_social}

    # Initialize an empty list to accumulate the diagnostic records for each series
    records: List[Dict[str, Any]] = []

    # Iterate over each channel and its corresponding matrix
    for channel_name, matrix in channels.items():
        # Iterate over each canonical ticker (column) in the matrix
        for ticker in matrix.columns:
            # Extract the time series and drop any remaining NaNs (e.g., leading NaNs)
            # This ensures the statistical tests receive a contiguous, valid numerical array
            valid_series = matrix[ticker].dropna()
            valid_array = valid_series.values
            n_obs = len(valid_array)

            # Initialize a default record structure
            record = {
                "Channel": channel_name,
                "Ticker": ticker,
                "N_Valid_Obs": n_obs,
                "ADF_Stat": np.nan,
                "ADF_P_Value": np.nan,
                "Is_Stationary": False,
                "Shapiro_Stat": np.nan,
                "Shapiro_P_Value": np.nan,
                "Is_Non_Normal": False,
                "Min_Value": np.nan,
                "Max_Value": np.nan,
                "Out_Of_Bounds_Count": 0,
                "Out_Of_Bounds_Prop": 0.0,
                "Diagnostic_Note": ""
            }

            if n_obs < 10:
                record["Diagnostic_Note"] = "Insufficient valid observations for statistical testing."
                records.append(record)
                continue

            notes = []

            # Step 1: Execute the Augmented Dickey-Fuller test
            try:
                adf_stat, adf_p, used_lag, is_stat = execute_adf_test(valid_array)
                record["ADF_Stat"] = adf_stat
                record["ADF_P_Value"] = adf_p
                record["Is_Stationary"] = is_stat
                if not is_stat:
                    notes.append("Failed to reject ADF null (Unit Root present).")
            except ValueError as e:
                notes.append(f"ADF Error: {str(e)}")

            # Step 2: Execute the Shapiro-Wilk test
            try:
                shap_stat, shap_p, is_non_norm = execute_shapiro_wilk_test(valid_array)
                record["Shapiro_Stat"] = shap_stat
                record["Shapiro_P_Value"] = shap_p
                record["Is_Non_Normal"] = is_non_norm
                if not is_non_norm:
                    notes.append("Failed to reject Shapiro null (Data may be normal).")
            except ValueError as e:
                notes.append(f"Shapiro Error: {str(e)}")

            # Step 3: Validate imputation bounds
            min_val, max_val, oob_count, oob_prop = validate_imputation_bounds(valid_array)
            record["Min_Value"] = min_val
            record["Max_Value"] = max_val
            record["Out_Of_Bounds_Count"] = oob_count
            record["Out_Of_Bounds_Prop"] = oob_prop

            if oob_count > 0:
                notes.append(f"{oob_count} values outside [-1, 1] bounds.")

            # Compile any diagnostic notes
            if notes:
                record["Diagnostic_Note"] = " | ".join(notes)
            else:
                record["Diagnostic_Note"] = "All paper gates passed successfully."

            # Append the finalized record to the list
            records.append(record)

    # Convert the accumulated list of records into a tidy pandas DataFrame
    df_diagnostics = pd.DataFrame(records)

    # Calculate summary statistics for logging
    total_series = len(df_diagnostics)
    stat_count = df_diagnostics["Is_Stationary"].sum()
    non_norm_count = df_diagnostics["Is_Non_Normal"].sum()
    oob_series_count = (df_diagnostics["Out_Of_Bounds_Count"] > 0).sum()

    logger.info(f"Diagnostics complete. Stationarity confirmed for {stat_count}/{total_series} series.")
    logger.info(f"Non-normality confirmed for {non_norm_count}/{total_series} series.")
    if oob_series_count > 0:
        logger.warning(f"{oob_series_count} series contain values outside the [-1, 1] bounds due to additive noise.")

    # Package the diagnostic artifacts into an immutable dataclass
    report = PostImputationDiagnosticReport(
        df_diagnostics=df_diagnostics
    )

    logger.info("=== Task 12 completed successfully. Post-imputation diagnostics compiled. ===")

    # Return the immutable diagnostic report
    return report

# %%
# Task 13 — Discretize sentiment into 3 symbolic states via quantile discretization (Eq. 1)

# =================================================================================
# Task 13: Discretize sentiment into 3 symbolic states via quantile discretization
# =================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 1: Lock quantile cut points and scope
# -------------------------------------------------------------------------------------------------------------------------------
def compute_windowed_quantiles(
    matrix_news: pd.DataFrame,
    matrix_social: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> Dict[str, Dict[int, pd.DataFrame]]:
    """
    Computes the q1 (33.33%) and q2 (66.67%) cut points per ticker, per rolling window.

    This function enforces the "per_rolling_window" scope defined in the configuration.
    It dynamically generates the window slices based on L=200 and s=10, and computes
    the quantiles using only the valid (non-NaN) observations within that specific window,
    preventing look-ahead bias.

    Parameters
    ----------
    matrix_news : pd.DataFrame
        The fully imputed wide-form News sentiment matrix.
    matrix_social : pd.DataFrame
        The fully imputed wide-form Social Media sentiment matrix.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing L, s, and quantile levels.

    Returns
    -------
    Dict[str, Dict[int, pd.DataFrame]]
        A nested dictionary mapping Channel -> Window ID -> DataFrame of cut points.
        The cut point DataFrame has index=Tickers and columns=['q1', 'q2'].

    Raises
    ------
    KeyError
        If required configuration parameters are missing.
    """
    # Extract architectural parameters
    L = study_configuration["network_architecture"]["rolling_window_length_L"]
    s = study_configuration["network_architecture"]["step_size_s"]
    T = len(matrix_news)

    # Extract quantile levels
    q1_level = study_configuration["discretization_parameters"]["quantile_levels"]["q1"]
    q2_level = study_configuration["discretization_parameters"]["quantile_levels"]["q2"]

    # Mathematically derive the total number of rolling windows (W)
    W = ((T - L) // s) + 1

    # Initialize the output dictionary
    cut_points: Dict[str, Dict[int, pd.DataFrame]] = {"News": {}, "Social": {}}
    channels = {"News": matrix_news, "Social": matrix_social}

    # Iterate over each channel
    for channel_name, matrix in channels.items():
        # Iterate over each window ID (1-indexed to match mathematical notation)
        for w in range(1, W + 1):
            # Calculate the zero-based start and end indices for the current window slice
            start_idx = (w - 1) * s
            end_idx = start_idx + L

            # Extract the L x n sub-matrix for the current window
            window_slice = matrix.iloc[start_idx:end_idx]

            # Compute the quantiles column-wise (axis=0). pandas .quantile() safely ignores NaNs.
            # The result is a Series indexed by the canonical tickers.
            q1_series = window_slice.quantile(q=q1_level, axis=0)
            q2_series = window_slice.quantile(q=q2_level, axis=0)

            # Combine the series into a DataFrame
            df_cuts = pd.DataFrame({"q1": q1_series, "q2": q2_series})

            # Store in the nested dictionary
            cut_points[channel_name][w] = df_cuts

            # Diagnostic check: Flag instances where q1 == q2 (highly concentrated distributions)
            degenerate_cuts = df_cuts[df_cuts["q1"] == df_cuts["q2"]]
            if not degenerate_cuts.empty:
                logger.debug(f"[{channel_name}] Window {w}: {len(degenerate_cuts)} tickers have q1 == q2.")

    logger.info(f"Successfully computed windowed quantiles for {W} windows across both channels.")
    return cut_points

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 2: Encode each observation using Equation 1
# -------------------------------------------------------------------------------------------------------------------------------
def encode_symbolic_states(
    matrix_news: pd.DataFrame,
    matrix_social: pd.DataFrame,
    cut_points: Dict[str, Dict[int, pd.DataFrame]],
    study_configuration: Dict[str, Any]
) -> Dict[str, Dict[int, pd.DataFrame]]:
    """
    Applies Equation 1 to map continuous sentiment scores into discrete states {1, 2, 3}.

    This function applies the strict inequalities defined in the manuscript:
    Z = 1 for z_t <= q1; Z = 2 for q1 < z_t < q2; Z = 3 for z_t >= q2.
    The encoding is performed independently for each rolling window using that window's
    specific cut points, returning a collection of window-specific symbolic matrices.

    Parameters
    ----------
    matrix_news : pd.DataFrame
        The fully imputed wide-form News sentiment matrix.
    matrix_social : pd.DataFrame
        The fully imputed wide-form Social Media sentiment matrix.
    cut_points : Dict[str, Dict[int, pd.DataFrame]]
        The nested dictionary of window-specific cut points (from Step 1).
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing L and s.

    Returns
    -------
    Dict[str, Dict[int, pd.DataFrame]]
        A nested dictionary mapping Channel -> Window ID -> Encoded DataFrame (L x n).
    """
    # Extract architectural parameters
    L = study_configuration["network_architecture"]["rolling_window_length_L"]
    s = study_configuration["network_architecture"]["step_size_s"]
    W = ((len(matrix_news) - L) // s) + 1

    # Initialize the output dictionary
    encoded_matrices: Dict[str, Dict[int, pd.DataFrame]] = {"News": {}, "Social": {}}
    channels = {"News": matrix_news, "Social": matrix_social}

    # Iterate over each channel
    for channel_name, matrix in channels.items():
        # Iterate over each window ID
        for w in range(1, W + 1):
            # Calculate the zero-based start and end indices
            start_idx = (w - 1) * s
            end_idx = start_idx + L

            # Extract the continuous L x n sub-matrix
            window_slice = matrix.iloc[start_idx:end_idx]

            # Extract the q1 and q2 vectors for this specific window
            df_cuts = cut_points[channel_name][w]
            q1_vec = df_cuts["q1"].values
            q2_vec = df_cuts["q2"].values

            # Extract the underlying numpy array for efficient vectorized conditional logic
            z_t = window_slice.values

            # Define the strict mathematical conditions from Equation 1
            # Broadcasting compares the (L x n) matrix against the (n,) quantile vectors
            cond_1 = z_t <= q1_vec
            cond_2 = (z_t > q1_vec) & (z_t < q2_vec)
            cond_3 = z_t >= q2_vec

            # Define the corresponding symbolic states
            choices = [1.0, 2.0, 3.0]

            # Apply the conditions. Values failing all conditions (i.e., NaNs) default to np.nan.
            # We use float dtype to safely accommodate np.nan without casting issues.
            encoded_array = np.select([cond_1, cond_2, cond_3], choices, default=np.nan)

            # Reconstruct the pandas DataFrame, preserving the exact temporal index and canonical columns
            df_encoded = pd.DataFrame(
                encoded_array,
                index=window_slice.index,
                columns=window_slice.columns
            )

            # Store the encoded matrix in the nested dictionary
            encoded_matrices[channel_name][w] = df_encoded

    logger.info("Successfully encoded continuous sentiment into symbolic states (Eq. 1).")
    return encoded_matrices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Step 3: Validate symbol support and approximate balance
# -------------------------------------------------------------------------------------------------------------------------------
def validate_symbolic_support(encoded_matrices: Dict[str, Dict[int, pd.DataFrame]]) -> pd.DataFrame:
    """
    Validates the support set {1, 2, 3} and computes the empirical Probability Mass Function.

    This function audits every encoded series to ensure no invalid symbols exist. It computes
    the normalized frequencies of states 1, 2, and 3. If any state has a probability of 0.0,
    the window is flagged as 'Is_Degenerate', providing critical metadata for downstream
    Transfer Entropy estimation.

    Parameters
    ----------
    encoded_matrices : Dict[str, Dict[int, pd.DataFrame]]
        The nested dictionary of window-specific symbolic matrices (from Step 2).

    Returns
    -------
    pd.DataFrame
        A tidy diagnostic DataFrame containing the PMF and degeneracy flags.

    Raises
    ------
    ValueError
        If any non-NaN symbol outside the set {1.0, 2.0, 3.0} is detected.
    """
    records: List[Dict[str, Any]] = []

    # Define the strict mathematical support set
    valid_support = {1.0, 2.0, 3.0}

    # Iterate over channels, windows, and tickers
    for channel_name, windows in encoded_matrices.items():
        for w, df_encoded in windows.items():
            for ticker in df_encoded.columns:
                # Extract the series and drop NaNs
                series = df_encoded[ticker].dropna()
                n_valid = len(series)

                if n_valid == 0:
                    # Handle the edge case of an entirely missing window
                    records.append({
                        "Channel": channel_name,
                        "Window_ID": w,
                        "Ticker": ticker,
                        "N_Valid_Obs": 0,
                        "P_State_1": np.nan,
                        "P_State_2": np.nan,
                        "P_State_3": np.nan,
                        "Is_Degenerate": True
                    })
                    continue

                # Extract unique symbols
                unique_symbols = set(series.unique())

                # Enforce strict support set validation
                if not unique_symbols.issubset(valid_support):
                    invalid_syms = unique_symbols - valid_support
                    raise ValueError(f"[{channel_name}] Window {w}, Ticker {ticker}: Invalid symbols detected: {invalid_syms}")

                # Compute the empirical PMF (normalized value counts)
                # Reindex to [1.0, 2.0, 3.0] and fill missing with 0.0 to ensure a complete probability vector
                pmf = series.value_counts(normalize=True).reindex([1.0, 2.0, 3.0], fill_value=0.0)

                p1, p2, p3 = pmf[1.0], pmf[2.0], pmf[3.0]

                # Flag degeneracy if any state is entirely absent
                is_degenerate = (p1 == 0.0) or (p2 == 0.0) or (p3 == 0.0)

                records.append({
                    "Channel": channel_name,
                    "Window_ID": w,
                    "Ticker": ticker,
                    "N_Valid_Obs": n_valid,
                    "P_State_1": float(p1),
                    "P_State_2": float(p2),
                    "P_State_3": float(p3),
                    "Is_Degenerate": is_degenerate
                })

    # Convert the accumulated records into a tidy pandas DataFrame
    df_diagnostics = pd.DataFrame(records)

    # Calculate summary statistics for logging
    total_series = len(df_diagnostics)
    degenerate_count = df_diagnostics["Is_Degenerate"].sum()

    logger.info(f"Symbolic validation complete. {degenerate_count}/{total_series} window-series exhibit state degeneracy.")

    return df_diagnostics

# -------------------------------------------------------------------------------------------------------------------------------
# Task 13, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class SymbolicEncodingReport:
    """
    Immutable data container for the symbolic encoding artifacts.

    Attributes
    ----------
    encoded_matrices : Dict[str, Dict[int, pd.DataFrame]]
        The nested dictionary mapping Channel -> Window ID -> Encoded DataFrame (L x n).
    df_encoding_diagnostics : pd.DataFrame
        The tidy DataFrame containing the empirical PMF and degeneracy flags.
    """
    encoded_matrices: Dict[str, Dict[int, pd.DataFrame]]
    df_encoding_diagnostics: pd.DataFrame


def orchestrate_quantile_discretization(
    imputed_report: Any,
    study_configuration: Dict[str, Any]
) -> SymbolicEncodingReport:
    """
    Orchestrates Task 13: Discretizes sentiment into 3 symbolic states (Eq. 1).

    This function executes the discretization steps in a strict Directed Acyclic Graph (DAG)
    order. It computes window-specific quantiles, applies the strict inequalities of Equation 1,
    and validates the resulting symbolic support set, ensuring the data is perfectly formatted
    for Information Theoretic estimation.

    Parameters
    ----------
    imputed_report : ImputedSentimentReport
        The dataclass containing the fully imputed matrices (from Task 11).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    SymbolicEncodingReport
        An immutable dataclass containing the encoded matrices and diagnostic report.
    """
    logger.info("Starting Task 13 Orchestration: Quantile Discretization (Eq. 1).")

    # Extract the imputed wide-form matrices from the input dataclass
    matrix_news: pd.DataFrame = imputed_report.matrix_news_imputed
    matrix_social: pd.DataFrame = imputed_report.matrix_social_imputed

    # Step 1: Compute the q1 and q2 cut points per ticker, per rolling window
    # This enforces the local scope required to maintain state balance over time
    cut_points = compute_windowed_quantiles(matrix_news, matrix_social, study_configuration)

    # Step 2: Encode the continuous observations into discrete states {1, 2, 3}
    # This applies the strict mathematical inequalities defined in Equation 1
    encoded_matrices = encode_symbolic_states(matrix_news, matrix_social, cut_points, study_configuration)

    # Step 3: Validate the support set and compute the empirical PMF
    # This audits the encoding and flags degenerate windows for downstream TE handling
    df_diagnostics = validate_symbolic_support(encoded_matrices)

    # Package the encoding artifacts into an immutable dataclass
    report = SymbolicEncodingReport(
        encoded_matrices=encoded_matrices,
        df_encoding_diagnostics=df_diagnostics
    )

    logger.info("=== Task 13 completed successfully. Sentiment discretized into symbolic states. ===")

    # Return the immutable encoding report
    return report

# %%
# Task 14 — Validate lag calibration via conditional entropy (Eq. 3)

# ===================================================================================
# Task 14: Validate lag calibration via conditional entropy (Eq. 3) to justify k=l=1
# ===================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 1: Define conditional entropy as in the manuscript
# -------------------------------------------------------------------------------------------------------------------------------
def compute_conditional_entropy(symbolic_series: np.ndarray, k: int) -> float:
    """
    Computes the conditional entropy H(z_{t+1} | z_t^{(k)}) using empirical frequencies.

    This function implements Equation 3: H(z_{t+1} | z_t^{(k)}) = H(z_{t+1}, z_t^{(k)}) - H(z_t^{(k)}).
    It uses a memory-efficient sliding window to extract overlapping sequences of length k+1.
    The base of the logarithm is strictly 2, measuring information in bits.

    Parameters
    ----------
    symbolic_series : np.ndarray
        A 1D numpy array containing the discrete symbolic states {1, 2, 3}.
    k : int
        The lag length (number of historical observations to condition on).

    Returns
    -------
    float
        The conditional entropy in bits. Returns 0.0 if the series is too short.

    Raises
    ------
    ValueError
        If k is less than 1.
    """
    if k < 1:
        raise ValueError("Lag length k must be strictly positive (k >= 1).")

    n_obs = len(symbolic_series)
    window_size = k + 1

    # If the series is shorter than the required window, entropy cannot be computed
    if n_obs < window_size:
        return 0.0

    # Create a memory-efficient, vectorized view of the overlapping sequences of length k+1
    # Shape: (n_obs - k, k + 1)
    windows = sliding_window_view(symbolic_series, window_shape=window_size)

    # The full window represents the joint state (z_{t+1}, z_t^{(k)})
    # We convert rows to tuples to make them hashable for counting
    joint_states = [tuple(row) for row in windows]

    # The prefix of length k represents the historical state z_t^{(k)}
    # We slice all rows, up to the second-to-last column
    history_states = [tuple(row[:-1]) for row in windows]

    # Count the empirical frequencies of the joint states and historical states
    joint_counts = Counter(joint_states)
    history_counts = Counter(history_states)

    # Total number of valid windows
    total_windows = float(len(windows))

    # Compute Joint Entropy: H(z_{t+1}, z_t^{(k)}) = - sum p * log2(p)
    # We only iterate over observed states, mathematically bypassing p=0 where log2(0) is undefined
    h_joint = 0.0
    for count in joint_counts.values():
        p = count / total_windows
        h_joint -= p * np.log2(p)

    # Compute Marginal Historical Entropy: H(z_t^{(k)}) = - sum p * log2(p)
    h_history = 0.0
    for count in history_counts.values():
        p = count / total_windows
        h_history -= p * np.log2(p)

    # Apply the identity from Equation 3
    conditional_entropy = h_joint - h_history

    # Safeguard against floating-point inaccuracies yielding slightly negative entropy
    return max(0.0, conditional_entropy)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 2: Replicate the calibration simulation study
# -------------------------------------------------------------------------------------------------------------------------------
def replicate_calibration_simulation(global_seed: int) -> pd.DataFrame:
    """
    Replicates the calibration study to observe conditional entropy decay against lag length.

    This function simulates an AR(1) process for various sample sizes, discretizes the
    continuous series into 3 states using empirical tertiles, and computes the conditional
    entropy across lags k=1 to k=9. The AR(1) parameters (psi_1=0.5, sigma=1.0) are
    engineering defaults [UNSPECIFIED IN MANUSCRIPT].

    Parameters
    ----------
    global_seed : int
        The master random seed to ensure perfect reproducibility of the simulation.

    Returns
    -------
    pd.DataFrame
        A DataFrame where the index is the Lag (k) and columns are the Sample Sizes (N),
        containing the computed conditional entropy values.
    """
    # Define the sample sizes specified in the manuscript
    sample_sizes = [100, 150, 200, 500, 1000, 10000, 100000]

    # Define the range of candidate lags to test
    lags = list(range(1, 10))

    # Initialize the output dictionary
    results_dict: Dict[int, List[float]] = {N: [] for N in sample_sizes}

    # Instantiate a deterministic RNG
    rng = np.random.Generator(np.random.PCG64(global_seed))

    # Define representative AR(1) parameters [UNSPECIFIED IN MANUSCRIPT]
    psi_1 = 0.5
    sigma = 1.0

    for N in sample_sizes:
        # Simulate the AR(1) process: x_t = psi_1 * x_{t-1} + epsilon_t
        x = np.zeros(N)
        epsilon = rng.normal(0, sigma, N)
        x[0] = epsilon[0]
        for t in range(1, N):
            x[t] = psi_1 * x[t-1] + epsilon[t]

        # Discretize into 3 states using empirical tertiles (q1=33.33%, q2=66.67%)
        q1 = np.percentile(x, 33.33)
        q2 = np.percentile(x, 66.67)

        # Apply Equation 1 logic
        z = np.ones(N)
        z[(x > q1) & (x < q2)] = 2.0
        z[x >= q2] = 3.0

        # Compute conditional entropy for each candidate lag
        for k in lags:
            ce = compute_conditional_entropy(z, k)
            results_dict[N].append(ce)

    # Construct the tidy DataFrame
    df_calibration = pd.DataFrame(results_dict, index=lags)
    df_calibration.index.name = "Lag_k"

    logger.info("Successfully replicated the conditional entropy calibration simulation.")
    return df_calibration

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Step 3: Lock TE lags for all downstream estimation
# -------------------------------------------------------------------------------------------------------------------------------
def lock_te_lags(study_configuration: Dict[str, Any]) -> Tuple[int, int]:
    """
    Validates and locks the optimal lag parameters (k=1, l=1) for Transfer Entropy.

    The manuscript concludes that only lag 1 can be chosen due to the rapid drop in
    conditional entropy for small samples (L=200). This function mathematically enforces
    this methodological decision, preventing downstream functions from using invalid lags.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the TE calibration parameters.

    Returns
    -------
    Tuple[int, int]
        The locked lag parameters (k, l).

    Raises
    ------
    ValueError
        If the configured lags are not exactly 1.
    """
    # Extract the configured lags
    k = study_configuration["te_calibration"]["optimal_lag_k"]
    l = study_configuration["te_calibration"]["optimal_lag_l"]

    # Enforce the strict equality derived from the calibration study
    if k != 1 or l != 1:
        raise ValueError(f"Methodological violation: The manuscript justifies k=1 and l=1. "
                         f"Configuration provided k={k}, l={l}. Pipeline execution blocked.")

    logger.info("Successfully locked TE lags: k=1, l=1. Methodological fidelity guaranteed.")
    return k, l

# -------------------------------------------------------------------------------------------------------------------------------
# Task 14, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class TECalibrationReport:
    """
    Immutable data container for the Transfer Entropy lag calibration artifacts.

    Attributes
    ----------
    df_calibration_simulation : pd.DataFrame
        The DataFrame containing the simulated conditional entropy decay across lags and sample sizes.
    locked_lag_k : int
        The mathematically enforced lag length for the target series (k=1).
    locked_lag_l : int
        The mathematically enforced lag length for the source series (l=1).
    """
    df_calibration_simulation: pd.DataFrame
    locked_lag_k: int
    locked_lag_l: int


def orchestrate_lag_calibration(study_configuration: Dict[str, Any]) -> TECalibrationReport:
    """
    Orchestrates Task 14: Validates lag calibration via conditional entropy (Eq. 3).

    This function executes the calibration steps in a strict Directed Acyclic Graph (DAG)
    order. It replicates the simulation study to empirically justify the lag selection,
    and then strictly locks the parameters (k=1, l=1) to prevent downstream methodological drift.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    TECalibrationReport
        An immutable dataclass containing the simulation results and locked lags.
    """
    logger.info("Starting Task 14 Orchestration: TE Lag Calibration (Eq. 3).")

    # Extract the global random seed for deterministic simulation
    global_seed = study_configuration["reproducibility"]["global_random_seed"]

    # Step 2 (incorporating Step 1): Replicate the calibration simulation study
    # This provides the empirical justification for the lag selection
    df_calibration = replicate_calibration_simulation(global_seed)

    # Step 3: Validate and lock the TE lags based on the configuration and manuscript findings
    # This acts as a strict "paper gate"
    k, l = lock_te_lags(study_configuration)

    # Package the calibration artifacts into an immutable dataclass
    report = TECalibrationReport(
        df_calibration_simulation=df_calibration,
        locked_lag_k=k,
        locked_lag_l=l
    )

    logger.info("=== Task 14 completed successfully. TE lags calibrated and locked. ===")

    # Return the immutable calibration report
    return report

# %%
# Task 15 — Enumerate rolling windows and define window-to-time-slice mapping

# ==============================================================================
# Task 15: Enumerate rolling windows and define window-to-time-slice mapping
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 1: Lock rolling-window parameters and generate metadata
# -------------------------------------------------------------------------------------------------------------------------------
def generate_window_metadata(
    master_calendar: pd.DatetimeIndex,
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Generates the metadata mapping for each rolling window based on configured parameters.

    This function extracts L=200 and s=10 from the configuration and maps each 1-based
    Window_ID to its exact 0-based array slice indices and corresponding calendar dates.
    It mathematically enforces the temporal boundaries required for dynamic network construction.

    Parameters
    ----------
    master_calendar : pd.DatetimeIndex
        The validated master date grid of length T=1319.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing L, s, and T.

    Returns
    -------
    pd.DataFrame
        A DataFrame indexed by Window_ID containing slice indices and boundary dates.

    Raises
    ------
    ValueError
        If the length of the master calendar does not match the configured T.
    """
    # Extract architectural parameters
    L = study_configuration["network_architecture"]["rolling_window_length_L"]
    s = study_configuration["network_architecture"]["step_size_s"]
    expected_T = study_configuration["metadata"]["observations_total_T"]

    # Enforce strict alignment between the empirical calendar and the configuration
    actual_T = len(master_calendar)
    if actual_T != expected_T:
        raise ValueError(f"Master calendar length ({actual_T}) does not match configured T ({expected_T}).")

    # Initialize a list to accumulate window records
    records: List[Dict[str, Any]] = []

    # Mathematically derive the total number of rolling windows (W)
    # Equation: W = floor((T - L) / s) + 1
    W = ((actual_T - L) // s) + 1

    # Iterate to generate boundaries for each window
    # We use 1-based indexing for the Window_ID to match mathematical notation (w \in {1, ..., W})
    for w in range(1, W + 1):
        # Calculate 0-based indices for Python array slicing
        start_idx = (w - 1) * s
        end_idx_exclusive = start_idx + L

        # Extract the corresponding dates from the master calendar
        start_date = master_calendar[start_idx]
        # The end date is the last inclusive day of the window
        end_date = master_calendar[end_idx_exclusive - 1]

        # Compute the center date (approximate midpoint of the window)
        center_idx = start_idx + (L // 2)
        center_date = master_calendar[center_idx]

        # Append the record
        records.append({
            "Window_ID": w,
            "Start_Index": start_idx,
            "End_Index_Exclusive": end_idx_exclusive,
            "Start_Date": start_date,
            "End_Date": end_date,
            "Center_Date": center_date
        })

    # Convert to a tidy pandas DataFrame and set Window_ID as the index
    df_window_metadata = pd.DataFrame(records).set_index("Window_ID")

    logger.info(f"Successfully generated metadata for {W} rolling windows (L={L}, s={s}).")
    return df_window_metadata

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 2: Compute total window count and validate
# -------------------------------------------------------------------------------------------------------------------------------
def validate_total_window_count(
    df_window_metadata: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> int:
    """
    Computes the theoretical window count W and validates it against the generated metadata.

    This function implements the exact integer arithmetic W = floor((T - L) / s) + 1
    and ensures that the metadata generation loop produced exactly this number of records,
    preventing off-by-one errors.

    Parameters
    ----------
    df_window_metadata : pd.DataFrame
        The metadata DataFrame generated in Step 1.
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    int
        The validated total number of rolling windows (W).

    Raises
    ------
    ValueError
        If the theoretical count does not match the empirical row count of the metadata.
    """
    # Extract parameters
    L = study_configuration["network_architecture"]["rolling_window_length_L"]
    s = study_configuration["network_architecture"]["step_size_s"]
    T = study_configuration["metadata"]["observations_total_T"]

    # Compute theoretical W using exact integer floor division
    theoretical_W = ((T - L) // s) + 1

    # Count empirical rows
    empirical_W = len(df_window_metadata)

    # Enforce strict equality
    if theoretical_W != empirical_W:
        raise ValueError(f"Window count mismatch. Theoretical W={theoretical_W}, but generated {empirical_W} records.")

    logger.info(f"Successfully validated total window count: W = {theoretical_W}.")
    return theoretical_W

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Step 3: Define each window's time slice deterministically
# -------------------------------------------------------------------------------------------------------------------------------
def lock_regime_assignment_date(
    df_window_metadata: pd.DataFrame,
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Locks the temporal convention used for downstream regime assignment.

    The manuscript does not specify whether a window is assigned to a regime based on its
    start, center, or end date. This function explicitly materializes the configured
    convention (defaulting to end-date) into a dedicated column, ensuring perfect
    reproducibility for Task 23.

    Parameters
    ----------
    df_window_metadata : pd.DataFrame
        The validated metadata DataFrame from Step 2.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the assignment rule.

    Returns
    -------
    pd.DataFrame
        The finalized metadata DataFrame with the 'Regime_Assignment_Date' column.
    """
    # Create a deep copy to adhere to immutability principles
    df_final = df_window_metadata.copy(deep=True)

    # Extract the assignment rule from the configuration
    assignment_rule = study_configuration["visualization_parameters"]["regime_assignment_rule"]

    # Determine the appropriate column based on the rule
    # The recommended default is end-date, as the window summarizes the preceding 200 days
    if "end-date" in assignment_rule.lower():
        df_final["Regime_Assignment_Date"] = df_final["End_Date"]
        locked_convention = "End_Date"
    elif "center-date" in assignment_rule.lower():
        df_final["Regime_Assignment_Date"] = df_final["Center_Date"]
        locked_convention = "Center_Date"
    elif "start-date" in assignment_rule.lower():
        df_final["Regime_Assignment_Date"] = df_final["Start_Date"]
        locked_convention = "Start_Date"
    else:
        # Fallback to End_Date if the rule string is ambiguous
        df_final["Regime_Assignment_Date"] = df_final["End_Date"]
        locked_convention = "End_Date (Fallback)"

    logger.info(f"Locked regime assignment convention to: {locked_convention} [UNSPECIFIED IN MANUSCRIPT].")
    return df_final

# -------------------------------------------------------------------------------------------------------------------------------
# Task 15, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class WindowMetadataReport:
    """
    Immutable data container for the rolling window metadata artifacts.

    Attributes
    ----------
    df_window_metadata : pd.DataFrame
        The finalized DataFrame mapping Window_ID to slice indices and dates.
    total_windows_W : int
        The validated total number of rolling windows (W=112).
    """
    df_window_metadata: pd.DataFrame
    total_windows_W: int


def orchestrate_window_enumeration(
    aligned_report: Any,
    study_configuration: Dict[str, Any]
) -> WindowMetadataReport:
    """
    Orchestrates Task 15: Enumerates rolling windows and defines time-slice mapping.

    This function executes the enumeration steps in a strict Directed Acyclic Graph (DAG)
    order. It generates the slice indices, mathematically validates the total window count,
    and locks the regime assignment convention, providing a definitive temporal map for
    all dynamic network construction.

    Parameters
    ----------
    aligned_report : AlignedSentimentReport
        The dataclass containing the validated master calendar (from Task 6).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    WindowMetadataReport
        An immutable dataclass containing the window metadata and total count.
    """
    logger.info("Starting Task 15 Orchestration: Rolling Window Enumeration.")

    # Extract the master calendar
    master_calendar: pd.DatetimeIndex = aligned_report.master_calendar

    # Step 1: Generate the base metadata mapping Window_ID to array slices and dates
    df_base_metadata = generate_window_metadata(master_calendar, study_configuration)

    # Step 2: Compute the theoretical W and validate against the generated metadata
    total_W = validate_total_window_count(df_base_metadata, study_configuration)

    # Step 3: Lock the regime assignment date convention to prevent downstream ambiguity
    df_final_metadata = lock_regime_assignment_date(df_base_metadata, study_configuration)

    # Package the metadata artifacts into an immutable dataclass
    report = WindowMetadataReport(
        df_window_metadata=df_final_metadata,
        total_windows_W=total_W
    )

    logger.info("=== Task 15 completed successfully. Window-to-time-slice mapping locked. ===")

    # Return the immutable metadata report
    return report

# %%
# Task 16 — Compute transfer entropy and normalized transfer entropy for each ordered pair (Eqs. 4–5)

# =======================================================================================
# Task 16: Compute transfer entropy and normalized transfer entropy for each ordered pair
# ========================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 1: Compute transfer entropy using plug-in empirical probabilities
# -------------------------------------------------------------------------------------------------------------------------------
def compute_raw_te_for_pair(y_series: np.ndarray, z_series: np.ndarray) -> float:
    """
    Computes the raw Transfer Entropy T_{Y->Z}^{1,1} using the plug-in empirical estimator.

    This is the single, canonical, private helper function designed to resolve the
    previous namespace collision. It must be called by both Task 16 (Network Assembly)
    and Task 18 (Markov Bootstrap) to guarantee statistical parity between the observed
    TE and the null distribution TE.

    It implements Equation 4: T_{Y->Z} = H(z_{t+1} | z_t) - H(z_{t+1} | z_t, y_t).
    It aligns the series to form (z_{t+1}, z_t, y_t) tuples, strictly filters out NaNs
    to maintain temporal integrity, and computes the empirical probability mass functions
    using highly optimized numpy unique counting.

    Parameters
    ----------
    y_series : np.ndarray
        A 1D numpy array representing the source symbolic series (Y) of length L.
    z_series : np.ndarray
        A 1D numpy array representing the target symbolic series (Z) of length L.

    Returns
    -------
    float
        The raw Transfer Entropy value in bits. Returns 0.0 if insufficient valid data exists.

    Raises
    ------
    TypeError
        If inputs are not numpy arrays.
    ValueError
        If the input arrays do not have identical lengths.
    """
    # Enforce strict type and shape checking to prevent silent broadcasting errors
    if not isinstance(y_series, np.ndarray) or not isinstance(z_series, np.ndarray):
        raise TypeError("Inputs y_series and z_series must be numpy arrays.")
    if len(y_series) != len(z_series):
        raise ValueError(f"Mismatched series lengths: {len(y_series)} vs {len(z_series)}.")

    # Step 1: Align the arrays for lag k=1, l=1
    # y_t and z_t represent the historical states (indices 0 to L-2)
    y_t: np.ndarray = y_series[:-1]
    z_t: np.ndarray = z_series[:-1]
    # z_{t+1} represents the future state of the target (indices 1 to L-1)
    z_t_plus_1: np.ndarray = z_series[1:]

    # Step 2: Create a strict boolean mask to filter out any tuples containing NaNs
    # This mathematically guarantees that missing data does not corrupt the joint distribution
    valid_mask: np.ndarray = ~np.isnan(y_t) & ~np.isnan(z_t) & ~np.isnan(z_t_plus_1)

    # Apply the mask to isolate valid transitions
    y_t_valid: np.ndarray = y_t[valid_mask]
    z_t_valid: np.ndarray = z_t[valid_mask]
    z_t_plus_1_valid: np.ndarray = z_t_plus_1[valid_mask]

    n_valid: int = len(y_t_valid)

    # If there are no valid transitions, information flow is undefined; return 0.0
    if n_valid == 0:
        return 0.0

    # Step 3: Compute empirical frequencies for the joint distribution p(z_{t+1}, z_t, y_t)
    # Stack into a 2D array of shape (n_valid, 3)
    joint_array: np.ndarray = np.column_stack((z_t_plus_1_valid, z_t_valid, y_t_valid))
    # np.unique with axis=0 efficiently finds unique rows (tuples) and their counts
    _, joint_counts = np.unique(joint_array, axis=0, return_counts=True)
    p_joint: np.ndarray = joint_counts / n_valid

    # Compute empirical frequencies for the marginal distribution p(z_t, y_t)
    marginal_zy_array: np.ndarray = np.column_stack((z_t_valid, y_t_valid))
    _, marginal_zy_counts = np.unique(marginal_zy_array, axis=0, return_counts=True)
    p_marginal_zy: np.ndarray = marginal_zy_counts / n_valid

    # Compute empirical frequencies for the joint distribution p(z_{t+1}, z_t)
    joint_z_array: np.ndarray = np.column_stack((z_t_plus_1_valid, z_t_valid))
    _, joint_z_counts = np.unique(joint_z_array, axis=0, return_counts=True)
    p_joint_z: np.ndarray = joint_z_counts / n_valid

    # Compute empirical frequencies for the marginal distribution p(z_t)
    _, marginal_z_counts = np.unique(z_t_valid, axis=0, return_counts=True)
    p_marginal_z: np.ndarray = marginal_z_counts / n_valid

    # Step 4: Compute Shannon Entropies (Equation 2)
    # H(z_{t+1}, z_t, y_t)
    h_joint_all: float = -np.sum(p_joint * np.log2(p_joint))
    # H(z_t, y_t)
    h_marginal_zy: float = -np.sum(p_marginal_zy * np.log2(p_marginal_zy))
    # H(z_{t+1} | z_t, y_t) = H(z_{t+1}, z_t, y_t) - H(z_t, y_t) (Equation 3 identity)
    h_cond_zy: float = h_joint_all - h_marginal_zy

    # H(z_{t+1}, z_t)
    h_joint_z: float = -np.sum(p_joint_z * np.log2(p_joint_z))
    # H(z_t)
    h_marginal_z: float = -np.sum(p_marginal_z * np.log2(p_marginal_z))
    # H(z_{t+1} | z_t) = H(z_{t+1}, z_t) - H(z_t) (Equation 3 identity)
    h_cond_z: float = h_joint_z - h_marginal_z

    # Step 5: Compute Transfer Entropy (Equation 4)
    # T_{Y->Z} = H(z_{t+1} | z_t) - H(z_{t+1} | z_t, y_t)
    raw_te: float = h_cond_z - h_cond_zy

    # Enforce mathematical bounds: TE must be non-negative.
    # Floating point arithmetic can sometimes yield values like -1e-16.
    return max(0.0, float(raw_te))

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Step 2 & 3: Normalize TE and apply degenerate-denominator policy
# -------------------------------------------------------------------------------------------------------------------------------
def compute_target_conditional_entropy(z_series: np.ndarray) -> float:
    """
    Computes the conditional entropy H(z_{t+1} | z_t) for a single target series.

    This function implements the mathematical identity for conditional entropy defined
    in Equation 3, specifically for the target series' own history. This value serves
    as the denominator for the Normalized Transfer Entropy calculation in Equation 5.
    It utilizes the plug-in empirical frequency estimator and Shannon entropy (Eq 2).

    Parameters
    ----------
    z_series : np.ndarray
        A 1D numpy array of discrete symbolic states {1, 2, 3} for the target series Z.
        Shape: (L,), where L is the rolling window length.

    Returns
    -------
    float
        The conditional entropy H(z_{t+1} | z_t) in bits.
        Returns 0.0 if data is insufficient or if the result is numerically negative.

    Algorithm
    ---------
    1. Align the series to form (z_{t+1}, z_t) pairs for lag k=1.
    2. Filter out any pairs containing NaN values to ensure temporal integrity.
    3. Compute joint empirical probabilities p(z_{t+1}, z_t) using unique state counting.
    4. Compute marginal empirical probabilities p(z_t).
    5. Calculate conditional entropy as H(z_{t+1}, z_t) - H(z_t) per Equation 3.

    Raises
    ------
    TypeError
        If z_series is not a numpy array.
    """
    # Validate that the input is a numpy array to ensure compatibility with vectorized operations
    if not isinstance(z_series, np.ndarray):
        # Raise TypeError to enforce strict numerical interface compliance
        raise TypeError("Input z_series must be of type np.ndarray.")

    # Extract the target history z_t for lag k=1 (indices 0 to L-2)
    z_t: np.ndarray = z_series[:-1]
    # Extract the target future state z_{t+1} (indices 1 to L-1)
    z_t_plus_1: np.ndarray = z_series[1:]

    # Create a boolean mask to identify indices where both aligned states are non-missing
    valid_mask: np.ndarray = ~np.isnan(z_t) & ~np.isnan(z_t_plus_1)
    # Filter the target history using the validity mask
    z_t_valid: np.ndarray = z_t[valid_mask]
    # Filter the target future using the validity mask
    z_t_plus_1_valid: np.ndarray = z_t_plus_1[valid_mask]

    # Determine the number of valid transitions available for probability estimation
    n_valid: int = len(z_t_valid)
    # Check if the valid sample size is sufficient for entropy estimation
    if n_valid == 0:
        # Return 0.0 if no valid transitions exist
        return 0.0

    # Stack the valid states into a 2D array of shape (n_valid, 2) for joint distribution counting
    joint_z_array: np.ndarray = np.column_stack((z_t_plus_1_valid, z_t_valid))
    # Compute empirical counts for the joint target state (z_{t+1}, z_t) using unique row counting
    _, joint_z_counts = np.unique(joint_z_array, axis=0, return_counts=True)
    # Convert counts to empirical probabilities p(z_{t+1}, z_t)
    p_joint_z: np.ndarray = joint_z_counts / n_valid
    # Calculate joint entropy H(z_{t+1}, z_t) using Shannon's formula (Equation 2)
    h_joint_z: float = -np.sum(p_joint_z * np.log2(p_joint_z))

    # Compute empirical counts for the marginal target history state (z_t)
    _, marginal_z_counts = np.unique(z_t_valid, axis=0, return_counts=True)
    # Convert counts to empirical probabilities p(z_t)
    p_marginal_z: np.ndarray = marginal_z_counts / n_valid
    # Calculate marginal entropy H(z_t) using Shannon's formula (Equation 2)
    h_marginal_z: float = -np.sum(p_marginal_z * np.log2(p_marginal_z))

    # Calculate conditional entropy H(z_{t+1} | z_t) using the identity in Equation 3
    h_cond_z: float = h_joint_z - h_marginal_z
    # Enforce non-negativity to correct for potential floating-point precision errors
    return max(0.0, float(h_cond_z))


def process_single_window(
    df_window: pd.DataFrame,
    tickers: List[str]
) -> Tuple[Dict[Tuple[str, str], float], Dict[Tuple[str, str], float]]:
    """
    Computes raw and normalized TE for all n(n-1) pairs within a single rolling window.

    This function serves as a parallelizable worker that constructs the local information
    topology for a 200-day window. It optimizes performance by pre-computing the
    conditional entropy denominators for all target tickers once. It then applies
    Equation 5 to normalize the directed spillover and enforces the configured
    degenerate-denominator policy.

    Parameters
    ----------
    df_window : pd.DataFrame
        The symbolic matrix for the current window of shape (L, n).
    tickers : List[str]
        The canonically ordered list of 34 tickers defining the vertex set V.

    Returns
    -------
    Tuple[Dict[Tuple[str, str], float], Dict[Tuple[str, str], float]]
        - raw_te_dict: Mapping of (Source, Target) pairs to raw TE values (bits).
        - norm_te_dict: Mapping of (Source, Target) pairs to Normalized TE values [0, 1].

    Algorithm
    ---------
    1. Pre-compute H(z_{t+1}|z_t) for all n tickers to reduce complexity from O(n^2) to O(n).
    2. Iterate through all ordered permutations of (source, target) where source != target.
    3. Compute raw TE using the plug-in estimator (Equation 4).
    4. Apply Equation 5: \hat{T}_{Y->Z} = T_{Y->Z} / H(z_{t+1} | z_t).
    5. Enforce the degenerate-denominator policy: if denominator < 1e-9, set result to 0.0.
    6. Clip normalized values to the mathematically defined [0, 1] interval.

    Raises
    ------
    TypeError
        If df_window is not a pandas DataFrame or tickers is not a list.
    """
    # Validate input types to ensure structural integrity of the window processing
    if not isinstance(df_window, pd.DataFrame) or not isinstance(tickers, list):
        # Raise TypeError to prevent attribute errors during processing
        raise TypeError("Inputs must be a pandas DataFrame (df_window) and a list (tickers).")

    # Initialize dictionaries to store the raw and normalized results for the window
    raw_te_dict: Dict[Tuple[str, str], float] = {}
    norm_te_dict: Dict[Tuple[str, str], float] = {}

    # Pre-compute the denominator H(z_{t+1} | z_t) for all potential target tickers
    # This optimization reduces the number of entropy calculations from 1,122 to 34 per window
    denom_lookup: Dict[str, float] = {}
    for ticker in tickers:
        # Extract the symbolic series for the ticker and compute its conditional entropy
        denom_lookup[ticker] = compute_target_conditional_entropy(df_window[ticker].values)

    # Iterate over all ordered permutations of (source, target) where source != target
    # This constructs the complete directed arc set A for the window
    for source, target in itertools.permutations(tickers, 2):
        # Extract the symbolic series for the source (Y) and target (Z)
        y_series: np.ndarray = df_window[source].values
        z_series: np.ndarray = df_window[target].values

        # Step 1: Compute raw Transfer Entropy (Equation 4)
        raw_te: float = compute_raw_te_for_pair(y_series, z_series)
        # Store the raw value in bits
        raw_te_dict[(source, target)] = raw_te

        # Steps 2 & 3: Normalize TE and apply degenerate-denominator policy
        # Retrieve the pre-computed denominator for the current target ticker
        denominator: float = denom_lookup[target]

        # Define a small epsilon to identify numerically zero denominators
        epsilon: float = 1e-9
        # Policy: if H(z_{t+1}|z_t) is effectively zero, set normalized TE to 0 [UNSPECIFIED IN MANUSCRIPT]
        if denominator < epsilon:
            # This prevents division-by-zero and handles constant target states
            norm_te = 0.0
        else:
            # Apply Equation 5: \hat{T}_{Y->Z} = T_{Y->Z} / H(z_{t+1} | z_t)
            norm_te = raw_te / denominator

        # Enforce mathematical bounds: Normalized TE must reside in the [0, 1] interval
        # This corrects for any finite-sample estimator noise that might exceed 1.0
        norm_te_dict[(source, target)] = min(1.0, max(0.0, norm_te))

    # Return the window's raw and normalized information topologies
    return raw_te_dict, norm_te_dict

# -------------------------------------------------------------------------------------------------------------------------------
# Task 16, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class TransferEntropyReport:
    """
    Immutable data container for the Transfer Entropy artifacts.

    Attributes
    ----------
    raw_te_matrices : Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        Nested dictionary mapping Channel -> Window ID -> (Source, Target) -> Raw TE.
    norm_te_matrices : Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        Nested dictionary mapping Channel -> Window ID -> (Source, Target) -> Normalized TE.
    """
    raw_te_matrices: Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
    norm_te_matrices: Dict[str, Dict[int, Dict[Tuple[str, str], float]]]


def orchestrate_transfer_entropy_estimation(
    encoding_report: Any,
    study_configuration: Dict[str, Any],
    n_jobs: int = -1
) -> TransferEntropyReport:
    """
    Orchestrates Task 16: Computes raw and normalized Transfer Entropy for all pairs.

    This function executes the TE estimation in a strict Directed Acyclic Graph (DAG) order.
    It utilizes multi-core parallelization to efficiently process the 112 rolling windows,
    computing the empirical probabilities, applying the normalization (Eq. 5), and enforcing
    the degenerate-denominator policy.

    Parameters
    ----------
    encoding_report : SymbolicEncodingReport
        The dataclass containing the encoded symbolic matrices (from Task 13).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.
    n_jobs : int, optional
        The number of CPU cores to use for parallelization (-1 uses all cores), by default -1.

    Returns
    -------
    TransferEntropyReport
        An immutable dataclass containing the raw and normalized TE dictionaries.
    """
    logger.info("Starting Task 16 Orchestration: Transfer Entropy Estimation (Eqs. 4-5).")

    encoded_matrices = encoding_report.encoded_matrices
    tickers = study_configuration["metadata"]["canonical_tickers"]

    raw_te_results: Dict[str, Dict[int, Dict[Tuple[str, str], float]]] = {"News": {}, "Social": {}}
    norm_te_results: Dict[str, Dict[int, Dict[Tuple[str, str], float]]] = {"News": {}, "Social": {}}

    # Iterate over each channel
    for channel_name, windows_dict in encoded_matrices.items():
        logger.info(f"[{channel_name}] Initiating parallel TE computation across {len(windows_dict)} windows...")

        # Extract window IDs and corresponding DataFrames to ensure ordered parallel execution
        window_ids = list(windows_dict.keys())
        window_dfs = list(windows_dict.values())

        # Execute the window processing in parallel using joblib
        # This satisfies the requirement for multi-core parallelization to handle the intensive load
        parallel_results = Parallel(n_jobs=n_jobs)(
            delayed(process_single_window)(df_window, tickers) for df_window in window_dfs
        )

        # Reconstruct the nested dictionaries from the parallel output
        for w_id, (raw_dict, norm_dict) in zip(window_ids, parallel_results):
            raw_te_results[channel_name][w_id] = raw_dict
            norm_te_results[channel_name][w_id] = norm_dict

    # Package the TE artifacts into an immutable dataclass
    report = TransferEntropyReport(
        raw_te_matrices=raw_te_results,
        norm_te_matrices=norm_te_results
    )

    logger.info("=== Task 16 completed successfully. Transfer Entropy computed and normalized. ===")

    # Return the immutable TE report
    return report

# %%
# Task 17 — Assemble adjacency matrices per window (Eq. 12) for each channel

# ==============================================================================
# Task 17: Assemble adjacency matrices per window (Eq. 12) for each channel
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Step 1 & 2: Define W_w exactly as in the paper and enforce diagonal policy
# -------------------------------------------------------------------------------------------------------------------------------
def assemble_and_enforce_matrices(
    norm_te_dict: Dict[str, Dict[int, Dict[tuple, float]]],
    ticker_to_position: Dict[str, int]
) -> Dict[str, Dict[int, np.ndarray]]:
    """
    Assembles the n x n weighted directed adjacency matrices W_w (Equation 12).

    This function has been refactored to utilize the O(1) ticker_to_position map.
    It iterates through the TE pairs and uses i = ticker_to_position[source] and
    j = ticker_to_position[target] to populate the numpy array. This is computationally
    faster and mathematically guarantees global index synchronization.

    Parameters
    ----------
    norm_te_dict : Dict[str, Dict[int, Dict[tuple, float]]]
        The nested dictionary containing Normalized TE values.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    Dict[str, Dict[int, np.ndarray]]
        A nested dictionary mapping Channel -> Window ID -> 34x34 numpy array.

    Raises
    ------
    KeyError
        If a source or target string in the TE dictionary does not exist in the map.
    """
    # Determine the matrix dimension n from the length of the lookup map
    n_nodes: int = len(ticker_to_position)
    assembled_matrices: Dict[str, Dict[int, np.ndarray]] = {"News": {}, "Social": {}}

    # Iterate over each channel (News, Social)
    for channel_name, windows in norm_te_dict.items():
        # Iterate over each rolling window ID
        for w_id, te_pairs in windows.items():
            # Step 1: Initialize an n x n matrix of zeros
            matrix_w = np.zeros((n_nodes, n_nodes), dtype=float)

            # Iterate over the computed TE pairs to populate the matrix
            for (source, target), te_value in te_pairs.items():
                # O(1) lookup to resolve the exact matrix coordinates
                # This guarantees perfect topological alignment with the vertex set V
                i: int = ticker_to_position[source]
                j: int = ticker_to_position[target]

                # Assign to the matrix: row i is the source, column j is the target
                matrix_w[i, j] = te_value

            # Step 2: Enforce the diagonal policy
            # Equation 12 explicitly requires zeros on the main diagonal
            np.fill_diagonal(matrix_w, 0.0)

            # Store the validated matrix in the output dictionary
            assembled_matrices[channel_name][w_id] = matrix_w

    logger.info(f"Successfully assembled and enforced diagonal policy for all W_w matrices using O(1) mapping.")
    return assembled_matrices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 17, Orchestrator Function (incorporating Step 3)
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class AdjacencyMatrixReport:
    """
    Immutable data container for the assembled adjacency matrix artifacts.

    Attributes
    ----------
    unfiltered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary mapping Channel -> Window ID -> 34x34 numpy array.
        These matrices represent the full network before Markov bootstrap filtering.
    canonical_tickers : List[str]
        The ordered list of tickers, preserved here to ensure downstream tasks
        can map matrix indices back to corporate entities.
    """
    unfiltered_matrices: Dict[str, Dict[int, np.ndarray]]
    canonical_tickers: List[str]


def orchestrate_adjacency_assembly(
    te_report: Any,
    ticker_to_position: Dict[str, int]
) -> Any: # Returns AdjacencyMatrixReport
    """
    Orchestrates Task 17: Assembles adjacency matrices per window (Eq. 12).

    This function executes the assembly steps in a strict Directed Acyclic Graph (DAG)
    order. It has been refactored to accept the ticker_to_position map, passing it
    down to the assembly function to guarantee index synchronization.

    Parameters
    ----------
    te_report : TransferEntropyReport
        The dataclass containing the normalized TE dictionaries.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    AdjacencyMatrixReport
        An immutable dataclass containing the unfiltered adjacency matrices.
    """
    logger.info("Starting Task 17 Orchestration: Adjacency Matrix Assembly (Eq. 12).")

    # Extract the normalized TE dictionary
    norm_te_dict = te_report.norm_te_matrices

    # Steps 1 & 2: Assemble the matrices and enforce the diagonal policy using the O(1) map
    unfiltered_matrices = assemble_and_enforce_matrices(norm_te_dict, ticker_to_position)

    # Extract the ordered list of tickers to preserve downstream compatibility
    ordered_tickers: List[str] = [k for k, v in sorted(ticker_to_position.items(), key=lambda item: item[1])]

    # Step 3: Persist the unfiltered versions
    report = AdjacencyMatrixReport(
        unfiltered_matrices=unfiltered_matrices,
        canonical_tickers=ordered_tickers
    )

    logger.info("=== Task 17 completed successfully. Unfiltered adjacency matrices assembled. ===")
    return report

# %%
# Task 18 — Generate Markov-bootstrap null samples for significance testing (Eq. 7 preparation)

# ==============================================================================
# Task 18: Generate Markov-bootstrap null samples for significance testing
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Helper Function: Reuse TE Estimator from Task 16
# -------------------------------------------------------------------------------------------------------------------------------
def compute_raw_te_for_pair(y_series: np.ndarray, z_series: np.ndarray) -> float:
    """
    Computes the raw Transfer Entropy T_{Y->Z}^{1,1} using the plug-in empirical estimator.

    This is the single, canonical, private helper function designed to resolve the
    previous namespace collision. It must be called by both Task 16 (Network Assembly)
    and Task 18 (Markov Bootstrap) to guarantee statistical parity between the observed
    TE and the null distribution TE.

    It implements Equation 4: T_{Y->Z} = H(z_{t+1} | z_t) - H(z_{t+1} | z_t, y_t).
    It aligns the series to form (z_{t+1}, z_t, y_t) tuples, strictly filters out NaNs
    to maintain temporal integrity, and computes the empirical probability mass functions
    using highly optimized numpy unique counting.

    Parameters
    ----------
    y_series : np.ndarray
        A 1D numpy array representing the source symbolic series (Y) of length L.
    z_series : np.ndarray
        A 1D numpy array representing the target symbolic series (Z) of length L.

    Returns
    -------
    float
        The raw Transfer Entropy value in bits. Returns 0.0 if insufficient valid data exists.

    Raises
    ------
    TypeError
        If inputs are not numpy arrays.
    ValueError
        If the input arrays do not have identical lengths.
    """
    # Enforce strict type and shape checking to prevent silent broadcasting errors
    if not isinstance(y_series, np.ndarray) or not isinstance(z_series, np.ndarray):
        raise TypeError("Inputs y_series and z_series must be numpy arrays.")
    if len(y_series) != len(z_series):
        raise ValueError(f"Mismatched series lengths: {len(y_series)} vs {len(z_series)}.")

    # Step 1: Align the arrays for lag k=1, l=1
    # y_t and z_t represent the historical states (indices 0 to L-2)
    y_t: np.ndarray = y_series[:-1]
    z_t: np.ndarray = z_series[:-1]
    # z_{t+1} represents the future state of the target (indices 1 to L-1)
    z_t_plus_1: np.ndarray = z_series[1:]

    # Step 2: Create a strict boolean mask to filter out any tuples containing NaNs
    # This mathematically guarantees that missing data does not corrupt the joint distribution
    valid_mask: np.ndarray = ~np.isnan(y_t) & ~np.isnan(z_t) & ~np.isnan(z_t_plus_1)

    # Apply the mask to isolate valid transitions
    y_t_valid: np.ndarray = y_t[valid_mask]
    z_t_valid: np.ndarray = z_t[valid_mask]
    z_t_plus_1_valid: np.ndarray = z_t_plus_1[valid_mask]

    n_valid: int = len(y_t_valid)

    # If there are no valid transitions, information flow is undefined; return 0.0
    if n_valid == 0:
        return 0.0

    # Step 3: Compute empirical frequencies for the joint distribution p(z_{t+1}, z_t, y_t)
    # Stack into a 2D array of shape (n_valid, 3)
    joint_array: np.ndarray = np.column_stack((z_t_plus_1_valid, z_t_valid, y_t_valid))
    # np.unique with axis=0 efficiently finds unique rows (tuples) and their counts
    _, joint_counts = np.unique(joint_array, axis=0, return_counts=True)
    p_joint: np.ndarray = joint_counts / n_valid

    # Compute empirical frequencies for the marginal distribution p(z_t, y_t)
    marginal_zy_array: np.ndarray = np.column_stack((z_t_valid, y_t_valid))
    _, marginal_zy_counts = np.unique(marginal_zy_array, axis=0, return_counts=True)
    p_marginal_zy: np.ndarray = marginal_zy_counts / n_valid

    # Compute empirical frequencies for the joint distribution p(z_{t+1}, z_t)
    joint_z_array: np.ndarray = np.column_stack((z_t_plus_1_valid, z_t_valid))
    _, joint_z_counts = np.unique(joint_z_array, axis=0, return_counts=True)
    p_joint_z: np.ndarray = joint_z_counts / n_valid

    # Compute empirical frequencies for the marginal distribution p(z_t)
    _, marginal_z_counts = np.unique(z_t_valid, axis=0, return_counts=True)
    p_marginal_z: np.ndarray = marginal_z_counts / n_valid

    # Step 4: Compute Shannon Entropies (Equation 2)
    # H(z_{t+1}, z_t, y_t)
    h_joint_all: float = -np.sum(p_joint * np.log2(p_joint))
    # H(z_t, y_t)
    h_marginal_zy: float = -np.sum(p_marginal_zy * np.log2(p_marginal_zy))
    # H(z_{t+1} | z_t, y_t) = H(z_{t+1}, z_t, y_t) - H(z_t, y_t) (Equation 3 identity)
    h_cond_zy: float = h_joint_all - h_marginal_zy

    # H(z_{t+1}, z_t)
    h_joint_z: float = -np.sum(p_joint_z * np.log2(p_joint_z))
    # H(z_t)
    h_marginal_z: float = -np.sum(p_marginal_z * np.log2(p_marginal_z))
    # H(z_{t+1} | z_t) = H(z_{t+1}, z_t) - H(z_t) (Equation 3 identity)
    h_cond_z: float = h_joint_z - h_marginal_z

    # Step 5: Compute Transfer Entropy (Equation 4)
    # T_{Y->Z} = H(z_{t+1} | z_t) - H(z_{t+1} | z_t, y_t)
    raw_te: float = h_cond_z - h_cond_zy

    # Enforce mathematical bounds: TE must be non-negative.
    # Floating point arithmetic can sometimes yield values like -1e-16.
    return max(0.0, float(raw_te))

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Step 1: Define Markov bootstrap mechanics per configuration
# -------------------------------------------------------------------------------------------------------------------------------
def estimate_markov_parameters(
    encoded_matrices: Dict[str, Dict[int, pd.DataFrame]]
) -> Dict[str, Dict[int, Dict[str, Tuple[np.ndarray, np.ndarray]]]]:
    """
    Estimates the empirical initial distribution (pi) and transition matrix (P).

    This function enforces a "strict empirical policy". If a state has no outgoing
    transitions, its corresponding row in P remains strictly zeros. It does not
    artificially smooth or replace zero-rows with the marginal distribution, ensuring
    perfect fidelity to the empirically observed data for the Markov bootstrap.

    Parameters
    ----------
    encoded_matrices : Dict[str, Dict[int, pd.DataFrame]]
        The nested dictionary of window-specific symbolic matrices.

    Returns
    -------
    Dict[str, Dict[int, Dict[str, Tuple[np.ndarray, np.ndarray]]]]
        A nested dictionary mapping Channel -> Window ID -> Ticker -> (pi_vector, P_matrix).
        pi_vector is shape (3,), P_matrix is shape (3, 3).
    """
    # Initialize the output dictionary hierarchy
    markov_params: Dict[str, Dict[int, Dict[str, Tuple[np.ndarray, np.ndarray]]]] = {"News": {}, "Social": {}}

    # Iterate over channels and windows
    for channel_name, windows in encoded_matrices.items():
        for w_id, df_encoded in windows.items():
            markov_params[channel_name][w_id] = {}

            # Iterate over each ticker in the window
            for ticker in df_encoded.columns:
                # Extract the series and drop NaNs to compute empirical dynamics
                series: np.ndarray = df_encoded[ticker].dropna().values
                n_valid: int = len(series)

                # Initialize pi and P with strict zeros
                pi_vec: np.ndarray = np.zeros(3, dtype=float)
                P_mat: np.ndarray = np.zeros((3, 3), dtype=float)

                # If insufficient data exists, return the zeroed arrays
                if n_valid < 2:
                    markov_params[channel_name][w_id][ticker] = (pi_vec, P_mat)
                    continue

                # 1. Estimate empirical initial distribution (pi)
                unique_states, counts = np.unique(series, return_counts=True)
                for state, count in zip(unique_states, counts):
                    # Map states {1.0, 2.0, 3.0} to indices {0, 1, 2}
                    idx = int(state - 1)
                    pi_vec[idx] = count / n_valid

                # 2. Estimate empirical transition matrix (P)
                y_t = series[:-1]
                y_t_plus_1 = series[1:]

                # Stack into transition pairs
                transitions = np.column_stack((y_t, y_t_plus_1))

                # Count unique transitions
                unique_transitions, trans_counts = np.unique(transitions, axis=0, return_counts=True)

                # Populate the transition matrix with raw counts
                for trans, count in zip(unique_transitions, trans_counts):
                    from_idx = int(trans[0] - 1)
                    to_idx = int(trans[1] - 1)
                    P_mat[from_idx, to_idx] = count

                # Normalize the rows of P to create probabilities
                row_sums = P_mat.sum(axis=1)

                # Strict Empirical Policy: Divide only where row_sums > 0.
                # Rows with sum == 0 remain exactly 0.0. No artificial smoothing is applied.
                P_mat = np.divide(
                    P_mat,
                    row_sums[:, np.newaxis],
                    out=np.zeros_like(P_mat),
                    where=row_sums[:, np.newaxis] > 0
                )

                # Store the parameters
                markov_params[channel_name][w_id][ticker] = (pi_vec, P_mat)

    logger.info("Successfully estimated Markov parameters under strict empirical policy.")
    return markov_params

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Step 2 & 3: Simulate bootstrap series and lock RNG seed
# -------------------------------------------------------------------------------------------------------------------------------
def generate_deterministic_seed(base_seed: int, channel: str, w_id: int, ticker_idx: int, b: int) -> int:
    """
    Generates a strictly deterministic, collision-resistant seed for a specific bootstrap replicate.

    This function ensures that every stochastic simulation in the high-frequency sentinel
    system is perfectly reproducible across different execution environments and parallel
    workers. It utilizes the MD5 cryptographic hashing algorithm to map the semantic
    identifiers of a simulation instance to a uniformly distributed 64-bit integer seed.

    Parameters
    ----------
    base_seed : int
        The global random seed combined with the process-specific offset.
    channel : str
        The media channel identifier ("News" or "Social").
    w_id : int
        The unique identifier for the rolling window.
    ticker_idx : int
        The positional index of the ticker in the canonical vertex set V.
    b : int
        The index of the bootstrap replicate (0 to N_boot - 1).

    Returns
    -------
    int
        A deterministic 64-bit unsigned integer suitable for seeding a PCG64 generator.

    Raises
    ------
    TypeError
        If any input parameter deviates from its required type.
    """
    # Validate that all inputs are of the correct type to prevent hashing errors
    if not all(isinstance(i, int) for i in [base_seed, w_id, ticker_idx, b]) or not isinstance(channel, str):
        # Raise TypeError to enforce strict interface compliance
        raise TypeError("Inputs must be integers (base_seed, w_id, ticker_idx, b) and string (channel).")

    # Construct a unique string identifier by concatenating the semantic coordinates of the simulation
    seed_str: str = f"{base_seed}_{channel}_{w_id}_{ticker_idx}_{b}"
    # Compute the MD5 hash of the identifier string to generate a high-entropy byte sequence
    hash_object = hashlib.md5(seed_str.encode('utf-8'))
    # Extract the raw digest bytes from the hash object
    hash_digest: bytes = hash_object.digest()
    # Convert the first 8 bytes of the digest into a 64-bit little-endian unsigned integer
    return int.from_bytes(hash_digest[:8], byteorder='little', signed=False)


def simulate_markov_series(pi_vec: np.ndarray, P_mat: np.ndarray, L: int, seed: int) -> np.ndarray:
    """
    Simulates a single Markov series of length L using the provided parameters and seed.

    This function implements the Markov bootstrap simulation described in Section 3.1.
    It generates a synthetic symbolic time series that preserves the internal state-transition
    dynamics of the source company while breaking any potential dependencies with the
    target company, thereby establishing the null distribution for Transfer Entropy.

    Parameters
    ----------
    pi_vec : np.ndarray
        The empirical initial state distribution vector of shape (3,).
    P_mat : np.ndarray
        The empirical transition probability matrix of shape (3, 3).
    L : int
        The required length of the simulated series (typically 200).
    seed : int
        The deterministic integer seed for the random number generator.

    Returns
    -------
    np.ndarray
        A 1D numpy array of length L containing the simulated symbolic states {1.0, 2.0, 3.0}.

    Raises
    ------
    ValueError
        If the probability distributions do not sum to unity or if dimensions are incorrect.
    """
    # Validate that the initial distribution vector has the correct dimensionality for 3 states
    if pi_vec.shape != (3,) or P_mat.shape != (3, 3):
        # Raise ValueError if the Markov parameters do not match the symbolic alphabet size
        raise ValueError("Markov parameters must have shapes (3,) for pi and (3, 3) for P.")

    # Validate that the probability distributions are mathematically sound (sum to 1.0)
    if not np.isclose(np.sum(pi_vec), 1.0) or not np.allclose(np.sum(P_mat, axis=1), 1.0):
        # Raise ValueError to prevent sampling from invalid probability mass functions
        raise ValueError("Probabilities in pi_vec and rows of P_mat must sum to 1.0.")

    # Instantiate a modern PCG64 random number generator using the deterministic seed
    rng = np.random.Generator(np.random.PCG64(seed))
    # Define the discrete symbolic alphabet {1, 2, 3} as specified in Equation 1
    states: np.ndarray = np.array([1.0, 2.0, 3.0])

    # Initialize an empty array of length L to store the simulated symbolic sequence
    simulated_series: np.ndarray = np.zeros(L, dtype=float)

    # Draw the initial state index from the distribution pi_vec
    current_state_idx: int = rng.choice(3, p=pi_vec)
    # Assign the corresponding symbolic state to the first position in the series
    simulated_series[0] = states[current_state_idx]

    # Iterate from t=1 to L-1 to generate the remainder of the Markov chain
    for t in range(1, L):
        # Draw the next state index based on the transition probabilities of the current state
        current_state_idx = rng.choice(3, p=P_mat[current_state_idx])
        # Assign the corresponding symbolic state to the current time step
        simulated_series[t] = states[current_state_idx]

    # Return the completed synthetic symbolic time series
    return simulated_series


def process_bootstrap_for_window(
    w_id: int,
    df_encoded: pd.DataFrame,
    markov_params_window: Dict[str, Tuple[np.ndarray, np.ndarray]],
    tickers: List[str],
    N_boot: int,
    L: int,
    base_seed: int,
    channel_name: str
) -> Tuple[int, Dict[Tuple[str, str], np.ndarray]]:
    """
    Simulates N_boot source series and computes the null TE distributions for all pairs in a window.

    This worker function is designed for parallel execution. It first pre-simulates all
    required bootstrap replicates for every ticker in the window to minimize redundant
    computation. It then iterates through all ordered pairs (i, j) to compute the
    Transfer Entropy (Equation 4) of the simulated source against the fixed target.

    Parameters
    ----------
    w_id : int
        The unique identifier for the current rolling window.
    df_encoded : pd.DataFrame
        The symbolic matrix for the current window of shape (L, n).
    markov_params_window : Dict[str, Tuple[np.ndarray, np.ndarray]]
        Mapping of Ticker -> (pi_vector, P_matrix) for the current window.
    tickers : List[str]
        The canonically ordered list of 34 tickers.
    N_boot : int
        The number of bootstrap replicates to generate (typically 1000).
    L : int
        The length of the rolling window (typically 200).
    base_seed : int
        The base seed for the bootstrap process.
    channel_name : str
        The name of the channel ("News" or "Social").

    Returns
    -------
    Tuple[int, Dict[Tuple[str, str], np.ndarray]]
        A tuple containing the Window ID and a dictionary mapping (Source, Target)
        pairs to their respective 1D arrays of N_boot null TE values.

    Raises
    ------
    KeyError
        If a ticker is missing from the Markov parameters or the DataFrame.
    """
    # Validate that the input DataFrame contains all tickers in the vertex set
    if not all(t in df_encoded.columns for t in tickers):
        # Raise KeyError if the symbolic matrix is incomplete
        raise KeyError("Mismatched tickers between vertex set and encoded DataFrame.")

    # Initialize a dictionary to store the pre-simulated source series for each ticker
    simulated_sources: Dict[str, List[np.ndarray]] = {ticker: [] for ticker in tickers}

    # Iterate through each ticker to generate its N_boot bootstrap replicates
    for i, ticker in enumerate(tickers):
        # Extract the Markov parameters (pi, P) for the current ticker
        pi_vec, P_mat = markov_params_window[ticker]
        # Generate N_boot independent Markov chains
        for b in range(N_boot):
            # Generate a deterministic seed for the current replicate
            seed: int = generate_deterministic_seed(base_seed, channel_name, w_id, i, b)
            # Simulate the Markov series of length L
            sim_series: np.ndarray = simulate_markov_series(pi_vec, P_mat, L, seed)
            # Append the simulated series to the ticker's list
            simulated_sources[ticker].append(sim_series)

    # Initialize a dictionary to store the resulting null TE distributions for each pair
    null_te_distributions: Dict[Tuple[str, str], np.ndarray] = {}

    # Iterate through all ordered permutations of (source, target) where source != target
    for source, target in itertools.permutations(tickers, 2):
        # Extract the fixed target symbolic series from the encoded DataFrame
        z_series_fixed: np.ndarray = df_encoded[target].values

        # Retrieve the list of N_boot simulated source series for the current source ticker
        y_simulated_list: List[np.ndarray] = simulated_sources[source]

        # Initialize a numpy array to store the TE values for each bootstrap replicate
        te_null_array: np.ndarray = np.zeros(N_boot, dtype=float)
        # Compute the Transfer Entropy for each simulated replicate
        for b in range(N_boot):
            # Extract the b-th simulated source series
            y_sim_series: np.ndarray = y_simulated_list[b]
            # Compute the raw Transfer Entropy (Equation 4) using the plug-in estimator
            te_null_array[b] = compute_raw_te_for_pair(y_sim_series, z_series_fixed)

        # Map the (source, target) pair to its computed null distribution array
        null_te_distributions[(source, target)] = te_null_array

    # Return the Window ID and the dictionary of null distributions
    return w_id, null_te_distributions

# -------------------------------------------------------------------------------------------------------------------------------
# Task 18, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class MarkovBootstrapReport:
    """
    Immutable data container for the Markov bootstrap null distributions.

    Attributes
    ----------
    null_te_distributions : Dict[str, Dict[int, Dict[Tuple[str, str], np.ndarray]]]
        Nested dictionary mapping Channel -> Window ID -> (Source, Target) -> 1D array of N_boot TE values.
    """
    null_te_distributions: Dict[str, Dict[int, Dict[Tuple[str, str], np.ndarray]]]


def orchestrate_markov_bootstrap(
    encoding_report: Any,
    study_configuration: Dict[str, Any],
    n_jobs: int = -1
) -> MarkovBootstrapReport:
    """
    Orchestrates Task 18: Generates Markov-bootstrap null samples for significance testing.

    This function executes the bootstrap steps in a strict Directed Acyclic Graph (DAG) order.
    It estimates the empirical Markov parameters without smoothing, pre-simulates the source
    series using strictly deterministic seeds, and computes the null TE distributions in parallel.

    Parameters
    ----------
    encoding_report : SymbolicEncodingReport
        The dataclass containing the encoded symbolic matrices (from Task 13).
    study_configuration : Dict[str, Any]
        The master configuration dictionary.
    n_jobs : int, optional
        The number of CPU cores to use for parallelization (-1 uses all cores), by default -1.

    Returns
    -------
    MarkovBootstrapReport
        An immutable dataclass containing the null TE distributions.
    """
    logger.info("Starting Task 18 Orchestration: Markov Bootstrap Null Generation.")

    encoded_matrices = encoding_report.encoded_matrices
    tickers = study_configuration["metadata"]["canonical_tickers"]

    N_boot = study_configuration["inference_parameters"]["n_boot"]
    L = study_configuration["network_architecture"]["rolling_window_length_L"]

    global_seed = study_configuration["reproducibility"]["global_random_seed"]
    bootstrap_offset = study_configuration["reproducibility"]["seed_partitioning"]["markov_bootstrap_seed_offset"]
    base_seed = global_seed + bootstrap_offset

    # Step 1: Estimate the empirical initial distribution (pi) and transition matrix (P)
    markov_params = estimate_markov_parameters(encoded_matrices)

    null_te_results: Dict[str, Dict[int, Dict[Tuple[str, str], np.ndarray]]] = {"News": {}, "Social": {}}

    # Steps 2 & 3: Simulate bootstrap series and compute null TE distributions in parallel
    for channel_name, windows_dict in encoded_matrices.items():
        logger.info(f"[{channel_name}] Initiating parallel Markov bootstrap ({N_boot} reps) across {len(windows_dict)} windows...")

        window_ids = list(windows_dict.keys())
        window_dfs = list(windows_dict.values())

        # Execute the window processing in parallel using joblib
        parallel_results = Parallel(n_jobs=n_jobs)(
            delayed(process_bootstrap_for_window)(
                w_id, df_window, markov_params[channel_name][w_id], tickers, N_boot, L, base_seed, channel_name
            ) for w_id, df_window in zip(window_ids, window_dfs)
        )

        # Reconstruct the nested dictionaries from the parallel output
        for w_id, null_distributions in parallel_results:
            null_te_results[channel_name][w_id] = null_distributions

    # Package the bootstrap artifacts into an immutable dataclass
    report = MarkovBootstrapReport(
        null_te_distributions=null_te_results
    )

    logger.info("=== Task 18 completed successfully. Markov bootstrap null distributions generated. ===")

    # Return the immutable bootstrap report
    return report

# %%
# Task 19 — Compute p-values and filter edges via bootstrap significance test (Eq. 7)

# ============================================================================================
# Task 19: Compute p-values and filter edges via bootstrap significance test (Eq. 7)
# ============================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 1: Compute p-value per edge (Eq. 7)
# -------------------------------------------------------------------------------------------------------------------------------
def compute_bootstrap_p_values(
    raw_te_matrices: Dict[str, Dict[int, Dict[Tuple[str, str], float]]],
    null_te_distributions: Dict[str, Dict[int, Dict[Tuple[str, str], np.ndarray]]],
    n_boot: int
) -> Dict[str, Dict[int, Dict[Tuple[str, str], float]]]:
    """
    Computes the bootstrap p-value for each directed edge using Equation 7.

    This function implements the mathematical definition: p-value = M / N_boot,
    where M is the number of bootstrapped TE estimates that strictly exceed the
    observed raw TE. It uses vectorized numpy operations for optimal performance.

    Parameters
    ----------
    raw_te_matrices : Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        Nested dictionary containing the observed raw Transfer Entropy values.
    null_te_distributions : Dict[str, Dict[int, Dict[Tuple[str, str], np.ndarray]]]
        Nested dictionary containing the 1D numpy arrays of N_boot null TE values.
    n_boot : int
        The total number of bootstrap replicates generated (typically 1000).

    Returns
    -------
    Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        A nested dictionary mapping Channel -> Window ID -> (Source, Target) -> p-value.

    Raises
    ------
    ValueError
        If n_boot is less than or equal to zero.
    KeyError
        If a (Source, Target) pair exists in the observed data but is missing from the null distribution.
    """
    # Enforce mathematical validity of the denominator
    if n_boot <= 0:
        raise ValueError(f"The number of bootstrap replicates (n_boot) must be strictly positive. Found: {n_boot}")

    # Initialize the output dictionary hierarchy
    p_values_dict: Dict[str, Dict[int, Dict[Tuple[str, str], float]]] = {"News": {}, "Social": {}}

    # Iterate over each channel (News, Social)
    for channel_name, windows in raw_te_matrices.items():
        # Iterate over each rolling window ID
        for w_id, observed_pairs in windows.items():
            p_values_dict[channel_name][w_id] = {}

            # Extract the corresponding null distributions for the current channel and window
            null_window = null_te_distributions.get(channel_name, {}).get(w_id, {})

            # Iterate over every ordered (Source, Target) pair in the observed data
            for pair, obs_te in observed_pairs.items():
                # Retrieve the null distribution array for the specific pair
                if pair not in null_window:
                    raise KeyError(f"Missing null distribution for pair {pair} in {channel_name}, Window {w_id}.")

                null_array: np.ndarray = null_window[pair]

                # Validate that the null array has the expected length
                if len(null_array) != n_boot:
                    raise ValueError(f"Null array length ({len(null_array)}) does not match n_boot ({n_boot}).")

                # Equation 7 Logic: M = #{T_ij^boot > T_ij}
                # We use the strict greater-than operator (>) as defined in the manuscript.
                # np.sum on a boolean array efficiently counts the True values.
                M: int = int(np.sum(null_array > obs_te))

                # Compute the p-value
                p_value: float = M / float(n_boot)

                # Store the computed p-value
                p_values_dict[channel_name][w_id][pair] = p_value

    logger.info(f"Successfully computed bootstrap p-values for all edges (N_boot={n_boot}).")
    return p_values_dict

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 2: Apply filtering rule with locked alpha
# -------------------------------------------------------------------------------------------------------------------------------
def evaluate_significance_threshold(
    p_values_dict: Dict[str, Dict[int, Dict[Tuple[str, str], float]]],
    alpha: float
) -> Dict[str, Dict[int, Dict[Tuple[str, str], bool]]]:
    """
    Evaluates the statistical significance of each edge against the locked alpha threshold.

    This function applies the strict inequality (p_value < alpha) to determine if an
    edge should be retained in the filtered network. It isolates the decision boundary
    logic from the matrix manipulation.

    Parameters
    ----------
    p_values_dict : Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        Nested dictionary containing the computed p-values (from Step 1).
    alpha : float
        The critical significance level (typically 0.10).

    Returns
    -------
    Dict[str, Dict[int, Dict[Tuple[str, str], bool]]]
        A nested dictionary mapping Channel -> Window ID -> (Source, Target) -> Boolean flag.
        True indicates the edge is statistically significant and should be kept.

    Raises
    ------
    ValueError
        If alpha is not within the valid probability range (0.0, 1.0).
    """
    # Validate the mathematical bounds of the alpha threshold
    if not (0.0 < alpha < 1.0):
        raise ValueError(f"Significance threshold alpha must be between 0.0 and 1.0. Found: {alpha}")

    # Initialize the output dictionary hierarchy
    significance_dict: Dict[str, Dict[int, Dict[Tuple[str, str], bool]]] = {"News": {}, "Social": {}}

    # Iterate over each channel
    for channel_name, windows in p_values_dict.items():
        # Iterate over each rolling window ID
        for w_id, pairs in windows.items():
            significance_dict[channel_name][w_id] = {}

            # Iterate over every computed p-value
            for pair, p_value in pairs.items():
                # Apply the strict inequality rule: keep edge iff p-value < alpha
                is_significant: bool = p_value < alpha

                # Store the boolean flag
                significance_dict[channel_name][w_id][pair] = is_significant

    logger.info(f"Successfully evaluated edge significance at alpha={alpha}.")
    return significance_dict

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Step 3: Build filtered adjacency matrix W_w^(sig)
# -------------------------------------------------------------------------------------------------------------------------------
def build_filtered_adjacency_matrices(
    unfiltered_matrices: Dict[str, Dict[int, np.ndarray]],
    significance_dict: Dict[str, Dict[int, Dict[Tuple[str, str], bool]]],
    ticker_to_position: Dict[str, int]
) -> Dict[str, Dict[int, np.ndarray]]:
    """
    Constructs the significance-filtered adjacency matrices W_w^(sig).

    This function has been refactored to remove the internal dictionary comprehension
    that rebuilt the ticker-to-index map. It now uses the injected ticker_to_position
    dictionary to map the (source, target) strings from the significance mask to the
    [i, j] coordinates of the numpy array when zeroing out non-significant edges.

    Parameters
    ----------
    unfiltered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the full 34x34 normalized adjacency matrices.
    significance_dict : Dict[str, Dict[int, Dict[Tuple[str, str], bool]]]
        Nested dictionary containing the boolean significance flags.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    Dict[str, Dict[int, np.ndarray]]
        A nested dictionary mapping Channel -> Window ID -> Filtered 34x34 numpy array.
    """
    # Initialize the output dictionary hierarchy
    filtered_matrices: Dict[str, Dict[int, np.ndarray]] = {"News": {}, "Social": {}}

    # Iterate over each channel
    for channel_name, windows in unfiltered_matrices.items():
        for w_id, unfiltered_matrix in windows.items():
            # Create a deep copy to preserve the original unfiltered matrix artifact
            filtered_matrix: np.ndarray = np.copy(unfiltered_matrix)

            # Extract the significance flags for the current channel and window
            sig_flags = significance_dict.get(channel_name, {}).get(w_id, {})

            # Iterate over all evaluated pairs
            for (source, target), is_significant in sig_flags.items():
                # If the edge is NOT statistically significant, its weight must be zeroed
                if not is_significant:
                    # Map the ticker strings to their canonical integer indices using the O(1) map
                    i: int = ticker_to_position[source]
                    j: int = ticker_to_position[target]

                    # Zero out the matrix entry
                    filtered_matrix[i, j] = 0.0

            # Mathematical Guarantee: Enforce the diagonal policy W_w[i,i] = 0.0
            np.fill_diagonal(filtered_matrix, 0.0)

            # Store the finalized filtered matrix
            filtered_matrices[channel_name][w_id] = filtered_matrix

    logger.info("Successfully constructed significance-filtered adjacency matrices W_w^(sig) using O(1) mapping.")
    return filtered_matrices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 19, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class FilteredAdjacencyReport:
    """
    Immutable data container for the significance-filtered network artifacts.

    Attributes
    ----------
    p_values_dict : Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
        Nested dictionary containing the computed bootstrap p-values for all edges.
    significance_dict : Dict[str, Dict[int, Dict[Tuple[str, str], bool]]]
        Nested dictionary containing the boolean significance flags (True if p < alpha).
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the filtered 34x34 normalized adjacency matrices W_w^(sig).
    """
    p_values_dict: Dict[str, Dict[int, Dict[Tuple[str, str], float]]]
    significance_dict: Dict[str, Dict[int, Dict[Tuple[str, str], bool]]]
    filtered_matrices: Dict[str, Dict[int, np.ndarray]]


def orchestrate_bootstrap_significance_filtering(
    te_report: Any,
    bootstrap_report: Any,
    adjacency_report: Any,
    study_configuration: Dict[str, Any],
    ticker_to_position: Dict[str, int]
) -> Any: # Returns FilteredAdjacencyReport
    """
    Orchestrates Task 19: Computes p-values and filters edges via bootstrap significance test.

    This function executes the statistical inference steps in a strict Directed Acyclic Graph
    (DAG) order. It has been refactored to accept the ticker_to_position map, passing it
    down to the filtering function to guarantee index synchronization.

    Parameters
    ----------
    te_report : TransferEntropyReport
        The dataclass containing the raw TE dictionaries.
    bootstrap_report : MarkovBootstrapReport
        The dataclass containing the null TE distributions.
    adjacency_report : AdjacencyMatrixReport
        The dataclass containing the unfiltered normalized matrices.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing n_boot and alpha.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    FilteredAdjacencyReport
        An immutable dataclass containing the p-values, flags, and filtered matrices.
    """
    logger.info("Starting Task 19 Orchestration: Bootstrap Significance Filtering (Eq. 7).")

    # Extract required parameters from the locked configuration
    n_boot: int = study_configuration["inference_parameters"]["n_boot"]
    alpha: float = study_configuration["inference_parameters"]["alpha"]

    # Extract the required artifacts from the upstream reports
    raw_te_matrices = te_report.raw_te_matrices
    null_te_distributions = bootstrap_report.null_te_distributions
    unfiltered_matrices = adjacency_report.unfiltered_matrices

    # Step 1: Compute the p-value for each directed edge (Equation 7)
    p_values_dict = compute_bootstrap_p_values(
        raw_te_matrices=raw_te_matrices,
        null_te_distributions=null_te_distributions,
        n_boot=n_boot
    )

    # Step 2: Apply the filtering rule with the locked alpha threshold
    significance_dict = evaluate_significance_threshold(
        p_values_dict=p_values_dict,
        alpha=alpha
    )

    # Step 3: Build the filtered adjacency matrices W_w^(sig) using the O(1) map
    filtered_matrices = build_filtered_adjacency_matrices(
        unfiltered_matrices=unfiltered_matrices,
        significance_dict=significance_dict,
        ticker_to_position=ticker_to_position
    )

    # Package the inference artifacts into an immutable dataclass
    report = FilteredAdjacencyReport(
        p_values_dict=p_values_dict,
        significance_dict=significance_dict,
        filtered_matrices=filtered_matrices
    )

    logger.info("=== Task 19 completed successfully. Edges filtered via bootstrap significance. ===")
    return report

# %%
# Task 20 — Compute dynamic network density and edge counts

# ==============================================================================
# Task 20: Compute dynamic network density and edge counts
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 1 & 2: Compute weighted density per window (Eq. 8) and edge count time series
# -------------------------------------------------------------------------------------------------------------------------------
def compute_density_and_edge_counts(
    unfiltered_matrices: Dict[str, Dict[int, np.ndarray]],
    filtered_matrices: Dict[str, Dict[int, np.ndarray]],
    n_nodes: int = 34
) -> pd.DataFrame:
    """
    Computes the weighted network density (Eq. 8) and edge counts for all rolling windows.

    This function processes both the unfiltered and significance-filtered adjacency matrices.
    It implements Equation 8: D_w = sum(T_ij) / (n * (n - 1)). It also computes the total
    number of active directed edges |A_w| where T_ij > 0.

    Parameters
    ----------
    unfiltered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the full 34x34 normalized adjacency matrices.
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.
    n_nodes : int, optional
        The number of nodes in the vertex set V, by default 34.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Window_ID, Filtering_State, Density, and Edge_Count.

    Raises
    ------
    ValueError
        If n_nodes is less than 2, which would cause a division-by-zero error.
    """
    # Enforce mathematical validity of the denominator
    if n_nodes < 2:
        raise ValueError(f"Number of nodes must be at least 2 to compute density. Found: {n_nodes}")

    # Calculate the denominator for Equation 8: n * (n - 1)
    # This represents the maximum possible number of directed edges (excluding self-loops)
    denominator: float = float(n_nodes * (n_nodes - 1))

    # Initialize a list to accumulate the computed metric records
    records: List[Dict[str, Any]] = []

    # Define a helper function to process a specific dictionary of matrices
    def process_matrix_dict(matrix_dict: Dict[str, Dict[int, np.ndarray]], state_label: str) -> None:
        for channel_name, windows in matrix_dict.items():
            for w_id, matrix in windows.items():
                # Validate matrix dimensions to ensure the denominator is applicable
                if matrix.shape != (n_nodes, n_nodes):
                    raise ValueError(f"Matrix shape {matrix.shape} does not match expected ({n_nodes}, {n_nodes}).")

                # Step 1: Compute weighted density (Equation 8)
                # Since the diagonal is strictly 0.0, np.sum() correctly sums only the off-diagonal elements
                total_weight: float = float(np.sum(matrix))
                density: float = total_weight / denominator

                # Step 2: Compute edge count
                # The edge set A_w is defined as pairs where T_ij > 0
                edge_count: int = int(np.count_nonzero(matrix > 0.0))

                # Append the computed metrics to the records list
                records.append({
                    "Channel": channel_name,
                    "Window_ID": w_id,
                    "Filtering_State": state_label,
                    "Density": density,
                    "Edge_Count": edge_count
                })

    # Process the unfiltered matrices (representing the full, noisy network)
    process_matrix_dict(unfiltered_matrices, "Unfiltered")

    # Process the significance-filtered matrices (representing the true information topology)
    process_matrix_dict(filtered_matrices, "Filtered")

    # Convert the accumulated records into a tidy pandas DataFrame
    df_metrics = pd.DataFrame(records)

    logger.info(f"Successfully computed density and edge counts for {len(df_metrics)} matrix instances.")
    return df_metrics

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Step 3: Validate qualitative density patterns
# -------------------------------------------------------------------------------------------------------------------------------
def validate_qualitative_density_patterns(
    df_metrics: pd.DataFrame,
    df_window_metadata: pd.DataFrame
) -> Dict[str, bool]:
    """
    Validates the computed density time series against the manuscript's qualitative invariants.

    This function merges the metrics with window dates and checks two primary conditions:
    1. News density exhibits a spike in the late 2021 / early 2022 period.
    2. Social Media density exhibits a decline post-October 2022.
    Deviations are logged as diagnostic warnings but do not halt pipeline execution.

    Parameters
    ----------
    df_metrics : pd.DataFrame
        The tidy DataFrame containing the computed density metrics (from Steps 1 & 2).
    df_window_metadata : pd.DataFrame
        The metadata DataFrame mapping Window_ID to calendar dates (from Task 15).

    Returns
    -------
    Dict[str, bool]
        A dictionary containing boolean flags indicating whether the expected patterns were observed.
    """
    # Merge the metrics with the window metadata to align densities with calendar dates
    # We use 'End_Date' as the representative timestamp for the 200-day rolling window
    df_merged = pd.merge(
        df_metrics,
        df_window_metadata[["End_Date"]],
        left_on="Window_ID",
        right_index=True,
        how="left"
    )

    # Isolate the significance-filtered networks, as these represent the true findings
    df_filtered = df_merged[df_merged["Filtering_State"] == "Filtered"].copy()

    # Initialize the diagnostic results dictionary
    diagnostic_results: Dict[str, bool] = {
        "news_spike_observed": False,
        "social_decay_observed": False
    }

    # --- Check 1: News Density Spike (Late 2021 to Early 2022) ---
    df_news = df_filtered[df_filtered["Channel"] == "News"]
    if not df_news.empty:
        # Define the baseline period (Pre-August 2021)
        baseline_news = df_news[df_news["End_Date"] < pd.to_datetime("2021-08-02")]["Density"].mean()

        # Define the expected spike period (Oct 2021 to May 2022)
        spike_period_news = df_news[
            (df_news["End_Date"] >= pd.to_datetime("2021-10-01")) &
            (df_news["End_Date"] <= pd.to_datetime("2022-05-31"))
        ]["Density"].mean()

        # Evaluate if the spike period mean is strictly greater than the baseline mean
        if pd.notna(baseline_news) and pd.notna(spike_period_news) and spike_period_news > baseline_news:
            diagnostic_results["news_spike_observed"] = True
            logger.info("Qualitative Validation: News density spike in late 2021/early 2022 successfully observed.")
        else:
            logger.warning("Qualitative Validation Alert: Expected News density spike was NOT observed. "
                           f"Baseline Mean: {baseline_news:.4f}, Spike Period Mean: {spike_period_news:.4f}")

    # --- Check 2: Social Media Density Decay (Post-October 2022) ---
    df_social = df_filtered[df_filtered["Channel"] == "Social"]
    if not df_social.empty:
        # Define the pre-decay baseline (Pre-October 2022)
        baseline_social = df_social[df_social["End_Date"] < pd.to_datetime("2022-10-03")]["Density"].mean()

        # Define the post-decay period (Post-October 2022)
        decay_period_social = df_social[df_social["End_Date"] >= pd.to_datetime("2022-10-03")]["Density"].mean()

        # Evaluate if the post-decay mean is strictly less than the baseline mean
        if pd.notna(baseline_social) and pd.notna(decay_period_social) and decay_period_social < baseline_social:
            diagnostic_results["social_decay_observed"] = True
            logger.info("Qualitative Validation: Social Media density decay post-Oct 2022 successfully observed.")
        else:
            logger.warning("Qualitative Validation Alert: Expected Social Media density decay was NOT observed. "
                           f"Baseline Mean: {baseline_social:.4f}, Post-Oct 2022 Mean: {decay_period_social:.4f}")

    return diagnostic_results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 20, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class NetworkDensityReport:
    """
    Immutable data container for the dynamic network density and edge count artifacts.

    Attributes
    ----------
    df_network_metrics : pd.DataFrame
        Tidy DataFrame containing Density and Edge_Count for all channels, windows, and filtering states.
    qualitative_diagnostics : Dict[str, bool]
        Dictionary containing boolean flags indicating if manuscript-expected patterns were observed.
    """
    df_network_metrics: pd.DataFrame
    qualitative_diagnostics: Dict[str, bool]


def orchestrate_network_density_computation(
    adjacency_report: Any,
    filtered_report: Any,
    window_metadata_report: Any,
    study_configuration: Dict[str, Any]
) -> NetworkDensityReport:
    """
    Orchestrates Task 20: Computes dynamic network density and edge counts.

    This function executes the metric extraction in a strict Directed Acyclic Graph (DAG) order.
    It computes the density (Eq. 8) and edge counts for both unfiltered and filtered matrices,
    and subsequently validates the resulting time series against the qualitative invariants
    described in the manuscript (e.g., the News spike and Social decay).

    Parameters
    ----------
    adjacency_report : AdjacencyMatrixReport
        The dataclass containing the unfiltered adjacency matrices (from Task 17).
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices (from Task 19).
    window_metadata_report : WindowMetadataReport
        The dataclass containing the window-to-date mapping metadata (from Task 15).
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the total node count.

    Returns
    -------
    NetworkDensityReport
        An immutable dataclass containing the computed metrics and diagnostic flags.
    """
    logger.info("Starting Task 20 Orchestration: Dynamic Network Density and Edge Counts (Eq. 8).")

    # Extract required parameters and artifacts
    n_nodes: int = study_configuration["metadata"]["nodes_total"]
    unfiltered_matrices = adjacency_report.unfiltered_matrices
    filtered_matrices = filtered_report.filtered_matrices
    df_window_metadata = window_metadata_report.df_window_metadata

    # Steps 1 & 2: Compute weighted density and edge counts for all matrices
    # This flattens the high-dimensional matrix data into a tidy time-series format
    df_network_metrics = compute_density_and_edge_counts(
        unfiltered_matrices=unfiltered_matrices,
        filtered_matrices=filtered_matrices,
        n_nodes=n_nodes
    )

    # Step 3: Validate the computed time series against the manuscript's qualitative patterns
    # This acts as a diagnostic fidelity check for the entire upstream pipeline
    qualitative_diagnostics = validate_qualitative_density_patterns(
        df_metrics=df_network_metrics,
        df_window_metadata=df_window_metadata
    )

    # Package the metrics and diagnostics into an immutable dataclass
    report = NetworkDensityReport(
        df_network_metrics=df_network_metrics,
        qualitative_diagnostics=qualitative_diagnostics
    )

    logger.info("=== Task 20 completed successfully. Network density and edge counts computed. ===")

    # Return the immutable density report
    return report

# %%
# Task 21 — Compute node-level influence measures: weighted degrees (Eqs. 9–10)

# ==============================================================================
# Task 21: Compute node-level influence measures: weighted degrees (Eqs. 9–10)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 1 & 2: Compute weighted in-degree and out-degree per node per window
# -------------------------------------------------------------------------------------------------------------------------------
def compute_weighted_degrees(
    unfiltered_matrices: Dict[str, Dict[int, np.ndarray]],
    filtered_matrices: Dict[str, Dict[int, np.ndarray]],
    ticker_to_position: Dict[str, int]
) -> pd.DataFrame:
    """
    Computes the weighted in-degree (Eq. 9) and out-degree (Eq. 10) for all nodes.

    This function has been refactored to consume the O(1) ticker_to_position map.
    By inverting this map, it mathematically guarantees that the degree computed at
    matrix index `i` is assigned to the exact corporate entity placed at index `i`
    during the adjacency matrix assembly phase.

    Parameters
    ----------
    unfiltered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the full 34x34 normalized adjacency matrices.
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Window_ID, Filtering_State, Ticker,
        In_Degree, and Out_Degree.

    Raises
    ------
    ValueError
        If any matrix does not match the expected (n, n) dimensions based on the lookup map.
    """
    # Determine the matrix dimension n from the length of the lookup map
    n_nodes: int = len(ticker_to_position)

    # Invert the dictionary to create an O(1) lookup from matrix index to ticker string
    # This is safe and lossless because the original mapping is strictly bijective
    position_to_ticker: Dict[int, str] = {v: k for k, v in ticker_to_position.items()}

    records: List[Dict[str, Any]] = []

    # Define a helper function to process a specific dictionary of matrices
    def process_matrix_dict(matrix_dict: Dict[str, Dict[int, np.ndarray]], state_label: str) -> None:
        for channel_name, windows in matrix_dict.items():
            for w_id, matrix in windows.items():
                # Validate matrix dimensions to ensure alignment with the lookup map
                if matrix.shape != (n_nodes, n_nodes):
                    raise ValueError(f"Matrix shape {matrix.shape} does not match expected ({n_nodes}, {n_nodes}).")

                # Step 1: Compute weighted in-degree (Equation 9)
                # axis=0 collapses the rows, yielding a 1D array of column sums.
                in_degrees: np.ndarray = np.sum(matrix, axis=0)

                # Step 2: Compute weighted out-degree (Equation 10)
                # axis=1 collapses the columns, yielding a 1D array of row sums.
                out_degrees: np.ndarray = np.sum(matrix, axis=1)

                # Iterate through the matrix dimensions and map back to the ticker string
                # This replaces the previous enumeration of a separate list, enforcing the Single Source of Truth
                for i in range(n_nodes):
                    ticker: str = position_to_ticker[i]
                    records.append({
                        "Channel": channel_name,
                        "Window_ID": w_id,
                        "Filtering_State": state_label,
                        "Ticker": ticker,
                        "In_Degree": float(in_degrees[i]),
                        "Out_Degree": float(out_degrees[i])
                    })

    # Process the unfiltered matrices (representing the full, noisy network)
    process_matrix_dict(unfiltered_matrices, "Unfiltered")

    # Process the significance-filtered matrices (representing the true information topology)
    process_matrix_dict(filtered_matrices, "Filtered")

    # Convert the accumulated records into a tidy pandas DataFrame
    df_degrees = pd.DataFrame(records)

    logger.info(f"Successfully computed weighted in/out-degrees using O(1) index mapping.")
    return df_degrees

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Step 3: Produce time-varying degree panels for heatmap visualization
# -------------------------------------------------------------------------------------------------------------------------------
def generate_degree_heatmap_panels(
    df_degrees: pd.DataFrame,
    df_window_metadata: pd.DataFrame,
    canonical_tickers: List[str]
) -> Tuple[Dict[Tuple[str, str, str], pd.DataFrame], Dict[Tuple[str, str, str], pd.DataFrame]]:
    """
    Transforms the tidy degree metrics into wide-form n x W panels for heatmap visualization.

    This function merges the metrics with calendar dates and pivots the data. It produces
    two sets of panels: one strictly ordered by the canonical vertex set V (for downstream
    mathematical operations), and one sorted by persistent influence (mean degree over time)
    to match the manuscript's visualization requirements for Figures 9 and 10.

    Parameters
    ----------
    df_degrees : pd.DataFrame
        The tidy DataFrame containing the computed degree metrics (from Steps 1 & 2).
    df_window_metadata : pd.DataFrame
        The metadata DataFrame mapping Window_ID to calendar dates (from Task 15).
    canonical_tickers : List[str]
        The validated, canonically ordered list of 34 unique ticker strings.

    Returns
    -------
    Tuple[Dict[Tuple[str, str, str], pd.DataFrame], Dict[Tuple[str, str, str], pd.DataFrame]]
        - canonical_panels: Dict keyed by (Channel, State, Degree_Type) -> n x W DataFrame.
        - sorted_panels: Dict keyed by (Channel, State, Degree_Type) -> n x W DataFrame (sorted y-axis).
    """
    # Merge the metrics with the window metadata to align degrees with calendar dates
    # We use the 'Regime_Assignment_Date' locked in Task 15 to represent the window's timestamp
    df_merged = pd.merge(
        df_degrees,
        df_window_metadata[["Regime_Assignment_Date"]],
        left_on="Window_ID",
        right_index=True,
        how="left"
    )

    canonical_panels: Dict[Tuple[str, str, str], pd.DataFrame] = {}
    sorted_panels: Dict[Tuple[str, str, str], pd.DataFrame] = {}

    channels = df_merged["Channel"].unique()
    states = df_merged["Filtering_State"].unique()
    degree_types = ["In_Degree", "Out_Degree"]

    # Iterate over all combinations of Channel, Filtering State, and Degree Type
    for channel in channels:
        for state in states:
            for deg_type in degree_types:
                # Isolate the specific subset of data
                mask = (df_merged["Channel"] == channel) & (df_merged["Filtering_State"] == state)
                df_subset = df_merged[mask]

                # Pivot the data: Rows = Tickers, Columns = Dates, Values = Degree
                # This creates the n x W matrix required for heatmap plotting
                df_pivot = df_subset.pivot(
                    index="Ticker",
                    columns="Regime_Assignment_Date",
                    values=deg_type
                )

                # 1. Create the Canonical Panel
                # Mathematically enforce the row order to match the canonical vertex set V
                # fill_value=0.0 ensures that any structurally missing data is treated as zero degree
                df_canonical = df_pivot.reindex(index=canonical_tickers, fill_value=0.0)

                # Ensure columns (dates) are strictly sorted chronologically
                df_canonical = df_canonical.sort_index(axis=1)

                canonical_panels[(channel, state, deg_type)] = df_canonical

                # 2. Create the Sorted Panel (for visualization)
                # The manuscript states: "Companies are ranked on the y-axis based on the frequency
                # of their persistent influence over time." We operationalize this by sorting by the row mean.
                row_means = df_canonical.mean(axis=1)
                sorted_tickers = row_means.sort_values(ascending=False).index.tolist()

                df_sorted = df_canonical.reindex(index=sorted_tickers)
                sorted_panels[(channel, state, deg_type)] = df_sorted

    logger.info("Successfully generated canonical and sorted heatmap panels for all degree types.")
    return canonical_panels, sorted_panels

# -------------------------------------------------------------------------------------------------------------------------------
# Task 21, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class NodeInfluenceReport:
    """
    Immutable data container for the node-level influence artifacts (Degrees).

    Attributes
    ----------
    df_degree_metrics : pd.DataFrame
        Tidy DataFrame containing In_Degree and Out_Degree for all nodes, windows, and states.
    canonical_heatmap_panels : Dict[Tuple[str, str, str], pd.DataFrame]
        Dictionary of n x W DataFrames ordered by the canonical vertex set V.
        Keys: (Channel, Filtering_State, Degree_Type).
    sorted_heatmap_panels : Dict[Tuple[str, str, str], pd.DataFrame]
        Dictionary of n x W DataFrames sorted by persistent influence for plotting.
        Keys: (Channel, Filtering_State, Degree_Type).
    """
    df_degree_metrics: pd.DataFrame
    canonical_heatmap_panels: Dict[Tuple[str, str, str], pd.DataFrame]
    sorted_heatmap_panels: Dict[Tuple[str, str, str], pd.DataFrame]


def orchestrate_node_influence_computation(
    adjacency_report: Any,
    filtered_report: Any,
    window_metadata_report: Any,
    study_configuration: Dict[str, Any],
    ticker_to_position: Dict[str, int]
) -> Any: # Returns NodeInfluenceReport
    """
    Orchestrates Task 21: Computes node-level influence measures (weighted degrees).

    This function has been refactored to accept the ticker_to_position map, passing it
    down to the degree computation function to guarantee index synchronization. It also
    dynamically reconstructs the ordered ticker list for the heatmap generator to maintain
    downstream compatibility without violating the Single Source of Truth.

    Parameters
    ----------
    adjacency_report : AdjacencyMatrixReport
        The dataclass containing the unfiltered adjacency matrices.
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices.
    window_metadata_report : WindowMetadataReport
        The dataclass containing the window-to-date mapping metadata.
    study_configuration : Dict[str, Any]
        The master configuration dictionary.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    NodeInfluenceReport
        An immutable dataclass containing the computed metrics and heatmap panels.
    """
    logger.info("Starting Task 21 Orchestration: Node-Level Influence Measures (Eqs. 9-10).")

    # Extract required artifacts
    unfiltered_matrices = adjacency_report.unfiltered_matrices
    filtered_matrices = filtered_report.filtered_matrices
    df_window_metadata = window_metadata_report.df_window_metadata

    # Steps 1 & 2: Compute weighted in-degree and out-degree using the O(1) map
    df_degree_metrics = compute_weighted_degrees(
        unfiltered_matrices=unfiltered_matrices,
        filtered_matrices=filtered_matrices,
        ticker_to_position=ticker_to_position
    )

    # Reconstruct the ordered list of tickers strictly from the O(1) map for the heatmap generator
    ordered_tickers: List[str] = [k for k, v in sorted(ticker_to_position.items(), key=lambda item: item[1])]

    # Step 3: Produce time-varying degree panels for heatmap visualization
    # Note: generate_degree_heatmap_panels is assumed to be available in the working environment
    canonical_panels, sorted_panels = generate_degree_heatmap_panels(
        df_degrees=df_degree_metrics,
        df_window_metadata=df_window_metadata,
        canonical_tickers=ordered_tickers
    )

    # Package the metrics and panels into an immutable dataclass
    report = NodeInfluenceReport(
        df_degree_metrics=df_degree_metrics,
        canonical_heatmap_panels=canonical_panels,
        sorted_heatmap_panels=sorted_panels
    )

    logger.info("=== Task 21 completed successfully. Node-level degrees computed and paneled. ===")
    return report

# %%
# Task 22 — Compute weighted PageRank with locked dangling-node policy (Eq. 11)

# ==============================================================================
# Task 22: Compute weighted PageRank with locked dangling-node policy (Eq. 11)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Step 1 & 2: Define PageRank recursion (Eq. 11) and apply dangling-node policy
# -------------------------------------------------------------------------------------------------------------------------------
def compute_pagerank_power_iteration(
    matrix_w: np.ndarray,
    f: float,
    tol: float,
    max_iter: int
) -> np.ndarray:
    """
    Computes the weighted PageRank vector using the power iteration method.

    This function implements Equation 11:
    PR(v_i) = (1-f)/n + f * sum_{v_j} [ T_{ji} / d_{v_j}^{out} * PR(v_j) ].
    It mathematically enforces the dangling-node policy by redistributing the mass
    of nodes with zero out-degree uniformly across all n nodes.

    Parameters
    ----------
    matrix_w : np.ndarray
        The 34x34 significance-filtered adjacency matrix W_w.
    f : float
        The damping factor (typically 0.85).
    tol : float
        The convergence tolerance for the L_infinity norm (typically 1e-12).
    max_iter : int
        The maximum number of iterations allowed before raising a convergence error.

    Returns
    -------
    np.ndarray
        A 1D numpy array of length n containing the converged PageRank scores.

    Raises
    ------
    RuntimeError
        If the power iteration fails to converge within max_iter.
    """
    n: int = matrix_w.shape[0]

    # Step 2: Apply dangling-node policy for d^{out} = 0 cases
    # Calculate the out-degree (row sums) for each node
    out_degrees: np.ndarray = np.sum(matrix_w, axis=1)

    # Initialize the row-stochastic transition matrix P
    P: np.ndarray = np.zeros_like(matrix_w, dtype=float)

    # Identify dangling nodes (out-degree effectively zero)
    # We use a small epsilon to account for floating-point inaccuracies
    epsilon: float = 1e-12
    dangling_mask: np.ndarray = out_degrees < epsilon

    # For non-dangling nodes, normalize the row by its out-degree
    # P[j, i] = W[j, i] / d_j^{out}
    non_dangling_mask: np.ndarray = ~dangling_mask
    P[non_dangling_mask, :] = matrix_w[non_dangling_mask, :] / out_degrees[non_dangling_mask, np.newaxis]

    # For dangling nodes, redistribute mass uniformly across all nodes [UNSPECIFIED IN MANUSCRIPT]
    P[dangling_mask, :] = 1.0 / n

    # Step 1: Define PageRank recursion and iterate to convergence
    # Initialize the PageRank vector uniformly
    x: np.ndarray = np.ones(n, dtype=float) / n

    # Define the teleportation vector (the random surfer jump probability)
    teleport: np.ndarray = np.ones(n, dtype=float) * (1.0 - f) / n

    # Execute the power iteration
    for iteration in range(max_iter):
        # x_{t+1} = (1-f)/n + f * P^T * x_t
        # We use P.T because P[j, i] represents flow FROM j TO i.
        x_new: np.ndarray = teleport + f * np.dot(P.T, x)

        # Check for convergence using the L_infinity norm (maximum absolute difference)
        if np.max(np.abs(x_new - x)) < tol:
            return x_new

        x = x_new

    # If the loop completes without returning, convergence failed
    raise RuntimeError(f"PageRank power iteration failed to converge after {max_iter} iterations.")

def compute_all_pageranks(
    filtered_matrices: Dict[str, Dict[int, np.ndarray]],
    ticker_to_position: Dict[str, int],
    study_configuration: Dict[str, Any]
) -> pd.DataFrame:
    """
    Computes PageRank scores for all nodes across all channels and rolling windows.

    This function has been refactored to consume the O(1) ticker_to_position map.
    It mathematically guarantees that the PageRank score computed at vector index `i`
    is perfectly attributed to the correct corporate entity.

    Parameters
    ----------
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing PageRank parameters.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Window_ID, Ticker, and PageRank.
    """
    # Extract PageRank parameters from the locked configuration
    pr_config = study_configuration["topological_metrics"]["pagerank"]
    f: float = pr_config["damping_factor_f"]
    tol: float = pr_config["convergence_tolerance"]
    max_iter: int = pr_config["max_iterations"]

    # Determine the matrix dimension n and invert the lookup map
    n_nodes: int = len(ticker_to_position)
    position_to_ticker: Dict[int, str] = {v: k for k, v in ticker_to_position.items()}

    records: List[Dict[str, Any]] = []

    # Iterate over each channel and window
    for channel_name, windows in filtered_matrices.items():
        for w_id, matrix_w in windows.items():
            # Compute the PageRank vector for the current window
            # Note: compute_pagerank_power_iteration is assumed to be available in the working environment
            pr_vector: np.ndarray = compute_pagerank_power_iteration(
                matrix_w=matrix_w, f=f, tol=tol, max_iter=max_iter
            )

            # Map the computed scores back to the ticker strings using the inverted O(1) map
            for i in range(n_nodes):
                ticker: str = position_to_ticker[i]
                records.append({
                    "Channel": channel_name,
                    "Window_ID": w_id,
                    "Ticker": ticker,
                    "PageRank": float(pr_vector[i])
                })

    # Convert the accumulated records into a tidy pandas DataFrame
    df_pagerank = pd.DataFrame(records)

    logger.info(f"Successfully computed PageRank scores using O(1) index mapping.")
    return df_pagerank

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Step 3: Iterate to convergence and produce top-5 rankings
# -------------------------------------------------------------------------------------------------------------------------------
def extract_top_5_rankings(
    df_pagerank: pd.DataFrame,
    df_degree_metrics: pd.DataFrame
) -> pd.DataFrame:
    """
    Produces the top-5 influential companies based on persistent influence over time.

    This function merges the PageRank scores with the significance-filtered degree metrics.
    It operationalizes "persistent influence" by computing the temporal mean of each metric
    across all rolling windows. It then ranks the tickers deterministically, breaking ties
    using the canonical ticker string.

    Parameters
    ----------
    df_pagerank : pd.DataFrame
        The tidy DataFrame containing computed PageRank scores.
    df_degree_metrics : pd.DataFrame
        The tidy DataFrame containing In_Degree and Out_Degree metrics (from Task 21).

    Returns
    -------
    pd.DataFrame
        A presentation-ready DataFrame containing the Top 5 tickers for each metric and channel.
    """
    # Filter the degree metrics to include ONLY the significance-filtered networks
    # Unfiltered networks contain structural noise and should not be used for final rankings
    df_degrees_filtered = df_degree_metrics[df_degree_metrics["Filtering_State"] == "Filtered"].copy()

    # Merge PageRank scores with the degree metrics on the composite logical key
    df_merged = pd.merge(
        df_pagerank,
        df_degrees_filtered[["Channel", "Window_ID", "Ticker", "In_Degree", "Out_Degree"]],
        on=["Channel", "Window_ID", "Ticker"],
        how="inner"
    )

    # Compute the temporal mean for each ticker within each channel to capture "persistent influence"
    df_agg = df_merged.groupby(["Channel", "Ticker"])[["PageRank", "Out_Degree", "In_Degree"]].mean().reset_index()

    ranking_records: List[Dict[str, Any]] = []
    metrics_to_rank = ["PageRank", "Out_Degree", "In_Degree"]

    # Iterate over each channel to extract the top 5 for each metric
    for channel in df_agg["Channel"].unique():
        df_channel = df_agg[df_agg["Channel"] == channel]

        for metric in metrics_to_rank:
            # Sort deterministically: descending by the metric, ascending by Ticker to break ties
            df_sorted = df_channel.sort_values(by=[metric, "Ticker"], ascending=[False, True])

            # Extract the top 5 rows
            top_5 = df_sorted.head(5)

            # Append the ranked records
            for rank, (_, row) in enumerate(top_5.iterrows(), start=1):
                ranking_records.append({
                    "Channel": channel,
                    "Metric": metric,
                    "Rank": rank,
                    "Ticker": row["Ticker"],
                    "Mean_Score": row[metric]
                })

    # Convert to a tidy DataFrame
    df_top_5_rankings = pd.DataFrame(ranking_records)

    logger.info("Successfully extracted Top-5 persistent influence rankings for all metrics.")
    return df_top_5_rankings

# -------------------------------------------------------------------------------------------------------------------------------
# Task 22, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class PageRankAndRankingReport:
    """
    Immutable data container for the PageRank and Top-5 Ranking artifacts.

    Attributes
    ----------
    df_pagerank_scores : pd.DataFrame
        Tidy DataFrame containing the computed PageRank scores for all nodes and windows.
    df_top_5_rankings : pd.DataFrame
        Presentation-ready DataFrame containing the Top 5 tickers by persistent influence
        for PageRank, Out-Degree, and In-Degree across both channels.
    """
    df_pagerank_scores: pd.DataFrame
    df_top_5_rankings: pd.DataFrame


def orchestrate_pagerank_and_rankings(
    filtered_report: Any,
    influence_report: Any,
    study_configuration: Dict[str, Any],
    ticker_to_position: Dict[str, int]
) -> Any: # Returns PageRankAndRankingReport
    """
    Orchestrates Task 22: Computes weighted PageRank and produces top-5 rankings.

    This function has been refactored to accept the ticker_to_position map, passing it
    down to the PageRank computation function to guarantee index synchronization.

    Parameters
    ----------
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices.
    influence_report : NodeInfluenceReport
        The dataclass containing the computed degree metrics.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing PageRank parameters.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    PageRankAndRankingReport
        An immutable dataclass containing the PageRank scores and Top-5 rankings.
    """
    logger.info("Starting Task 22 Orchestration: Weighted PageRank and Top-5 Rankings (Eq. 11).")

    # Extract required artifacts
    filtered_matrices = filtered_report.filtered_matrices
    df_degree_metrics = influence_report.df_degree_metrics

    # Steps 1 & 2: Compute PageRank scores using the O(1) map
    df_pagerank_scores = compute_all_pageranks(
        filtered_matrices=filtered_matrices,
        ticker_to_position=ticker_to_position,
        study_configuration=study_configuration
    )

    # Step 3: Aggregate metrics over time and extract the deterministic Top-5 rankings
    # Note: extract_top_5_rankings is assumed to be available in the working environment
    df_top_5_rankings = extract_top_5_rankings(
        df_pagerank=df_pagerank_scores,
        df_degree_metrics=df_degree_metrics
    )

    # Package the metrics and rankings into an immutable dataclass
    report = PageRankAndRankingReport(
        df_pagerank_scores=df_pagerank_scores,
        df_top_5_rankings=df_top_5_rankings
    )

    logger.info("=== Task 22 completed successfully. PageRank computed and rankings extracted. ===")
    return report

# %%
# Task 23 — Segment windows into regimes using paper-stated breakpoints

# ==============================================================================
# Task 23: Segment windows into regimes using paper-stated breakpoints
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 1: Lock regime boundaries
# -------------------------------------------------------------------------------------------------------------------------------
def lock_regime_boundaries(study_configuration: Dict[str, Any]) -> Tuple[pd.Timestamp, pd.Timestamp]:
    """
    Parses and locks the mathematical boundaries for the three temporal regimes.

    This function extracts the string-based breakpoints from the configuration,
    converts them to strict pandas Timestamp objects, and ensures they are
    chronologically sorted. This prevents silent downstream failures caused by
    malformed or misordered date strings.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the visualization parameters.

    Returns
    -------
    Tuple[pd.Timestamp, pd.Timestamp]
        A tuple containing (t_1, t_2), representing the exact boundaries between
        Regime 1 & 2, and Regime 2 & 3, respectively.

    Raises
    ------
    KeyError
        If the 'regime_breakpoints' key is missing from the configuration.
    ValueError
        If exactly two breakpoints are not provided, or if parsing fails.
    """
    # Extract the breakpoints list from the configuration
    try:
        breakpoints_str: List[str] = study_configuration["visualization_parameters"]["regime_breakpoints"]
    except KeyError as e:
        raise KeyError(f"Missing required configuration key for regime boundaries: {str(e)}")

    # Enforce the mathematical constraint: exactly two breakpoints define three regimes
    if len(breakpoints_str) != 2:
        raise ValueError(f"Exactly two regime breakpoints are required. Found: {len(breakpoints_str)}")

    try:
        # Parse the strings into strict pandas Timestamps
        # errors='raise' ensures that invalid formats immediately halt execution
        t_1 = pd.to_datetime(breakpoints_str[0], errors='raise')
        t_2 = pd.to_datetime(breakpoints_str[1], errors='raise')
    except Exception as e:
        raise ValueError(f"Failed to parse regime breakpoints into Timestamps. Details: {str(e)}")

    # Ensure chronological ordering to maintain logical interval boundaries
    if t_1 > t_2:
        logger.warning("Regime breakpoints were not chronologically sorted. Sorting applied automatically.")
        t_1, t_2 = t_2, t_1

    logger.info(f"Successfully locked regime boundaries: t_1={t_1.date()}, t_2={t_2.date()}.")
    return t_1, t_2

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 2: Lock regime assignment rule for rolling windows
# -------------------------------------------------------------------------------------------------------------------------------
def assign_regimes_to_windows(
    df_window_metadata: pd.DataFrame,
    t_1: pd.Timestamp,
    t_2: pd.Timestamp
) -> pd.DataFrame:
    """
    Assigns each rolling window to a specific regime based on its locked assignment date.

    This function applies the strict mathematical intervals defined in the manuscript:
    - Regime 1: Date < t_1
    - Regime 2: t_1 <= Date <= t_2
    - Regime 3: Date > t_2
    It uses vectorized numpy operations to map these conditions to integer Regime IDs.

    Parameters
    ----------
    df_window_metadata : pd.DataFrame
        The metadata DataFrame containing the 'Regime_Assignment_Date' column.
    t_1 : pd.Timestamp
        The boundary between Regime 1 and Regime 2.
    t_2 : pd.Timestamp
        The boundary between Regime 2 and Regime 3.

    Returns
    -------
    pd.DataFrame
        A deep copy of the metadata DataFrame with a new 'Regime_ID' integer column.

    Raises
    ------
    KeyError
        If the 'Regime_Assignment_Date' column is missing.
    """
    # Create a deep copy to preserve the immutability of upstream artifacts
    df_assigned = df_window_metadata.copy(deep=True)

    # Verify the existence of the locked assignment date column
    if "Regime_Assignment_Date" not in df_assigned.columns:
        raise KeyError("The required column 'Regime_Assignment_Date' is missing from the metadata.")

    # Extract the assignment dates as a pandas Series
    assignment_dates = df_assigned["Regime_Assignment_Date"]

    # Define the boolean conditions for each regime
    # The manuscript specifies "2021-08-02 to 2022-10-03" for Regime 2, implying inclusive bounds
    cond_regime_1 = assignment_dates < t_1
    cond_regime_2 = (assignment_dates >= t_1) & (assignment_dates <= t_2)
    cond_regime_3 = assignment_dates > t_2

    # Define the corresponding integer Regime IDs
    choices = [1, 2, 3]

    # Apply the conditions using vectorized numpy select
    # default=-1 acts as a sentinel value for any unhandled edge cases
    df_assigned["Regime_ID"] = np.select(
        [cond_regime_1, cond_regime_2, cond_regime_3],
        choices,
        default=-1
    )

    # Validate that no windows fell through the conditional logic
    if (df_assigned["Regime_ID"] == -1).any():
        raise ValueError("Critical Error: One or more windows could not be assigned to a valid regime.")

    logger.info("Successfully assigned Regime IDs to all rolling windows.")
    return df_assigned

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Step 3: Partition window sets
# -------------------------------------------------------------------------------------------------------------------------------
def partition_window_sets(df_assigned_metadata: pd.DataFrame) -> Dict[int, List[int]]:
    """
    Partitions the Window IDs into mathematical sets W_r based on their assigned Regime ID.

    This function groups the metadata by Regime_ID and extracts the corresponding
    Window_IDs into sorted lists. It mathematically guarantees that no regime is empty,
    preventing division-by-zero errors during downstream matrix aggregation.

    Parameters
    ----------
    df_assigned_metadata : pd.DataFrame
        The metadata DataFrame containing the 'Regime_ID' column (from Step 2).

    Returns
    -------
    Dict[int, List[int]]
        A dictionary mapping Regime_ID (1, 2, 3) to a sorted list of Window_IDs.

    Raises
    ------
    ValueError
        If any of the three regimes contains zero windows.
    """
    # Initialize the output dictionary representing the sets W_r
    W_r: Dict[int, List[int]] = {}

    # Group the DataFrame by the integer Regime_ID
    grouped = df_assigned_metadata.groupby("Regime_ID")

    # Iterate over the expected regimes (1, 2, 3)
    for regime_id in [1, 2, 3]:
        if regime_id in grouped.groups:
            # Extract the index (Window_ID) for the current group
            # Convert to a list and sort to guarantee deterministic iteration order downstream
            window_list = sorted(list(grouped.groups[regime_id]))
            W_r[regime_id] = window_list
        else:
            # If a regime is entirely missing from the groups, it contains zero windows
            raise ValueError(f"Fatal Error: Regime {regime_id} contains zero windows. "
                             f"Check calendar alignment and breakpoint configuration.")

    # Log the cardinality of each partitioned set
    logger.info(f"Successfully partitioned window sets: "
                f"|W_1|={len(W_r[1])}, |W_2|={len(W_r[2])}, |W_3|={len(W_r[3])}.")

    return W_r

# -------------------------------------------------------------------------------------------------------------------------------
# Task 23, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class RegimeSegmentationReport:
    """
    Immutable data container for the regime segmentation artifacts.

    Attributes
    ----------
    df_regime_metadata : pd.DataFrame
        The metadata DataFrame updated with the 'Regime_ID' column.
    regime_window_sets : Dict[int, List[int]]
        Dictionary mapping Regime_ID (1, 2, 3) to a sorted list of Window_IDs (W_r).
    t_1 : pd.Timestamp
        The locked boundary between Regime 1 and Regime 2.
    t_2 : pd.Timestamp
        The locked boundary between Regime 2 and Regime 3.
    """
    df_regime_metadata: pd.DataFrame
    regime_window_sets: Dict[int, List[int]]
    t_1: pd.Timestamp
    t_2: pd.Timestamp


def orchestrate_regime_segmentation(
    window_metadata_report: Any,
    study_configuration: Dict[str, Any]
) -> RegimeSegmentationReport:
    """
    Orchestrates Task 23: Segments windows into regimes using paper-stated breakpoints.

    This function executes the segmentation steps in a strict Directed Acyclic Graph (DAG) order.
    It parses the temporal boundaries, assigns each rolling window to a specific regime based
    on its locked assignment date, and partitions the Window IDs into mathematical sets (W_r)
    required for downstream regime-level network aggregation.

    Parameters
    ----------
    window_metadata_report : WindowMetadataReport
        The dataclass containing the window-to-date mapping metadata (from Task 15).
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the regime breakpoints.

    Returns
    -------
    RegimeSegmentationReport
        An immutable dataclass containing the updated metadata and partitioned sets.
    """
    logger.info("Starting Task 23 Orchestration: Regime Segmentation.")

    # Extract the base metadata DataFrame
    df_base_metadata = window_metadata_report.df_window_metadata

    # Step 1: Parse and lock the mathematical boundaries for the regimes
    t_1, t_2 = lock_regime_boundaries(study_configuration)

    # Step 2: Assign each rolling window to a regime based on the locked boundaries
    df_regime_metadata = assign_regimes_to_windows(
        df_window_metadata=df_base_metadata,
        t_1=t_1,
        t_2=t_2
    )

    # Step 3: Partition the Window IDs into mathematical sets W_r
    regime_window_sets = partition_window_sets(df_regime_metadata)

    # Package the segmentation artifacts into an immutable dataclass
    report = RegimeSegmentationReport(
        df_regime_metadata=df_regime_metadata,
        regime_window_sets=regime_window_sets,
        t_1=t_1,
        t_2=t_2
    )

    logger.info("=== Task 23 completed successfully. Windows segmented into regimes. ===")

    # Return the immutable segmentation report
    return report

# %%
# Task 24 — Construct regime-specific networks via aggregation operator

# ==============================================================================
# Task 24: Construct regime-specific networks via aggregation operator
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 1 & 2: Lock aggregation operator and compute regime networks
# -------------------------------------------------------------------------------------------------------------------------------
def construct_regime_networks(
    filtered_matrices: Dict[str, Dict[int, np.ndarray]],
    regime_window_sets: Dict[int, List[int]],
    n_nodes: int = 34
) -> Dict[str, Dict[int, np.ndarray]]:
    """
    Constructs regime-specific networks using the elementwise average aggregation operator.

    This function implements the engineering convention [UNSPECIFIED IN MANUSCRIPT] to
    aggregate rolling window matrices into a single regime matrix:
    W^(r) = (1 / |W_r|) * sum_{w in W_r} W_w^(sig).
    It strictly uses the significance-filtered matrices to ensure the resulting regime
    network represents true, statistically validated information flow.

    Parameters
    ----------
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.
    regime_window_sets : Dict[int, List[int]]
        Dictionary mapping Regime_ID (1, 2, 3) to a sorted list of Window_IDs (W_r).
    n_nodes : int, optional
        The number of nodes in the vertex set V, by default 34.

    Returns
    -------
    Dict[str, Dict[int, np.ndarray]]
        A nested dictionary mapping Channel -> Regime_ID -> 34x34 numpy array.

    Raises
    ------
    ValueError
        If a regime set is empty, precluding the calculation of a mean.
    KeyError
        If a required window matrix is missing from the filtered_matrices dictionary.
    """
    # Initialize the output dictionary hierarchy
    regime_matrices: Dict[str, Dict[int, np.ndarray]] = {"News": {}, "Social": {}}

    # Iterate over each channel (News, Social)
    for channel_name, windows_dict in filtered_matrices.items():

        # Iterate over each defined regime and its associated set of Window IDs
        for regime_id, window_ids in regime_window_sets.items():

            # Enforce mathematical validity: cannot compute mean of an empty set
            if not window_ids:
                raise ValueError(f"Regime {regime_id} contains zero windows. Aggregation impossible.")

            # Initialize a list to collect the 2D numpy arrays for the current regime
            matrix_stack: List[np.ndarray] = []

            # Extract the filtered matrix for each window in the regime set
            for w_id in window_ids:
                if w_id not in windows_dict:
                    raise KeyError(f"Missing filtered matrix for {channel_name}, Window {w_id}.")

                matrix_w = windows_dict[w_id]

                # Validate dimensions before stacking
                if matrix_w.shape != (n_nodes, n_nodes):
                    raise ValueError(f"Matrix shape {matrix_w.shape} does not match expected ({n_nodes}, {n_nodes}).")

                matrix_stack.append(matrix_w)

            # Convert the list of 2D arrays into a 3D numpy array of shape (|W_r|, n, n)
            stacked_array = np.stack(matrix_stack, axis=0)

            # Apply the aggregation operator: elementwise mean across the temporal axis (axis=0)
            # W^(r) = (1 / |W_r|) * sum_{w in W_r} W_w^(sig)
            regime_matrix = np.mean(stacked_array, axis=0)

            # Mathematical Guarantee: Enforce the diagonal policy W^(r)[i,i] = 0.0
            # While the average of zeros is zero, this prevents any floating-point noise accumulation
            np.fill_diagonal(regime_matrix, 0.0)

            # Store the finalized regime matrix
            regime_matrices[channel_name][regime_id] = regime_matrix

    logger.info("Successfully constructed 6 regime-specific networks using elementwise average [UNSPECIFIED IN MANUSCRIPT].")
    return regime_matrices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Step 3: Validate regime networks have interpretable density
# -------------------------------------------------------------------------------------------------------------------------------
def compute_and_validate_regime_densities(
    regime_matrices: Dict[str, Dict[int, np.ndarray]],
    n_nodes: int = 34
) -> Tuple[pd.DataFrame, Dict[str, bool]]:
    """
    Computes the weighted density for each regime network and validates qualitative patterns.

    This function implements Equation 8: D^(r) = sum(T_ij^(r)) / (n * (n - 1)) directly
    on the aggregated regime matrices. It then performs diagnostic checks to verify if
    the manuscript's qualitative findings (e.g., News Regime 2 > Regime 1) hold true.

    Parameters
    ----------
    regime_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the aggregated regime matrices (from Steps 1 & 2).
    n_nodes : int, optional
        The number of nodes in the vertex set V, by default 34.

    Returns
    -------
    Tuple[pd.DataFrame, Dict[str, bool]]
        - df_regime_densities: Tidy DataFrame containing Channel, Regime_ID, and Regime_Density.
        - diagnostic_results: Dictionary of boolean flags indicating if expected patterns were observed.

    Raises
    ------
    ValueError
        If n_nodes is less than 2, causing a division-by-zero error.
    """
    if n_nodes < 2:
        raise ValueError(f"Number of nodes must be at least 2 to compute density. Found: {n_nodes}")

    # Calculate the denominator for Equation 8: n * (n - 1)
    denominator: float = float(n_nodes * (n_nodes - 1))

    records: List[Dict[str, Any]] = []

    # Compute density for each regime matrix
    for channel_name, regimes in regime_matrices.items():
        for regime_id, matrix in regimes.items():
            # Compute weighted density (Equation 8)
            total_weight: float = float(np.sum(matrix))
            density: float = total_weight / denominator

            records.append({
                "Channel": channel_name,
                "Regime_ID": regime_id,
                "Regime_Density": density
            })

    # Convert to a tidy pandas DataFrame
    df_regime_densities = pd.DataFrame(records)

    # Initialize diagnostic results
    diagnostic_results: Dict[str, bool] = {
        "news_regime2_gt_regime1": False,
        "social_regime3_lt_regime1": False
    }

    # --- Diagnostic Check 1: News Regime 2 > Regime 1 ---
    # The manuscript notes a clear spike in news-based information spillover at the end of 2021 (Regime 2)
    df_news = df_regime_densities[df_regime_densities["Channel"] == "News"]
    if not df_news.empty and set([1, 2]).issubset(df_news["Regime_ID"].values):
        d1_news = df_news[df_news["Regime_ID"] == 1]["Regime_Density"].iloc[0]
        d2_news = df_news[df_news["Regime_ID"] == 2]["Regime_Density"].iloc[0]

        if d2_news > d1_news:
            diagnostic_results["news_regime2_gt_regime1"] = True
            logger.info(f"Qualitative Validation: News Regime 2 density ({d2_news:.4f}) > Regime 1 ({d1_news:.4f}).")
        else:
            logger.warning(f"Qualitative Validation Alert: News Regime 2 density ({d2_news:.4f}) is NOT greater than Regime 1 ({d1_news:.4f}).")

    # --- Diagnostic Check 2: Social Media Regime 3 < Regime 1 ---
    # The manuscript notes a decrease in social media spillover post-Twitter rebranding (Regime 3)
    df_social = df_regime_densities[df_regime_densities["Channel"] == "Social"]
    if not df_social.empty and set([1, 3]).issubset(df_social["Regime_ID"].values):
        d1_social = df_social[df_social["Regime_ID"] == 1]["Regime_Density"].iloc[0]
        d3_social = df_social[df_social["Regime_ID"] == 3]["Regime_Density"].iloc[0]

        if d3_social < d1_social:
            diagnostic_results["social_regime3_lt_regime1"] = True
            logger.info(f"Qualitative Validation: Social Regime 3 density ({d3_social:.4f}) < Regime 1 ({d1_social:.4f}).")
        else:
            logger.warning(f"Qualitative Validation Alert: Social Regime 3 density ({d3_social:.4f}) is NOT less than Regime 1 ({d1_social:.4f}).")

    return df_regime_densities, diagnostic_results

# -------------------------------------------------------------------------------------------------------------------------------
# Task 24, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class RegimeNetworkReport:
    """
    Immutable data container for the regime-specific network artifacts.

    Attributes
    ----------
    regime_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary mapping Channel -> Regime_ID -> 34x34 aggregated numpy array.
    df_regime_densities : pd.DataFrame
        Tidy DataFrame containing the computed density for each regime network.
    qualitative_diagnostics : Dict[str, bool]
        Dictionary containing boolean flags indicating if manuscript-expected patterns were observed.
    """
    regime_matrices: Dict[str, Dict[int, np.ndarray]]
    df_regime_densities: pd.DataFrame
    qualitative_diagnostics: Dict[str, bool]


def orchestrate_regime_network_construction(
    filtered_report: Any,
    segmentation_report: Any,
    study_configuration: Dict[str, Any]
) -> RegimeNetworkReport:
    """
    Orchestrates Task 24: Constructs regime-specific networks via aggregation operator.

    This function executes the construction steps in a strict Directed Acyclic Graph (DAG) order.
    It applies the elementwise average operator to the significance-filtered matrices within
    each partitioned regime set, mathematically enforces the diagonal policy, and computes
    the resulting regime-level densities to validate qualitative manuscript findings.

    Parameters
    ----------
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices (from Task 19).
    segmentation_report : RegimeSegmentationReport
        The dataclass containing the partitioned window sets W_r (from Task 23).
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the total node count.

    Returns
    -------
    RegimeNetworkReport
        An immutable dataclass containing the regime matrices and density metrics.
    """
    logger.info("Starting Task 24 Orchestration: Regime-Specific Network Construction.")

    # Extract required parameters and artifacts
    n_nodes: int = study_configuration["metadata"]["nodes_total"]
    filtered_matrices = filtered_report.filtered_matrices
    regime_window_sets = segmentation_report.regime_window_sets

    # Steps 1 & 2: Lock aggregation operator and compute the 6 regime networks
    # This collapses the temporal dimension (windows) into discrete regimes
    regime_matrices = construct_regime_networks(
        filtered_matrices=filtered_matrices,
        regime_window_sets=regime_window_sets,
        n_nodes=n_nodes
    )

    # Step 3: Compute densities directly from the new regime matrices and validate patterns
    # This provides a macro-level view of systemic interconnectedness per regime
    df_regime_densities, qualitative_diagnostics = compute_and_validate_regime_densities(
        regime_matrices=regime_matrices,
        n_nodes=n_nodes
    )

    # Package the artifacts into an immutable dataclass
    report = RegimeNetworkReport(
        regime_matrices=regime_matrices,
        df_regime_densities=df_regime_densities,
        qualitative_diagnostics=qualitative_diagnostics
    )

    logger.info("=== Task 24 completed successfully. Regime networks constructed and validated. ===")

    # Return the immutable regime network report
    return report

# %%
# Task 25 — Extract Maximum Spanning Arborescence backbones per regime

# ==============================================================================
# Task 25: Extract Maximum Spanning Arborescence backbones per regime
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 1: Select root using weighted out-degree
# -------------------------------------------------------------------------------------------------------------------------------
def select_msa_roots(
    regime_matrices: Dict[str, Dict[int, np.ndarray]],
    ticker_to_position: Dict[str, int]
) -> Dict[str, Dict[int, int]]:
    """
    Identifies the optimal root node for the MSA based on peak weighted out-degree.

    This function has been refactored to consume the O(1) ticker_to_position map.
    It uses the inverted map to accurately log the ticker string corresponding to the
    mathematically selected root index.

    Parameters
    ----------
    regime_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the aggregated 34x34 regime matrices.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    Dict[str, Dict[int, int]]
        A nested dictionary mapping Channel -> Regime_ID -> Root_Index (int).

    Raises
    ------
    ValueError
        If the maximum out-degree is exactly 0.0.
    """
    # Invert the dictionary to create an O(1) lookup from matrix index to ticker string
    position_to_ticker: Dict[int, str] = {v: k for k, v in ticker_to_position.items()}

    root_indices: Dict[str, Dict[int, int]] = {"News": {}, "Social": {}}

    for channel_name, regimes in regime_matrices.items():
        for regime_id, matrix in regimes.items():

            # Compute the weighted out-degree (row sums)
            out_degrees: np.ndarray = np.sum(matrix, axis=1)

            # Find the index of the maximum out-degree
            root_idx: int = int(np.argmax(out_degrees))
            max_out_degree: float = float(out_degrees[root_idx])

            if max_out_degree <= 0.0:
                raise ValueError(f"[{channel_name}] Regime {regime_id}: Maximum out-degree is 0.0.")

            root_indices[channel_name][regime_id] = root_idx

            # Log the selection using the inverted O(1) map
            root_ticker: str = position_to_ticker[root_idx]
            logger.debug(f"[{channel_name}] Regime {regime_id} Root: {root_ticker} (Out-Degree: {max_out_degree:.4f})")

    logger.info("Successfully selected MSA roots based on peak weighted out-degree.")
    return root_indices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 2: Apply Chu-Liu/Edmonds to maximize total arborescence weight
# -------------------------------------------------------------------------------------------------------------------------------
def extract_maximum_spanning_arborescences(
    regime_matrices: Dict[str, Dict[int, np.ndarray]],
    root_indices: Dict[str, Dict[int, int]]
) -> Dict[str, Dict[int, nx.DiGraph]]:
    """
    Applies the Chu-Liu/Edmonds algorithm to extract root-constrained arborescences.

    This function solves the optimization objective: max sum w(v_i, v_j) subject to T
    being an arborescence rooted strictly at r*. It mathematically forces the Edmonds
    algorithm to respect the selected root by explicitly deleting all incoming edges
    to r* prior to optimization, guaranteeing an in-degree of 0 for the root.

    Parameters
    ----------
    regime_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the aggregated 34x34 regime matrices.
    root_indices : Dict[str, Dict[int, int]]
        Nested dictionary containing the designated root indices r*.

    Returns
    -------
    Dict[str, Dict[int, nx.DiGraph]]
        A nested dictionary mapping Channel -> Regime_ID -> Optimal Arborescence (nx.DiGraph).

    Raises
    ------
    RuntimeError
        If the resulting tree violates the mathematical properties of an arborescence.
    """
    # Initialize the output dictionary hierarchy
    optimal_arborescences: Dict[str, Dict[int, nx.DiGraph]] = {"News": {}, "Social": {}}

    # Iterate over each channel and regime
    for channel_name, regimes in regime_matrices.items():
        for regime_id, matrix in regimes.items():

            # Retrieve the designated root index r* for this specific regime
            root_idx: int = root_indices[channel_name][regime_id]

            # Construct the full directed graph from the numpy matrix
            G_full = nx.DiGraph()
            n_nodes = matrix.shape[0]
            G_full.add_nodes_from(range(n_nodes))

            # Add edges only where the normalized TE weight is strictly positive
            for i in range(n_nodes):
                for j in range(n_nodes):
                    weight = matrix[i, j]
                    if weight > 0.0:
                        G_full.add_edge(i, j, weight=weight)

            # Mathematical Constraint: Force r* to be the root by removing all incoming edges.
            # This guarantees that the Edmonds algorithm cannot select a different root.
            edges_to_remove = list(G_full.in_edges(root_idx))
            G_full.remove_edges_from(edges_to_remove)

            # Isolate the subgraph of nodes strictly reachable from r*
            # This handles sparse graphs where a full 34-node spanning tree is impossible
            reachable_nodes = nx.descendants(G_full, root_idx)
            reachable_nodes.add(root_idx)

            # Create the constrained subgraph
            G_constrained = G_full.subgraph(reachable_nodes).copy()

            # Apply the Chu-Liu/Edmonds algorithm using the Edmonds class directly
            edmonds_algo = nx.algorithms.tree.branchings.Edmonds(G_constrained)

            # Extract the optimum branching, maximizing the sum of weights
            optimal_tree: nx.DiGraph = edmonds_algo.find_optimum(
                attr='weight', kind='max', style='arborescence', preserve_attrs=True
            )

            # Validation: Assert the mathematical properties of the resulting arborescence
            if optimal_tree.number_of_nodes() > 0:
                # 1. The root must have an in-degree of exactly 0
                if optimal_tree.in_degree(root_idx) != 0:
                    raise RuntimeError(f"Root constraint failed: Node {root_idx} has in-degree > 0.")

                # 2. All other nodes in the tree must have an in-degree of exactly 1
                for node in optimal_tree.nodes():
                    if node != root_idx and optimal_tree.in_degree(node) != 1:
                        raise RuntimeError(f"Arborescence property failed: Node {node} has in-degree != 1.")

            # Store the validated optimal arborescence
            optimal_arborescences[channel_name][regime_id] = optimal_tree

    logger.info("Successfully extracted and validated root-constrained Maximum Spanning Arborescences.")
    return optimal_arborescences

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Step 3: Produce path statistics
# -------------------------------------------------------------------------------------------------------------------------------
def compute_msa_path_statistics(
    optimal_arborescences: Dict[str, Dict[int, nx.DiGraph]],
    ticker_to_position: Dict[str, int]
) -> pd.DataFrame:
    """
    Computes the number of steps and total weight for all root-to-leaf paths in the MSAs.

    This function has been refactored to consume the O(1) ticker_to_position map.
    It uses the inverted map to translate the integer nodes of the networkx.DiGraph
    back into human-readable ticker strings, guaranteeing that the path strings
    perfectly reflect the underlying mathematical graph structure.

    Parameters
    ----------
    optimal_arborescences : Dict[str, Dict[int, nx.DiGraph]]
        Nested dictionary containing the optimal arborescences.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Regime_ID, Path_ID, Steps, Total_Weight, and Path_String.
    """
    # Invert the dictionary to create an O(1) lookup from matrix index to ticker string
    position_to_ticker: Dict[int, str] = {v: k for k, v in ticker_to_position.items()}

    records: List[Dict[str, Any]] = []

    for channel_name, regimes in optimal_arborescences.items():
        for regime_id, tree in regimes.items():

            if len(tree.edges) == 0:
                continue

            # Identify the root node (in-degree == 0)
            root_nodes = [n for n, d in tree.in_degree() if d == 0]
            if len(root_nodes) != 1:
                raise ValueError(f"Arborescence must have exactly one root. Found: {len(root_nodes)}")
            root_node = root_nodes[0]

            # Identify all leaf nodes (out-degree == 0)
            leaf_nodes = [n for n, d in tree.out_degree() if d == 0]

            path_counter = 1

            # Extract all simple paths from the root to every leaf node
            for leaf in leaf_nodes:
                paths = list(nx.all_simple_paths(tree, source=root_node, target=leaf))

                for path in paths:
                    steps: int = len(path) - 1

                    total_weight: float = 0.0
                    for i in range(steps):
                        u = path[i]
                        v = path[i+1]
                        total_weight += tree[u][v]['weight']

                    # Construct a human-readable string representation of the path
                    # REFACTORED: Uses the inverted O(1) map to guarantee correct translation
                    path_string: str = " -> ".join([position_to_ticker[n] for n in path])

                    records.append({
                        "Channel": channel_name,
                        "Regime_ID": regime_id,
                        "Path_ID": path_counter,
                        "Steps": steps,
                        "Total_Weight": float(total_weight),
                        "Path_String": path_string
                    })

                    path_counter += 1

    df_path_stats = pd.DataFrame(records)
    logger.info(f"Successfully computed path statistics using O(1) index mapping.")
    return df_path_stats

# -------------------------------------------------------------------------------------------------------------------------------
# Task 25, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class MSAReport:
    """
    Immutable data container for the Maximum Spanning Arborescence artifacts.

    Attributes
    ----------
    root_indices : Dict[str, Dict[int, int]]
        Nested dictionary mapping Channel -> Regime_ID -> Root_Index.
    optimal_arborescences : Dict[str, Dict[int, nx.DiGraph]]
        Nested dictionary mapping Channel -> Regime_ID -> Optimal Arborescence (nx.DiGraph).
    df_path_statistics : pd.DataFrame
        Tidy DataFrame containing the computed steps and weights for all root-to-leaf paths.
    """
    root_indices: Dict[str, Dict[int, int]]
    optimal_arborescences: Dict[str, Dict[int, nx.DiGraph]]
    df_path_statistics: pd.DataFrame


def orchestrate_msa_extraction(
    regime_network_report: Any,
    study_configuration: Dict[str, Any],
    ticker_to_position: Dict[str, int]
) -> Any: # Returns MSAReport
    """
    Orchestrates Task 25: Extracts Maximum Spanning Arborescence backbones per regime.

    This function has been refactored to accept the ticker_to_position map, passing it
    down to the root selection and path statistics functions to guarantee index synchronization.

    Parameters
    ----------
    regime_network_report : RegimeNetworkReport
        The dataclass containing the aggregated regime matrices.
    study_configuration : Dict[str, Any]
        The master configuration dictionary.
    ticker_to_position : Dict[str, int]
        A deterministic, O(1) mapping from canonical ticker strings to integer matrix indices.

    Returns
    -------
    MSAReport
        An immutable dataclass containing the roots, arborescences, and path statistics.
    """
    logger.info("Starting Task 25 Orchestration: Maximum Spanning Arborescence Extraction.")

    regime_matrices = regime_network_report.regime_matrices

    # Step 1: Select the root node for each regime using the O(1) map
    root_indices = select_msa_roots(
        regime_matrices=regime_matrices,
        ticker_to_position=ticker_to_position
    )

    # Step 2: Apply the Chu-Liu/Edmonds algorithm
    # Note: extract_maximum_spanning_arborescences is assumed to be available in the working environment
    optimal_arborescences = extract_maximum_spanning_arborescences(
        regime_matrices=regime_matrices,
        root_indices=root_indices
    )

    # Step 3: Compute path statistics using the O(1) map
    df_path_statistics = compute_msa_path_statistics(
        optimal_arborescences=optimal_arborescences,
        ticker_to_position=ticker_to_position
    )

    # Package the optimization artifacts into an immutable dataclass
    report = MSAReport(
        root_indices=root_indices,
        optimal_arborescences=optimal_arborescences,
        df_path_statistics=df_path_statistics
    )

    logger.info("=== Task 25 completed successfully. MSA backbones extracted and analyzed. ===")
    return report

# %%
# Task 26 — Compare News vs Social network structures via Jaccard similarity (Eq. 13)

# ==============================================================================
# Task 26: Compare News vs Social network structures via Jaccard similarity
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 1: Define edge sets consistently
# -------------------------------------------------------------------------------------------------------------------------------
def extract_significant_edge_sets(
    filtered_matrices: Dict[str, Dict[int, np.ndarray]]
) -> Dict[int, Dict[str, Set[Tuple[int, int]]]]:
    """
    Extracts the mathematical sets of directed edges A_w for both channels.

    This function implements the definition A_w = {(i,j): i != j, T_ij > 0}.
    It strictly requires the significance-filtered matrices to ensure the sets
    represent true information flow, preventing artificially inflated Jaccard scores.

    Parameters
    ----------
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.

    Returns
    -------
    Dict[int, Dict[str, Set[Tuple[int, int]]]]
        A nested dictionary mapping Window_ID -> Channel -> Set of (source, target) integer tuples.

    Raises
    ------
    KeyError
        If either 'News' or 'Social' is missing from the input dictionary.
    """
    if "News" not in filtered_matrices or "Social" not in filtered_matrices:
        raise KeyError("Both 'News' and 'Social' channels must be present to compute Jaccard similarity.")

    # Identify the common Window IDs present in both channels to ensure valid comparisons
    news_windows = set(filtered_matrices["News"].keys())
    social_windows = set(filtered_matrices["Social"].keys())
    common_windows = sorted(list(news_windows & social_windows))

    if not common_windows:
        logger.warning("No common Window IDs found between News and Social channels.")
        return {}

    # Initialize the output dictionary hierarchy
    edge_sets: Dict[int, Dict[str, Set[Tuple[int, int]]]] = {}

    for w_id in common_windows:
        edge_sets[w_id] = {}

        for channel in ["News", "Social"]:
            matrix = filtered_matrices[channel][w_id]

            # Use vectorized numpy operations to find indices where the weight is strictly positive
            # Since non-significant edges were explicitly set to 0.0, this perfectly isolates the significant edges
            row_indices, col_indices = np.nonzero(matrix > 0.0)

            # Zip the indices into a list of tuples, mathematically enforcing the i != j constraint
            # (Although the diagonal policy should already guarantee this, explicit enforcement is safer)
            edges = {(int(i), int(j)) for i, j in zip(row_indices, col_indices) if i != j}

            edge_sets[w_id][channel] = edges

    logger.info(f"Successfully extracted significant edge sets for {len(common_windows)} common windows.")
    return edge_sets

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 2: Compute Jaccard similarity
# -------------------------------------------------------------------------------------------------------------------------------
def compute_jaccard_similarity_index(
    edge_sets: Dict[int, Dict[str, Set[Tuple[int, int]]]]
) -> pd.DataFrame:
    """
    Computes the Jaccard Similarity Index (Eq. 13) and set cardinalities for each window.

    This function implements Equation 13: J(G_1, G_2) = |A_1 \cap A_2| / |A_1 \cup A_2|.
    It utilizes native Python set operations for optimal O(1) average time complexity.
    It also records the raw edge counts required to reproduce the manuscript's figures.

    Parameters
    ----------
    edge_sets : Dict[int, Dict[str, Set[Tuple[int, int]]]]
        Nested dictionary containing the edge sets (from Step 1).

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Window_ID, Jaccard_Index, and the cardinalities of
        the News, Social, Intersection, and Union sets.
    """
    records: List[Dict[str, Any]] = []

    for w_id, channels in edge_sets.items():
        set_news = channels["News"]
        set_social = channels["Social"]

        # Compute the intersection (edges present in BOTH channels)
        set_intersection = set_news & set_social

        # Compute the union (edges present in EITHER channel)
        set_union = set_news | set_social

        # Calculate the cardinalities
        len_news = len(set_news)
        len_social = len(set_social)
        len_intersection = len(set_intersection)
        len_union = len(set_union)

        # Compute the Jaccard Index
        # Handle the edge case where both sets are empty (division by zero)
        # [UNSPECIFIED IN MANUSCRIPT] Convention: If union is 0, similarity is 0.0
        if len_union == 0:
            jaccard_index = 0.0
        else:
            jaccard_index = float(len_intersection) / float(len_union)

        records.append({
            "Window_ID": w_id,
            "Edges_News": len_news,
            "Edges_Social": len_social,
            "Edges_Common": len_intersection,
            "Edges_Union": len_union,
            "Jaccard_Index": jaccard_index
        })

    # Convert the accumulated records into a tidy pandas DataFrame
    df_jaccard = pd.DataFrame(records)

    logger.info("Successfully computed Jaccard Similarity Index and set cardinalities.")
    return df_jaccard

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Step 3: Validate expected low similarity
# -------------------------------------------------------------------------------------------------------------------------------
def validate_low_jaccard_similarity(df_jaccard: pd.DataFrame, threshold: float = 0.15) -> bool:
    """
    Validates the qualitative invariant that News and Social networks exhibit low similarity.

    The manuscript concludes that the two media sources tell different stories, evidenced
    by a consistently low Jaccard similarity. This function computes the temporal mean
    and checks it against a diagnostic threshold.

    Parameters
    ----------
    df_jaccard : pd.DataFrame
        The tidy DataFrame containing the computed Jaccard indices (from Step 2).
    threshold : float, optional
        The diagnostic threshold for "low" similarity, by default 0.15.

    Returns
    -------
    bool
        True if the mean Jaccard similarity is below the threshold, False otherwise.
    """
    if df_jaccard.empty:
        logger.warning("Jaccard DataFrame is empty. Cannot validate similarity.")
        return False

    # Compute the mean Jaccard similarity across all rolling windows
    mean_jaccard = df_jaccard["Jaccard_Index"].mean()

    # Evaluate against the diagnostic threshold
    is_low_similarity = mean_jaccard < threshold

    if is_low_similarity:
        logger.info(f"Qualitative Validation: Consistently low Jaccard similarity observed (Mean: {mean_jaccard:.4f}). "
                    f"This supports the manuscript's conclusion of source divergence.")
    else:
        logger.warning(f"Qualitative Validation Alert: Mean Jaccard similarity ({mean_jaccard:.4f}) exceeds the "
                       f"diagnostic threshold ({threshold}). This suggests unfiltered matrices may have been used, "
                       f"or the significance alpha is too permissive.")

    return is_low_similarity

# -------------------------------------------------------------------------------------------------------------------------------
# Task 26, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class JaccardSimilarityReport:
    """
    Immutable data container for the Jaccard similarity artifacts.

    Attributes
    ----------
    df_jaccard_metrics : pd.DataFrame
        Tidy DataFrame containing the Jaccard Index and set cardinalities, merged with calendar dates.
    low_similarity_observed : bool
        Boolean flag indicating if the manuscript-expected low similarity pattern was observed.
    """
    df_jaccard_metrics: pd.DataFrame
    low_similarity_observed: bool


def orchestrate_jaccard_similarity_comparison(
    filtered_report: Any,
    window_metadata_report: Any
) -> JaccardSimilarityReport:
    """
    Orchestrates Task 26: Compares News vs Social network structures via Jaccard similarity.

    This function executes the comparative topology steps in a strict Directed Acyclic Graph (DAG) order.
    It extracts the mathematical edge sets from the significance-filtered matrices, computes the
    Jaccard Similarity Index (Eq. 13) and raw edge counts, merges the results with calendar dates
    for downstream plotting, and validates the qualitative invariant of source divergence.

    Parameters
    ----------
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices (from Task 19).
    window_metadata_report : WindowMetadataReport
        The dataclass containing the window-to-date mapping metadata (from Task 15).

    Returns
    -------
    JaccardSimilarityReport
        An immutable dataclass containing the computed metrics and diagnostic flag.
    """
    logger.info("Starting Task 26 Orchestration: Jaccard Similarity Comparison (Eq. 13).")

    # Extract required artifacts
    filtered_matrices = filtered_report.filtered_matrices
    df_window_metadata = window_metadata_report.df_window_metadata

    # Step 1: Define edge sets consistently using the filtered matrices
    # This ensures we are comparing the true, statistically significant information topologies
    edge_sets = extract_significant_edge_sets(filtered_matrices)

    # Step 2: Compute the Jaccard Similarity Index and set cardinalities
    # This provides the raw data required to reproduce Figure 7
    df_jaccard = compute_jaccard_similarity_index(edge_sets)

    # Merge the metrics with the window metadata to align with calendar dates
    # We use 'Regime_Assignment_Date' as the representative timestamp for the window
    df_jaccard_metrics = pd.merge(
        df_jaccard,
        df_window_metadata[["Regime_Assignment_Date"]],
        left_on="Window_ID",
        right_index=True,
        how="left"
    )

    # Step 3: Validate the expected low similarity qualitative invariant
    # This acts as a diagnostic fidelity check for the filtering and matrix assembly stages
    low_similarity_observed = validate_low_jaccard_similarity(df_jaccard_metrics)

    # Package the metrics and diagnostics into an immutable dataclass
    report = JaccardSimilarityReport(
        df_jaccard_metrics=df_jaccard_metrics,
        low_similarity_observed=low_similarity_observed
    )

    logger.info("=== Task 26 completed successfully. Jaccard similarity computed and validated. ===")

    # Return the immutable Jaccard report
    return report

# %%
# Task 27 — Stability diagnostic via spectral radius and power series (Eq. 14)

# ==============================================================================
# Task 27: Stability diagnostic via spectral radius and power series (Eq. 14)
# ==============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 1: Evaluate spectral radius condition
# -------------------------------------------------------------------------------------------------------------------------------
def evaluate_spectral_radius(
    filtered_matrices: Dict[str, Dict[int, np.ndarray]]
) -> pd.DataFrame:
    """
    Computes the spectral radius (rho) for each adjacency matrix to evaluate stability.

    This function implements the mathematical condition for convergence:
    rho(W_w) = max_k |lambda_k| < 1. It uses robust LAPACK eigenvalue solvers to
    determine if the infinite matrix power series will converge to a stable point.

    Parameters
    ----------
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Window_ID, Spectral_Radius, and Is_Convergent.

    Raises
    ------
    ValueError
        If the input matrices are not square.
    """
    records: List[Dict[str, Any]] = []

    for channel_name, windows in filtered_matrices.items():
        for w_id, matrix_w in windows.items():

            # Validate matrix dimensions
            if matrix_w.shape[0] != matrix_w.shape[1]:
                raise ValueError(f"Matrix for {channel_name}, Window {w_id} is not square.")

            try:
                # Compute the complex eigenvalues of the adjacency matrix
                eigenvalues = np.linalg.eigvals(matrix_w)

                # Compute the moduli (absolute values) of the eigenvalues
                moduli = np.abs(eigenvalues)

                # The spectral radius is the maximum modulus
                spectral_radius = float(np.max(moduli))

                # Evaluate the strict convergence condition: rho < 1.0
                is_convergent = spectral_radius < 1.0

                # Diagnostic warning for matrices dangerously close to divergence
                if 0.99 < spectral_radius < 1.0:
                    logger.debug(f"[{channel_name}] Window {w_id}: Spectral radius ({spectral_radius:.4f}) is near 1.0.")

            except np.linalg.LinAlgError as e:
                # Catch numerical instabilities in the eigenvalue solver
                logger.error(f"[{channel_name}] Window {w_id}: Eigenvalue computation failed. Details: {str(e)}")
                spectral_radius = np.nan
                is_convergent = False

            records.append({
                "Channel": channel_name,
                "Window_ID": w_id,
                "Spectral_Radius": spectral_radius,
                "Is_Convergent": is_convergent
            })

    # Convert the accumulated records into a tidy pandas DataFrame
    df_spectral = pd.DataFrame(records)

    # Log summary statistics
    total_matrices = len(df_spectral)
    convergent_count = df_spectral["Is_Convergent"].sum()
    logger.info(f"Spectral radius evaluation complete. {convergent_count}/{total_matrices} matrices are strictly convergent.")

    return df_spectral

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 2: Compute or approximate the power series (Eq. 14)
# -------------------------------------------------------------------------------------------------------------------------------
def compute_cumulative_reachability(
    filtered_matrices: Dict[str, Dict[int, np.ndarray]],
    df_spectral: pd.DataFrame,
    omega_max: int
) -> Dict[str, Dict[int, np.ndarray]]:
    """
    Computes the summation of the power network adjacency matrix (Equation 14).

    If the matrix is convergent (rho < 1), it attempts the closed-form solution:
    S_w = (I - W_w)^(-1) * W_w.
    If divergent or if inversion fails, it falls back to the truncated iterative summation:
    S_w(Omega) = sum_{omega=1}^{Omega} W_w^omega.

    Parameters
    ----------
    filtered_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the significance-filtered 34x34 adjacency matrices.
    df_spectral : pd.DataFrame
        The tidy DataFrame containing the convergence flags (from Step 1).
    omega_max : int
        The truncation depth for divergent matrices (typically 50).

    Returns
    -------
    Dict[str, Dict[int, np.ndarray]]
        A nested dictionary mapping Channel -> Window_ID -> Cumulative Reachability Matrix.
    """
    cumulative_matrices: Dict[str, Dict[int, np.ndarray]] = {"News": {}, "Social": {}}

    # Create a fast lookup dictionary for convergence status
    # Key: (Channel, Window_ID), Value: Is_Convergent
    convergence_lookup = df_spectral.set_index(["Channel", "Window_ID"])["Is_Convergent"].to_dict()

    for channel_name, windows in filtered_matrices.items():
        for w_id, matrix_w in windows.items():
            n = matrix_w.shape[0]
            is_convergent = convergence_lookup.get((channel_name, w_id), False)

            cumulative_matrix = None

            # Attempt the mathematically elegant closed-form solution if convergent
            if is_convergent:
                try:
                    # Identity matrix I
                    I = np.eye(n)
                    # Compute (I - W_w)^(-1)
                    inv_matrix = np.linalg.inv(I - matrix_w)
                    # S_w = (I - W_w)^(-1) * W_w
                    # Note: The standard geometric series sum_{k=0}^inf W^k = (I-W)^-1.
                    # Equation 14 starts at omega=1, so we must subtract I or multiply by W.
                    # sum_{k=1}^inf W^k = (I-W)^-1 - I = (I-W)^-1 * W
                    cumulative_matrix = np.dot(inv_matrix, matrix_w)
                except np.linalg.LinAlgError:
                    logger.debug(f"[{channel_name}] Window {w_id}: Matrix inversion failed despite rho < 1. Falling back to truncation.")
                    cumulative_matrix = None

            # Fallback to truncated iterative summation [UNSPECIFIED IN MANUSCRIPT]
            if cumulative_matrix is None:
                cumulative_matrix = np.zeros((n, n), dtype=float)
                current_power = np.copy(matrix_w)

                for omega in range(1, omega_max + 1):
                    cumulative_matrix += current_power
                    # Compute W^(omega+1) for the next iteration
                    current_power = np.dot(current_power, matrix_w)

                    # Early stopping if the matrix power becomes numerically negligible
                    if np.max(np.abs(current_power)) < 1e-12:
                        break

            cumulative_matrices[channel_name][w_id] = cumulative_matrix

    logger.info(f"Successfully computed cumulative reachability matrices (Omega_max={omega_max}).")
    return cumulative_matrices

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Step 3: Interpret connectivity outcome
# -------------------------------------------------------------------------------------------------------------------------------
def interpret_network_connectivity(
    cumulative_matrices: Dict[str, Dict[int, np.ndarray]],
    epsilon: float = 1e-9
) -> pd.DataFrame:
    """
    Evaluates whether the cumulative matrices indicate a fully connected network.

    This function tests the manuscript's claim that "the network eventually becomes
    fully connected." It computes the proportion of off-diagonal entries in the
    cumulative matrix that are strictly greater than a numerical epsilon threshold.

    Parameters
    ----------
    cumulative_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the cumulative reachability matrices (from Step 2).
    epsilon : float, optional
        The numerical threshold to distinguish true indirect paths from floating-point noise,
        by default 1e-9.

    Returns
    -------
    pd.DataFrame
        A tidy DataFrame containing Channel, Window_ID, Cumulative_Density, and Is_Fully_Connected.
    """
    records: List[Dict[str, Any]] = []

    for channel_name, windows in cumulative_matrices.items():
        for w_id, matrix_s in windows.items():
            n = matrix_s.shape[0]
            denominator = float(n * (n - 1))

            # Create a copy to avoid mutating the stored cumulative matrix
            matrix_eval = np.copy(matrix_s)

            # Zero out the diagonal, as "fully connected" refers to off-diagonal reachability
            np.fill_diagonal(matrix_eval, 0.0)

            # Count the number of entries strictly greater than the epsilon threshold
            # This filters out floating-point artifacts from the matrix inversion/multiplication
            reachable_paths = int(np.count_nonzero(matrix_eval > epsilon))

            # Compute the cumulative density
            cumulative_density = reachable_paths / denominator

            # Evaluate full connectivity
            # We use a strict equality to 1.0, meaning every node can reach every other node
            is_fully_connected = (reachable_paths == int(denominator))

            records.append({
                "Channel": channel_name,
                "Window_ID": w_id,
                "Cumulative_Density": cumulative_density,
                "Is_Fully_Connected": is_fully_connected
            })

    # Convert the accumulated records into a tidy pandas DataFrame
    df_connectivity = pd.DataFrame(records)

    # Log summary statistics
    total_matrices = len(df_connectivity)
    fully_connected_count = df_connectivity["Is_Fully_Connected"].sum()
    logger.info(f"Connectivity interpretation complete. {fully_connected_count}/{total_matrices} networks are fully connected.")

    return df_connectivity

# -------------------------------------------------------------------------------------------------------------------------------
# Task 27, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class StabilityAndConvergenceReport:
    """
    Immutable data container for the stability and convergence artifacts.

    Attributes
    ----------
    df_spectral_radius : pd.DataFrame
        Tidy DataFrame containing the spectral radius and convergence flag for each window.
    cumulative_matrices : Dict[str, Dict[int, np.ndarray]]
        Nested dictionary containing the cumulative reachability matrices S_w.
    df_connectivity : pd.DataFrame
        Tidy DataFrame containing the cumulative density and full connectivity flags.
    """
    df_spectral_radius: pd.DataFrame
    cumulative_matrices: Dict[str, Dict[int, np.ndarray]]
    df_connectivity: pd.DataFrame


def orchestrate_stability_and_convergence(
    filtered_report: Any,
    study_configuration: Dict[str, Any]
) -> StabilityAndConvergenceReport:
    """
    Orchestrates Task 27: Stability diagnostic via spectral radius and power series (Eq. 14).

    This function executes the spectral analysis steps in a strict Directed Acyclic Graph (DAG) order.
    It evaluates the spectral radius condition to determine convergence, computes the cumulative
    reachability matrices using either a closed-form solution or truncated summation, and interprets
    the resulting matrices to validate the manuscript's claim of eventual full connectivity.

    Parameters
    ----------
    filtered_report : FilteredAdjacencyReport
        The dataclass containing the significance-filtered adjacency matrices (from Task 19).
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing the truncation parameter.

    Returns
    -------
    StabilityAndConvergenceReport
        An immutable dataclass containing the stability metrics and cumulative matrices.
    """
    logger.info("Starting Task 27 Orchestration: Stability Diagnostic and Power Series (Eq. 14).")

    # Extract required parameters and artifacts
    filtered_matrices = filtered_report.filtered_matrices

    # Extract the truncation parameter for divergent matrices [UNSPECIFIED IN MANUSCRIPT]
    omega_max: int = study_configuration["comparative_methodology"]["stability_convergence"]["if_diverges_policy"]["omega_max"]

    # Step 1: Evaluate the spectral radius condition (rho < 1)
    # This determines whether the infinite power series converges to a stable point
    df_spectral_radius = evaluate_spectral_radius(
        filtered_matrices=filtered_matrices
    )

    # Step 2: Compute or approximate the power series (Equation 14)
    # This accumulates direct and indirect information paths to form the reachability matrix S_w
    cumulative_matrices = compute_cumulative_reachability(
        filtered_matrices=filtered_matrices,
        df_spectral=df_spectral_radius,
        omega_max=omega_max
    )

    # Step 3: Interpret the connectivity outcome
    # This tests the manuscript's claim that the network eventually becomes fully connected
    df_connectivity = interpret_network_connectivity(
        cumulative_matrices=cumulative_matrices
    )

    # Package the stability artifacts into an immutable dataclass
    report = StabilityAndConvergenceReport(
        df_spectral_radius=df_spectral_radius,
        cumulative_matrices=cumulative_matrices,
        df_connectivity=df_connectivity
    )

    logger.info("=== Task 27 completed successfully. Stability and convergence analyzed. ===")

    # Return the immutable stability report
    return report

# %%
# Task 28 — Create an orchestrator callable for the end-to-end replication pipeline

# ================================================================================
# Task 28: Create an orchestrator callable for the end-to-end replication pipeline
# ================================================================================

import logging

import pandas as pd
from typing import Dict, Any
from dataclasses import dataclass

# Configure module-level logger for clinical, professional output
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
if not logger.handlers:
    handler = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 1: Define the orchestrator's deterministic signature and output structure
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class SentinelSystemReport:
    """
    Immutable master data container for the end-to-end Sentinel System artifacts.

    This dataclass encapsulates every intermediate and final artifact generated by the
    replication pipeline, ensuring perfect auditability and preventing downstream mutation.

    Attributes
    ----------
    configuration_snapshot : Dict[str, Any]
        A deep copy of the exact configuration used for the run.
    configuration_hash : str
        An MD5 hash of the configuration snapshot to guarantee provenance.
    universe_report : UniverseValidationReport
        Artifacts from Task 1 (canonical tickers, alias map).
    sector_report : SectorMappingReport
        Artifacts from Task 3 (validated sector metadata).
    aligned_data_report : AlignedSentimentReport
        Artifacts from Task 6 (master calendar, aligned long-form data).
    missingness_report : MissingnessProfileReport
        Artifacts from Task 8 (missingness rates).
    ar1_estimation_report : AR1EstimationReport
        Artifacts from Task 10 (AR(1) parameters and innovation variance).
    imputed_data_report : ImputedSentimentReport
        Artifacts from Task 11 (stochastically imputed matrices).
    encoding_report : SymbolicEncodingReport
        Artifacts from Task 13 (quantiles and symbolic states).
    te_calibration_report : TECalibrationReport
        Artifacts from Task 14 (conditional entropy simulation).
    window_metadata_report : WindowMetadataReport
        Artifacts from Task 15 (window-to-date mapping).
    adjacency_report : AdjacencyMatrixReport
        Artifacts from Task 17 (unfiltered normalized adjacency matrices).
    filtered_adjacency_report : FilteredAdjacencyReport
        Artifacts from Task 19 (p-values, significance masks, filtered matrices).
    network_density_report : NetworkDensityReport
        Artifacts from Task 20 (dynamic density and edge counts).
    node_influence_report : NodeInfluenceReport
        Artifacts from Task 21 (in/out-degrees and heatmap panels).
    pagerank_report : PageRankAndRankingReport
        Artifacts from Task 22 (PageRank scores and Top-5 rankings).
    regime_segmentation_report : RegimeSegmentationReport
        Artifacts from Task 23 (regime boundaries and partitioned window sets).
    regime_network_report : RegimeNetworkReport
        Artifacts from Task 24 (aggregated regime matrices and densities).
    msa_report : MSAReport
        Artifacts from Task 25 (optimal roots, arborescences, and path statistics).
    jaccard_report : JaccardSimilarityReport
        Artifacts from Task 26 (Jaccard indices and set cardinalities).
    stability_report : StabilityAndConvergenceReport
        Artifacts from Task 27 (spectral radii and cumulative reachability matrices).
    """
    configuration_snapshot: Dict[str, Any]
    configuration_hash: str
    universe_report: Any
    sector_report: Any
    aligned_data_report: Any
    missingness_report: Any
    ar1_estimation_report: Any
    imputed_data_report: Any
    encoding_report: Any
    te_calibration_report: Any
    window_metadata_report: Any
    adjacency_report: Any
    filtered_adjacency_report: Any
    network_density_report: Any
    node_influence_report: Any
    pagerank_report: Any
    regime_segmentation_report: Any
    regime_network_report: Any
    msa_report: Any
    jaccard_report: Any
    stability_report: Any

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 3: Lock configuration snapshotting to prevent drift
# -------------------------------------------------------------------------------------------------------------------------------
def create_configuration_snapshot(study_configuration: Dict[str, Any]) -> Tuple[Dict[str, Any], str]:
    """
    Creates a deep copy and a deterministic MD5 hash of the study configuration.

    This function ensures that the exact parameters used for a pipeline run are
    permanently recorded and mathematically verifiable, preventing silent drift
    caused by interactive mutation of the configuration dictionary.

    Parameters
    ----------
    study_configuration : Dict[str, Any]
        The master configuration dictionary.

    Returns
    -------
    Tuple[Dict[str, Any], str]
        A deep copy of the configuration and its MD5 hash string.
    """
    # Create a deep copy to ensure complete immutability
    config_snapshot = copy.deepcopy(study_configuration)

    # Convert the dictionary to a JSON string.
    # sort_keys=True guarantees that the string representation is deterministic.
    config_str = json.dumps(config_snapshot, sort_keys=True)

    # Compute the MD5 hash of the deterministic string
    config_hash = hashlib.md5(config_str.encode('utf-8')).hexdigest()

    logger.info(f"Configuration snapshot locked. Hash: {config_hash}")
    return config_snapshot, config_hash

# -------------------------------------------------------------------------------------------------------------------------------
# Task 28, Step 2: Define the orchestrator's internal call graph as a strict DAG
# -------------------------------------------------------------------------------------------------------------------------------
def orchestrate_sentinel_system_pipeline(
    tech_universe_raw: Dict[str, Any],
    df_sector_mapping: pd.DataFrame,
    df_news_sentiment_raw: pd.DataFrame,
    df_social_sentiment_raw: pd.DataFrame,
    study_configuration: Dict[str, Any],
    fallback_calendar: Optional[pd.DatetimeIndex] = None
) -> Any: # Returns SentinelSystemReport (type hinted as Any to avoid circular imports in this isolated block)
    """
    Orchestrates the end-to-end High-Frequency Sentinel System pipeline.

    This function executes the entire methodology of Wu et al. (2026) in a strict
    Directed Acyclic Graph (DAG) order. It has been comprehensively refactored to
    enforce a Single Source of Truth for topological indexing. By extracting the
    O(1) ticker_to_position map from Task 1 and routing it to Tasks 7, 17, 19, 21,
    22, and 25, it mathematically guarantees that matrix indices are perfectly
    synchronized with corporate entities across all centrality metrics, PageRank
    scores, and Maximum Spanning Arborescences.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe (Vertex Set V).
    df_sector_mapping : pd.DataFrame
        The raw GICS mapping DataFrame for sector interpretation.
    df_news_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg News daily sentiment DataFrame.
    df_social_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg Social Media daily sentiment DataFrame.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing all methodological parameters.
    fallback_calendar : Optional[pd.DatetimeIndex], optional
        A pre-validated, exact calendar of length 1319 to use if standard business
        days do not align perfectly with the manuscript's count, by default None.

    Returns
    -------
    SentinelSystemReport
        An immutable dataclass containing all intermediate and final research artifacts.

    Raises
    ------
    RuntimeError
        If any fatal error occurs during the execution of the underlying DAG.
    """
    logger.info("=====================================================================")
    logger.info("INITIATING END-TO-END SENTINEL SYSTEM PIPELINE")
    logger.info("=====================================================================")

    # Step 3 (Task 28): Lock the configuration snapshot to prevent silent drift
    # Note: create_configuration_snapshot is assumed to be available in the working environment
    config_snapshot, config_hash = create_configuration_snapshot(study_configuration)

    # -------------------------------------------------------------------------------------------
    # Phase 1: Parameter Validation and Configuration Consistency
    # -------------------------------------------------------------------------------------------
    # Execute Task 1: Validate universe cardinality, ordering, and alias coherence
    universe_report = orchestrate_universe_validation(
        tech_universe_raw, config_snapshot
    )

    # Explicitly extract the O(1) mapping dictionary for downstream routing.
    # This is the Single Source of Truth for all matrix indexing.
    ticker_to_position: Dict[str, int] = universe_report.ticker_to_position

    # Execute Task 2: Validate completeness and integrity of study configuration
    config_validation_report = orchestrate_config_validation(
        config_snapshot
    )

    # Execute Task 3: Validate sector mapping DataFrame schema and coverage
    sector_report = orchestrate_sector_mapping_validation(
        df_sector_mapping, universe_report.canonical_tickers
    )

    # -------------------------------------------------------------------------------------------
    # Phase 2: Data Ingestion, Cleansing, and Alignment
    # -------------------------------------------------------------------------------------------
    # Execute Task 4: Ingest raw daily sentiment panels and validate hard schema constraints (News)
    news_ingestion_report = orchestrate_news_sentiment_ingestion(
        df_news_sentiment_raw
    )

    # Execute Task 5: Ingest raw daily sentiment panels and validate hard schema constraints (Social)
    social_ingestion_report = orchestrate_social_sentiment_ingestion(
        df_social_sentiment_raw
    )

    # Execute Task 6: Cleanse data via canonical ticker normalization and master calendar alignment
    # Pass the fallback_calendar to guarantee T=1319
    aligned_data_report = orchestrate_data_cleansing_and_alignment(
        news_ingestion_report.df_news_validated,
        social_ingestion_report.df_social_validated,
        universe_report.inverted_alias_map,
        universe_report.canonical_tickers,
        config_snapshot,
        fallback_calendar=fallback_calendar
    )

    # Execute Task 7: Pivot sentiment panels into firm-indexed matrices with canonical vertex ordering
    # Pass ticker_to_position to guarantee column ordering
    pivoted_matrices_report = orchestrate_matrix_pivoting(
        aligned_data_report.df_news_aligned,
        aligned_data_report.df_social_aligned,
        aligned_data_report.master_calendar,
        ticker_to_position=ticker_to_position
    )

    # Execute Task 8: Profile missingness and validate against manuscript-stated magnitudes
    missingness_report = orchestrate_missingness_profiling(
        aligned_data_report, pivoted_matrices_report
    )

    # -------------------------------------------------------------------------------------------
    # Phase 3: Stochastic Imputation and Diagnostics
    # -------------------------------------------------------------------------------------------
    # Execute Task 9: Diagnose AR(1) plausibility via ACF/PACF
    ar1_diagnostic_report = orchestrate_ar1_diagnostics(
        pivoted_matrices_report
    )

    # Execute Task 10: Fit AR(1) model and estimate innovation variance (sigma^2)
    ar1_estimation_report = orchestrate_ar1_variance_estimation(
        pivoted_matrices_report
    )

    # Execute Task 11: Impute missing sentiment using exponential decay with additive Gaussian noise
    imputed_data_report = orchestrate_stochastic_imputation(
        pivoted_matrices_report, ar1_estimation_report, config_snapshot
    )

    # Execute Task 12: Post-imputation diagnostics: stationarity and non-normality validation
    post_imputation_report = orchestrate_post_imputation_diagnostics(
        imputed_data_report
    )

    # -------------------------------------------------------------------------------------------
    # Phase 4: Information Theory Preparation
    # -------------------------------------------------------------------------------------------
    # Execute Task 13: Discretize sentiment into 3 symbolic states via quantile discretization
    encoding_report = orchestrate_quantile_discretization(
        imputed_data_report, config_snapshot
    )

    # Execute Task 14: Validate lag calibration via conditional entropy
    te_calibration_report = orchestrate_lag_calibration(
        config_snapshot
    )

    # Execute Task 15: Enumerate rolling windows and define window-to-time-slice mapping
    window_metadata_report = orchestrate_window_enumeration(
        aligned_data_report, config_snapshot
    )

    # -------------------------------------------------------------------------------------------
    # Phase 5: Transfer Entropy and Network Assembly
    # -------------------------------------------------------------------------------------------
    # Execute Task 16: Compute transfer entropy and normalized transfer entropy for each ordered pair
    te_report = orchestrate_transfer_entropy_estimation(
        encoding_report, config_snapshot, n_jobs=-1
    )

    # Execute Task 17: Assemble adjacency matrices per window for each channel
    # Pass ticker_to_position to guarantee matrix index alignment
    adjacency_report = orchestrate_adjacency_assembly(
        te_report, ticker_to_position=ticker_to_position
    )

    # Execute Task 18: Generate Markov-bootstrap null samples for significance testing
    bootstrap_report = orchestrate_markov_bootstrap(
        encoding_report, config_snapshot, n_jobs=-1
    )

    # Execute Task 19: Compute p-values and filter edges via bootstrap significance test
    # Pass ticker_to_position to guarantee filtering alignment
    filtered_adjacency_report = orchestrate_bootstrap_significance_filtering(
        te_report, bootstrap_report, adjacency_report, config_snapshot, ticker_to_position=ticker_to_position
    )

    # -------------------------------------------------------------------------------------------
    # Phase 6: Topological Metrics and Centrality
    # -------------------------------------------------------------------------------------------
    # Execute Task 20: Compute dynamic network density and edge counts
    network_density_report = orchestrate_network_density_computation(
        adjacency_report, filtered_adjacency_report, window_metadata_report, config_snapshot
    )

    # Execute Task 21: Compute node-level influence measures: weighted degrees
    # Pass ticker_to_position to guarantee degree-to-ticker mapping
    node_influence_report = orchestrate_node_influence_computation(
        adjacency_report, filtered_adjacency_report, window_metadata_report, config_snapshot, ticker_to_position=ticker_to_position
    )

    # Execute Task 22: Compute weighted PageRank with locked dangling-node policy
    # Pass ticker_to_position to guarantee PageRank-to-ticker mapping
    pagerank_report = orchestrate_pagerank_and_rankings(
        filtered_adjacency_report, node_influence_report, config_snapshot, ticker_to_position=ticker_to_position
    )

    # -------------------------------------------------------------------------------------------
    # Phase 7: Regime Analysis and Optimization
    # -------------------------------------------------------------------------------------------
    # Execute Task 23: Segment windows into regimes using paper-stated breakpoints
    regime_segmentation_report = orchestrate_regime_segmentation(
        window_metadata_report, config_snapshot
    )

    # Execute Task 24: Construct regime-specific networks via aggregation operator
    regime_network_report = orchestrate_regime_network_construction(
        filtered_adjacency_report, regime_segmentation_report, config_snapshot
    )

    # Execute Task 25: Extract Maximum Spanning Arborescence backbones per regime
    # Pass ticker_to_position to guarantee MSA root and path string mapping
    msa_report = orchestrate_msa_extraction(
        regime_network_report, config_snapshot, ticker_to_position=ticker_to_position
    )

    # -------------------------------------------------------------------------------------------
    # Phase 8: Comparative Topology and Stability
    # -------------------------------------------------------------------------------------------
    # Execute Task 26: Compare News vs Social network structures via Jaccard similarity
    jaccard_report = orchestrate_jaccard_similarity_comparison(
        filtered_adjacency_report, window_metadata_report
    )

    # Execute Task 27: Stability diagnostic via spectral radius and power series
    stability_report = orchestrate_stability_and_convergence(
        filtered_adjacency_report, config_snapshot
    )

    # -------------------------------------------------------------------------------------------
    # Final Assembly
    # -------------------------------------------------------------------------------------------
    # Note: SentinelSystemReport is assumed to be available in the working environment
    master_report = SentinelSystemReport(
        configuration_snapshot=config_snapshot,
        configuration_hash=config_hash,
        universe_report=universe_report,
        sector_report=sector_report,
        aligned_data_report=aligned_data_report,
        missingness_report=missingness_report,
        ar1_estimation_report=ar1_estimation_report,
        imputed_data_report=imputed_data_report,
        encoding_report=encoding_report,
        te_calibration_report=te_calibration_report,
        window_metadata_report=window_metadata_report,
        adjacency_report=adjacency_report,
        filtered_adjacency_report=filtered_adjacency_report,
        network_density_report=network_density_report,
        node_influence_report=node_influence_report,
        pagerank_report=pagerank_report,
        regime_segmentation_report=regime_segmentation_report,
        regime_network_report=regime_network_report,
        msa_report=msa_report,
        jaccard_report=jaccard_report,
        stability_report=stability_report
    )

    logger.info("=====================================================================")
    logger.info("END-TO-END SENTINEL SYSTEM PIPELINE COMPLETED SUCCESSFULLY")
    logger.info("=====================================================================")

    return master_report

# %%
# Task 29 — Produce paper-grade deliverables and verify fidelity against expected patterns

# ========================================================================================
# Task 29: Produce paper-grade deliverables and verify fidelity against expected patterns
# ========================================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 1: Generate required tables and figures
# -------------------------------------------------------------------------------------------------------------------------------
def generate_descriptive_statistics_tables(
    aligned_data_report: Any,
    post_imputation_report: Any
) -> Dict[str, pd.DataFrame]:
    """
    Generates Table 1 and Table 2: Descriptive statistics of sentiment for the companies.

    This function merges the raw sentiment data aggregations (Min, Max, Mean, SD, Q25, Q75,
    Skewness, Kurtosis) with the statistical test results (ADF stat, Shapiro stat) from
    Task 12 to perfectly replicate the manuscript's summary tables.

    Parameters
    ----------
    aligned_data_report : AlignedSentimentReport
        The dataclass containing the aligned long-form DataFrames (from Task 6).
    post_imputation_report : PostImputationDiagnosticReport
        The dataclass containing the ADF and Shapiro-Wilk test results (from Task 12).

    Returns
    -------
    Dict[str, pd.DataFrame]
        A dictionary containing 'Table_1_News_Stats' and 'Table_2_Social_Stats'.
    """
    tables: Dict[str, pd.DataFrame] = {}

    df_news = aligned_data_report.df_news_aligned
    df_social = aligned_data_report.df_social_aligned
    df_diagnostics = post_imputation_report.df_diagnostics

    def build_table(df_raw: pd.DataFrame, channel_name: str) -> pd.DataFrame:
        # Compute standard descriptive statistics
        # We use the raw, pre-imputation data for the basic stats to reflect the true empirical distribution
        stats = df_raw.groupby("Ticker")["Sentiment_Score"].agg(
            Min='min',
            Max='max',
            Mean='mean',
            SD='std',
            Q25=lambda x: x.quantile(0.25),
            Q75=lambda x: x.quantile(0.75),
            Skewness='skew',
            Kurtosis=lambda x: x.kurt()
        ).reset_index()

        # Extract the diagnostic test statistics for the specific channel
        diag_subset = df_diagnostics[df_diagnostics["Channel"] == channel_name][
            ["Ticker", "ADF_Stat", "Shapiro_Stat"]
        ]

        # Merge the descriptive stats with the diagnostic stats
        table = pd.merge(stats, diag_subset, on="Ticker", how="left")

        # Set Ticker as the index to match the manuscript's presentation format
        table.set_index("Ticker", inplace=True)
        return table

    tables["Table_1_News_Stats"] = build_table(df_news, "News")
    tables["Table_2_Social_Stats"] = build_table(df_social, "Social")

    logger.info("Successfully generated Table 1 and Table 2 (Descriptive Statistics).")
    return tables


def generate_top_5_influential_companies_table(
    pagerank_report: Any
) -> pd.DataFrame:
    """
    Generates Table 3: The top 5 influential companies.

    This function pivots the tidy ranking DataFrame from Task 22 into a multi-level
    column structure that mirrors the manuscript's presentation, comparing PageRank,
    Weighted Out-degree, and Weighted In-degree across News and Social Media.

    Parameters
    ----------
    pagerank_report : PageRankAndRankingReport
        The dataclass containing the Top-5 rankings (from Task 22).

    Returns
    -------
    pd.DataFrame
        The formatted Table 3.
    """
    df_rankings = pagerank_report.df_top_5_rankings

    # Pivot the tidy data to create a wide-form table
    # Index: Rank (1 to 5)
    # Columns: MultiIndex (Metric, Channel)
    # Values: Ticker
    table_3 = df_rankings.pivot(
        index="Rank",
        columns=["Metric", "Channel"],
        values="Ticker"
    )

    # Reorder the columns to match the manuscript's specific layout
    # Order: PageRank (News, Social), Out-degree (News, Social), In-degree (News, Social)
    column_order = [
        ("PageRank", "News"), ("PageRank", "Social"),
        ("Out_Degree", "News"), ("Out_Degree", "Social"),
        ("In_Degree", "News"), ("In_Degree", "Social")
    ]

    # Reindex columns, handling potential missing combinations gracefully
    table_3 = table_3.reindex(columns=column_order)

    logger.info("Successfully generated Table 3 (Top 5 Influential Companies).")
    return table_3


def generate_density_and_jaccard_figures(
    network_density_report: Any,
    jaccard_report: Any
) -> Dict[str, plt.Figure]:
    """
    Generates Figure 5 (Density), Figure 6 (Edge Counts), and Figure 7 (Jaccard Similarity).

    This function utilizes matplotlib to create publication-quality static plots of the
    time-varying network metrics, strictly separating unfiltered and filtered states.

    Parameters
    ----------
    network_density_report : NetworkDensityReport
        The dataclass containing the density and edge count metrics (from Task 20).
    jaccard_report : JaccardSimilarityReport
        The dataclass containing the Jaccard indices (from Task 26).

    Returns
    -------
    Dict[str, plt.Figure]
        A dictionary containing the generated matplotlib Figure objects.
    """
    figures: Dict[str, plt.Figure] = {}

    df_metrics = network_density_report.df_network_metrics
    df_jaccard = jaccard_report.df_jaccard_metrics

    # --- Figure 5: Transfer entropy network density over time ---
    fig5, axes5 = plt.subplots(1, 2, figsize=(16, 6))

    for i, state in enumerate(["Unfiltered", "Filtered"]):
        ax = axes5[i]
        df_state = df_metrics[df_metrics["Filtering_State"] == state]

        # We plot against Window_ID as a proxy for time, as the exact date merging
        # was handled in the Jaccard report. For a production system, we would merge
        # dates here as well, but Window_ID preserves the exact sequence.
        for channel, color in [("News", "blue"), ("Social", "orange")]:
            df_chan = df_state[df_state["Channel"] == channel]
            ax.plot(df_chan["Window_ID"], df_chan["Density"], label=channel, color=color)

        ax.set_title(f"Network Density ({state})")
        ax.set_xlabel("Rolling Window Index")
        ax.set_ylabel("Density")
        ax.legend()
        ax.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    figures["Figure_5_Density"] = fig5

    # --- Figure 7: Jaccard Similarity scores over time ---
    fig7, ax7 = plt.subplots(figsize=(10, 4))

    # Plot the Jaccard Index against the Window_ID
    ax7.plot(df_jaccard["Window_ID"], df_jaccard["Jaccard_Index"], color="green")
    ax7.set_title("Jaccard Similarity Over Time")
    ax7.set_xlabel("Window Number")
    ax7.set_ylabel("Jaccard Similarity")
    ax7.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    figures["Figure_7_Jaccard"] = fig7

    logger.info("Successfully generated Figures 5 and 7 (Density and Jaccard).")
    return figures


def generate_heatmap_figures(
    node_influence_report: Any
) -> Dict[str, plt.Figure]:
    """
    Generates Figure 9 and 10: Out-degree and In-degree heatmaps.

    This function utilizes seaborn to create high-dimensional heatmaps of nodal intensity
    across the rolling windows, using the sorted panels generated in Task 21.

    Parameters
    ----------
    node_influence_report : NodeInfluenceReport
        The dataclass containing the sorted heatmap panels (from Task 21).

    Returns
    -------
    Dict[str, plt.Figure]
        A dictionary containing the generated matplotlib Figure objects.
    """
    figures: Dict[str, plt.Figure] = {}
    sorted_panels = node_influence_report.sorted_heatmap_panels

    def plot_channel_heatmaps(channel_name: str, cmap: str) -> plt.Figure:
        fig, axes = plt.subplots(1, 2, figsize=(20, 10))

        # Extract the significance-filtered panels for plotting
        df_out = sorted_panels.get((channel_name, "Filtered", "Out_Degree"))
        df_in = sorted_panels.get((channel_name, "Filtered", "In_Degree"))

        if df_out is not None and not df_out.empty:
            sns.heatmap(df_out, ax=axes[0], cmap=cmap, cbar_kws={'label': 'Weighted Out-degree'})
            axes[0].set_title(f"Out-degree heatmap ({channel_name})")
            axes[0].set_xlabel("Window")
            axes[0].set_ylabel("Node")

        if df_in is not None and not df_in.empty:
            sns.heatmap(df_in, ax=axes[1], cmap=cmap, cbar_kws={'label': 'Weighted In-degree'})
            axes[1].set_title(f"In-degree heatmap ({channel_name})")
            axes[1].set_xlabel("Window")
            axes[1].set_ylabel("Node")

        plt.tight_layout()
        return fig

    # Generate Figure 9 (News) using a green colormap
    figures["Figure_9_Heatmaps_News"] = plot_channel_heatmaps("News", "Greens")

    # Generate Figure 10 (Social) using a green colormap to match the manuscript style
    figures["Figure_10_Heatmaps_Social"] = plot_channel_heatmaps("Social", "Greens")

    logger.info("Successfully generated Figures 9 and 10 (Heatmaps).")
    return figures

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Step 2 & 3: Perform fidelity checks and diagnose systematically
# -------------------------------------------------------------------------------------------------------------------------------
def verify_fidelity_and_diagnose(
    network_density_report: Any,
    regime_network_report: Any,
    jaccard_report: Any
) -> Tuple[Dict[str, bool], str]:
    """
    Consolidates qualitative diagnostic flags and generates a systematic diagnostic report.

    This function evaluates whether the final outputs match the manuscript's qualitative
    descriptions. If a mismatch occurs, it provides actionable, systematic diagnostic
    recommendations pointing to the most likely upstream methodological deviations.

    Parameters
    ----------
    network_density_report : NetworkDensityReport
        Contains dynamic density diagnostic flags.
    regime_network_report : RegimeNetworkReport
        Contains regime density diagnostic flags.
    jaccard_report : JaccardSimilarityReport
        Contains the Jaccard similarity diagnostic flag.

    Returns
    -------
    Tuple[Dict[str, bool], str]
        - consolidated_flags: Dictionary of all boolean fidelity checks.
        - diagnostic_log: A formatted string containing systematic recommendations.
    """
    consolidated_flags: Dict[str, bool] = {}

    # Extract flags from upstream reports
    consolidated_flags.update(network_density_report.qualitative_diagnostics)
    consolidated_flags.update(regime_network_report.qualitative_diagnostics)
    consolidated_flags["low_jaccard_similarity"] = jaccard_report.low_similarity_observed

    diagnostic_messages: List[str] = []
    diagnostic_messages.append("=== SYSTEMATIC FIDELITY DIAGNOSTIC REPORT ===")

    all_passed = True

    # Check 1: News Density Spike
    if not consolidated_flags.get("news_spike_observed", False) or not consolidated_flags.get("news_regime2_gt_regime1", False):
        all_passed = False
        diagnostic_messages.append(
            "[FAIL] News Density Spike (Late 2021): The expected increase in News sentiment spillover was not observed."
        )
        diagnostic_messages.append(
            "  -> DIAGNOSIS 1: Verify Calendar Alignment (Task 6). If T != 1319, the rolling windows are misaligned with the market events."
        )
        diagnostic_messages.append(
            "  -> DIAGNOSIS 2: Verify Quantile Scope (Task 13). Quantiles must be computed 'per_rolling_window' to capture local volatility."
        )

    # Check 2: Social Media Decay
    if not consolidated_flags.get("social_decay_observed", False) or not consolidated_flags.get("social_regime3_lt_regime1", False):
        all_passed = False
        diagnostic_messages.append(
            "[FAIL] Social Media Decay (Post-Oct 2022): The expected decrease in Social sentiment spillover was not observed."
        )
        diagnostic_messages.append(
            "  -> DIAGNOSIS 1: Verify Bootstrap Mechanics (Task 18). Ensure the null distribution is generated using a source-only Markov bootstrap without smoothing."
        )

    # Check 3: Jaccard Similarity
    if not consolidated_flags.get("low_jaccard_similarity", False):
        all_passed = False
        diagnostic_messages.append(
            "[FAIL] Low Jaccard Similarity: The structural divergence between News and Social networks was not observed."
        )
        diagnostic_messages.append(
            "  -> DIAGNOSIS 1: Verify Edge Filtering (Task 19). High similarity strongly indicates that unfiltered matrices (containing structural noise) were used instead of significance-filtered matrices."
        )
        diagnostic_messages.append(
            "  -> DIAGNOSIS 2: Verify Alpha Threshold (Task 19). Ensure alpha is strictly 0.10."
        )

    if all_passed:
        diagnostic_messages.append("[PASS] All qualitative manuscript invariants were successfully replicated.")
        logger.info("Fidelity Check: All qualitative patterns match the manuscript.")
    else:
        logger.warning("Fidelity Check: One or more qualitative patterns deviated from the manuscript. See diagnostic report.")

    diagnostic_log = "\n".join(diagnostic_messages)
    return consolidated_flags, diagnostic_log

# -------------------------------------------------------------------------------------------------------------------------------
# Task 29, Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
@dataclass(frozen=True)
class PaperDeliverablesReport:
    """
    Immutable data container for the final paper-grade deliverables and fidelity diagnostics.

    Attributes
    ----------
    tables : Dict[str, pd.DataFrame]
        Dictionary containing the generated manuscript tables (e.g., Table 1, Table 3).
    figures : Dict[str, plt.Figure]
        Dictionary containing the generated matplotlib Figure objects.
    fidelity_flags : Dict[str, bool]
        Dictionary of boolean flags indicating if qualitative invariants were met.
    diagnostic_log : str
        A formatted string containing systematic diagnostic recommendations.
    """
    tables: Dict[str, pd.DataFrame]
    figures: Dict[str, plt.Figure]
    fidelity_flags: Dict[str, bool]
    diagnostic_log: str


def orchestrate_paper_deliverables(
    master_report: Any
) -> PaperDeliverablesReport:
    """
    Orchestrates Task 29: Produces paper-grade deliverables and verifies fidelity.

    This function executes the final synthesis steps in a strict Directed Acyclic Graph (DAG) order.
    It extracts the necessary artifacts from the SentinelSystemReport, generates the formatted
    tables and publication-quality figures, consolidates the qualitative diagnostic flags, and
    produces a systematic diagnostic report to guide any necessary methodological debugging.

    Parameters
    ----------
    master_report : SentinelSystemReport
        The immutable dataclass containing all intermediate and final research artifacts (from Task 28).

    Returns
    -------
    PaperDeliverablesReport
        An immutable dataclass containing the final tables, figures, and diagnostic logs.
    """
    logger.info("Starting Task 29 Orchestration: Paper Deliverables and Fidelity Verification.")

    tables: Dict[str, pd.DataFrame] = {}
    figures: Dict[str, plt.Figure] = {}

    # Step 1: Generate required tables and figures
    # Generate Table 1 and 2 (Descriptive Statistics)
    stats_tables = generate_descriptive_statistics_tables(
        master_report.aligned_data_report,
        master_report.post_imputation_report
    )
    tables.update(stats_tables)

    # Generate Table 3 (Top 5 Influential Companies)
    table_3 = generate_top_5_influential_companies_table(
        master_report.pagerank_report
    )
    tables["Table_3_Top_5_Influential"] = table_3

    # Generate Figures 5 and 7 (Density and Jaccard)
    line_figures = generate_density_and_jaccard_figures(
        master_report.network_density_report,
        master_report.jaccard_report
    )
    figures.update(line_figures)

    # Generate Figures 9 and 10 (Heatmaps)
    heatmap_figures = generate_heatmap_figures(
        master_report.node_influence_report
    )
    figures.update(heatmap_figures)

    # Steps 2 & 3: Perform fidelity checks and diagnose systematically
    fidelity_flags, diagnostic_log = verify_fidelity_and_diagnose(
        master_report.network_density_report,
        master_report.regime_network_report,
        master_report.jaccard_report
    )

    # Package the deliverables into an immutable dataclass
    report = PaperDeliverablesReport(
        tables=tables,
        figures=figures,
        fidelity_flags=fidelity_flags,
        diagnostic_log=diagnostic_log
    )

    logger.info("=== Task 29 completed successfully. Paper deliverables generated and fidelity verified. ===")

    # Return the immutable deliverables report
    return report

# %%
# Top-Level Orchestrator

# ===============================================================================
# Top-Level Orchestrator: High-Frequency Sentinel System for Information Topology
# ===============================================================================

# -------------------------------------------------------------------------------------------------------------------------------
# Top-Level Orchestrator Function
# -------------------------------------------------------------------------------------------------------------------------------
def run_sentinel_system_pipeline(
    tech_universe_raw: Dict[str, Any],
    df_sector_mapping: pd.DataFrame,
    df_news_sentiment_raw: pd.DataFrame,
    df_social_sentiment_raw: pd.DataFrame,
    study_configuration: Dict[str, Any],
    fallback_calendar: Optional[pd.DatetimeIndex] = None
) -> Dict[str, Any]:
    """
    Executes the complete High-Frequency Sentinel System pipeline (Tasks 1-29).

    This is the top-level entry point for the research methodology defined by Wu et al. (2026).
    It has been refactored to expose the fallback_calendar parameter, allowing the user
    to inject a pre-validated exchange calendar if standard business day generation fails
    due to holiday anomalies, thereby mathematically guaranteeing the T=1319 invariant.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe (Vertex Set V).
    df_sector_mapping : pd.DataFrame
        The raw GICS mapping DataFrame for sector interpretation.
    df_news_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg News daily sentiment DataFrame.
    df_social_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg Social Media daily sentiment DataFrame.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing all methodological parameters.
    fallback_calendar : Optional[pd.DatetimeIndex], optional
        A pre-validated, exact calendar of length 1319 to use if standard business
        days do not align perfectly with the manuscript's count, by default None.

    Returns
    -------
    Dict[str, Any]
        A comprehensive dictionary containing:
        - 'system_artifacts': The immutable SentinelSystemReport (Task 28 output).
        - 'paper_deliverables': The immutable PaperDeliverablesReport (Task 29 output).
        - 'pipeline_diagnostics': The formatted diagnostic log string.
        - 'fidelity_passed': Boolean indicating if all qualitative invariants were met.

    Raises
    ------
    RuntimeError
        If any fatal error occurs during the execution of the underlying DAG.
    """
    logger.info("*********************************************************************")
    logger.info("INITIALIZING TOP-LEVEL SENTINEL SYSTEM EXECUTION")
    logger.info("*********************************************************************")

    try:
        # -------------------------------------------------------------------------------------------
        # Phase A: Execute the Mathematical Engine (Tasks 1-28)
        # -------------------------------------------------------------------------------------------
        logger.info("Phase A: Engaging Mathematical Engine (Tasks 1-28)...")

        # REFACTORED: Pass the fallback_calendar down to the DAG orchestrator
        master_system_report = orchestrate_sentinel_system_pipeline(
            tech_universe_raw=tech_universe_raw,
            df_sector_mapping=df_sector_mapping,
            df_news_sentiment_raw=df_news_sentiment_raw,
            df_social_sentiment_raw=df_social_sentiment_raw,
            study_configuration=study_configuration,
            fallback_calendar=fallback_calendar
        )

        # -------------------------------------------------------------------------------------------
        # Phase B: Execute the Presentation and Diagnostic Layer (Task 29)
        # -------------------------------------------------------------------------------------------
        logger.info("Phase B: Engaging Presentation and Diagnostic Layer (Task 29)...")

        paper_deliverables_report = orchestrate_paper_deliverables(
            master_report=master_system_report
        )

        # -------------------------------------------------------------------------------------------
        # Phase C: Compile the Final Output Dictionary
        # -------------------------------------------------------------------------------------------
        all_fidelity_passed: bool = all(paper_deliverables_report.fidelity_flags.values())

        final_output: Dict[str, Any] = {
            "system_artifacts": master_system_report,
            "paper_deliverables": paper_deliverables_report,
            "pipeline_diagnostics": paper_deliverables_report.diagnostic_log,
            "fidelity_passed": all_fidelity_passed
        }

        logger.info("*********************************************************************")
        if all_fidelity_passed:
            logger.info("TOP-LEVEL EXECUTION COMPLETE: ALL FIDELITY CHECKS PASSED.")
        else:
            logger.warning("TOP-LEVEL EXECUTION COMPLETE: FIDELITY DEVIATIONS DETECTED.")
        logger.info("*********************************************************************")

        return final_output

    except Exception as e:
        logger.error("*********************************************************************")
        logger.error("FATAL PIPELINE ERROR DETECTED")
        logger.error(f"Details: {str(e)}")
        logger.error("*********************************************************************")
        raise RuntimeError(f"Sentinel System pipeline failed during execution. Details: {str(e)}") from e

# %%
# External Execution Script

# -------------------------------------------------------------------------------------------------------------------------------
# 1. Refactoring the External Execution Script (User-Facing Deployment)
# -------------------------------------------------------------------------------------------------------------------------------
def deploy_sentinel_system(
    tech_universe_raw: Dict[str, Any],
    df_sector_mapping: pd.DataFrame,
    df_news_sentiment_raw: pd.DataFrame,
    df_social_sentiment_raw: pd.DataFrame,
    study_configuration: Dict[str, Any],
    output_directory: str = "./sentinel_deliverables"
) -> None:
    """
    Executes the Sentinel System pipeline and exports publication-ready artifacts.

    This function serves as the ultimate user-facing deployment script. It mathematically
    guarantees the temporal invariant T=1319 by querying the exact NYSE trading schedule,
    bypassing the anomalies of standard business day generation. It then executes the
    top-level pipeline, asserts qualitative fidelity, and persists the resulting tables
    and figures to disk.

    Parameters
    ----------
    tech_universe_raw : Dict[str, Any]
        The raw dictionary defining the Technology Company Universe (Vertex Set V).
    df_sector_mapping : pd.DataFrame
        The raw GICS mapping DataFrame for sector interpretation.
    df_news_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg News daily sentiment DataFrame.
    df_social_sentiment_raw : pd.DataFrame
        The raw ingested Bloomberg Social Media daily sentiment DataFrame.
    study_configuration : Dict[str, Any]
        The master configuration dictionary containing all methodological parameters.
    output_directory : str, optional
        The local directory path where artifacts will be saved, by default "./sentinel_deliverables".

    Raises
    ------
    ValueError
        If the generated NYSE calendar does not exactly equal T=1319.
    RuntimeError
        If the pipeline execution fails or if the qualitative fidelity checks fail.
    """
    logger.info("=====================================================================")
    logger.info("INITIATING SENTINEL SYSTEM DEPLOYMENT SCRIPT")
    logger.info("=====================================================================")

    # -------------------------------------------------------------------------------------------
    # Step 1: Generate the Exact Exchange Calendar (Mathematical Safeguard)
    # -------------------------------------------------------------------------------------------
    # Extract the study boundaries from the configuration
    start_date_str, end_date_str = study_configuration["metadata"]["date_range"]
    expected_T: int = study_configuration["metadata"]["observations_total_T"]

    logger.info(f"Querying NYSE trading schedule from {start_date_str} to {end_date_str}...")

    # Instantiate the New York Stock Exchange calendar
    nyse = mcal.get_calendar('NYSE')

    # Retrieve the valid trading schedule within the study bounds
    schedule = nyse.schedule(start_date=start_date_str, end_date=end_date_str)

    # Extract the dates, convert to a DatetimeIndex, and strip timezone information
    # Stripping timezones (.tz_localize(None)) is critical to prevent alignment crashes
    # when compared against timezone-naive configuration strings downstream.
    fallback_calendar: pd.DatetimeIndex = pd.DatetimeIndex(schedule.index).tz_localize(None).sort_values()

    # Enforce the mathematical invariant T=1319
    if len(fallback_calendar) != expected_T:
        raise ValueError(f"NYSE calendar generation failed to yield exactly T={expected_T}. "
                         f"Found {len(fallback_calendar)} days. Check date bounds or library version.")

    logger.info(f"Successfully generated exact exchange calendar. T={len(fallback_calendar)}.")

    # -------------------------------------------------------------------------------------------
    # Step 2: Execute the Top-Level Pipeline
    # -------------------------------------------------------------------------------------------
    logger.info("Executing run_sentinel_system_pipeline...")

    try:
        # Note: run_sentinel_system_pipeline is assumed to be available in the working environment
        pipeline_results: Dict[str, Any] = run_sentinel_system_pipeline(
            tech_universe_raw=tech_universe_raw,
            df_sector_mapping=df_sector_mapping,
            df_news_sentiment_raw=df_news_sentiment_raw,
            df_social_sentiment_raw=df_social_sentiment_raw,
            study_configuration=study_configuration,
            fallback_calendar=fallback_calendar
        )
    except Exception as e:
        raise RuntimeError(f"Pipeline execution failed: {str(e)}") from e

    # -------------------------------------------------------------------------------------------
    # Step 3: Assert Qualitative Fidelity
    # -------------------------------------------------------------------------------------------
    # The pipeline returns a boolean flag indicating if the manuscript's qualitative
    # findings (e.g., the News density spike) were successfully replicated.
    fidelity_passed: bool = pipeline_results.get("fidelity_passed", False)

    if not fidelity_passed:
        diagnostic_log = pipeline_results.get("pipeline_diagnostics", "No diagnostics available.")
        logger.error("Pipeline completed, but qualitative fidelity checks failed.")
        logger.error(f"Diagnostic Log:\n{diagnostic_log}")
        raise RuntimeError("Deployment aborted due to fidelity check failure. See logs for details.")

    logger.info("Qualitative fidelity checks passed. Proceeding to artifact extraction.")

    # -------------------------------------------------------------------------------------------
    # Step 4: Extract and Persist Paper-Grade Deliverables
    # -------------------------------------------------------------------------------------------
    # Extract the presentation layer dataclass
    deliverables_report = pipeline_results["paper_deliverables"]

    # Create the output directory if it does not exist
    out_dir = Path(output_directory)
    out_dir.mkdir(parents=True, exist_ok=True)

    logger.info(f"Persisting artifacts to {out_dir.resolve()}...")

    # Persist Tables (DataFrames) to CSV
    for table_name, df_table in deliverables_report.tables.items():
        file_path = out_dir / f"{table_name}.csv"
        # Save with index=True as the index often contains critical data (e.g., Ticker or Rank)
        df_table.to_csv(file_path, index=True)
        logger.debug(f"Saved table: {file_path}")

    # Persist Figures (Matplotlib Objects) to high-resolution PDF
    for fig_name, fig_obj in deliverables_report.figures.items():
        file_path = out_dir / f"{fig_name}.pdf"
        # Save as PDF with 300 DPI for publication-quality vector graphics
        fig_obj.savefig(file_path, format='pdf', dpi=300, bbox_inches='tight')
        # Close the figure to free memory
        plt.close(fig_obj)
        logger.debug(f"Saved figure: {file_path}")

    # Persist the Diagnostic Log to a text file for auditability
    log_path = out_dir / "fidelity_diagnostic_log.txt"
    with open(log_path, "w") as f:
        f.write(deliverables_report.diagnostic_log)
    logger.debug(f"Saved diagnostic log: {log_path}")

    logger.info("=====================================================================")
    logger.info("SENTINEL SYSTEM DEPLOYMENT COMPLETED SUCCESSFULLY")
    logger.info("=====================================================================")
